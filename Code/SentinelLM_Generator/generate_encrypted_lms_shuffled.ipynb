# %%
# !git clone -b CameraReady https://lmd0420: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@github.com/abhijitmishra/CyberLLM.git
#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
# Out:
# Cloning into 'CyberLLM'...
# remote: Enumerating objects: 231, done.
# remote: Counting objects: 100% (231/231), done.
# remote: Compressing objects: 100% (155/155), done.
# remote: Total 231 (delta 133), reused 156 (delta 68), pack-reused 0
# Receiving objects: 100% (231/231), 22.86 MiB | 4.09 MiB/s, done.
# Resolving deltas: 100% (133/133), done.
# Updating files: 100% (41/41), done.

# %%
# %cd CyberLLM/Code/SentinelLM_Generator
# !pip install -r requirements.txt
# Out:
# /content/CyberLLM/Code/SentinelLM_Generator
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 60.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 81.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 71.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.7/265.7 kB 31.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 44.3 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 8.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 11.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 15.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 18.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 90.9 MB/s eta 0:00:00
# ...

# %%
# %cd /content
# !ls
# Out:
# /content
# CyberLLM  sample_data

# %%
# %%bash
# models="roberta-base bert-base-uncased bert-base-multilingual-uncased"
# keys="llm123 nlp2023"
# embedding_rescaling_factors="3 10"
#
# for model in $models; do
#   for key in $keys; do
#     for erf in $embedding_rescaling_factors; do
#       MODEL_PATH="${model}-blake2-glide{erf}-key-${key}-shuffled"
#       echo $MODEL_PATH
#       python llm_converter.py \
#         --model_name_or_path $model \
#         --encryption_key $key \
#         --destination $MODEL_PATH \
#         --embedding_rescaling_factor $erf \
#         --shuffle
#     done
#   done
# done
# Out:
# roberta-base-llm123-fact3-shuffle
# roberta-base-llm123-fact10-shuffle
# roberta-base-nlp2023-fact3-shuffle
# roberta-base-nlp2023-fact10-shuffle
# bert-base-uncased-llm123-fact3-shuffle
# bert-base-uncased-llm123-fact10-shuffle
# bert-base-uncased-nlp2023-fact3-shuffle
# bert-base-uncased-nlp2023-fact10-shuffle
# bert-base-multilingual-uncased-llm123-fact3-shuffle
# bert-base-multilingual-uncased-llm123-fact10-shuffle
# bert-base-multilingual-uncased-nlp2023-fact3-shuffle
# bert-base-multilingual-uncased-nlp2023-fact10-shuffle
# 2023-12-18 10:24:46,151 - INFO - Adapting model roberta-base with seed 475
# 2023-12-18 10:24:46,151 - INFO - Manipulating Embeddings with a transform factor 3
# 2023-12-18 10:24:46,151 - INFO - Encrypting and shuffling vocabulary
# config.json: 100%|██████████| 481/481 [00:00<00:00, 2.62MB/s]
# vocab.json: 100%|██████████| 899k/899k [00:00<00:00, 1.83MB/s]
# merges.txt: 100%|██████████| 456k/456k [00:00<00:00, 1.84MB/s]
# ...

# %% [markdown]
# ## Upload Models to HuggingFace

# %%
# !pip install transformers huggingface_hub

# %%
# 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

# %%
import os
from huggingface_hub import HfApi
os.environ["HF_TOKEN"] = "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"
api = HfApi()

# %%
# %%writefile upload_script.py
from huggingface_hub import HfApi, Repository
import os

def upload_model(model_path, model_name):
    api = HfApi()
    hf_username = api.whoami(token=os.environ["HF_TOKEN"])["name"]
    repo_id = f"{hf_username}/{model_name}"

    # create repos
    try:
        api.create_repo(token=os.environ["HF_TOKEN"], name=model_name, organization=hf_username, exist_ok=True)
    except Exception as e:
        print(f"Repository creation failed or already exists: {e}")

    # upload models
    api.upload_folder(
        folder_path=model_path,
        repo_id=repo_id,
        token=os.environ["HF_TOKEN"]
    )
# Out:
# Overwriting upload_script.py

# %%
# %%bash
# models="roberta-base bert-base-uncased bert-base-multilingual-uncased"
# keys="llm123 nlp2023"
# embedding_rescaling_factors="3 10"
#
# for model in $models; do
#   for key in $keys; do
#     for erf in $embedding_rescaling_factors; do
#       MODEL_PATH="${model}-blake2-glide{erf}-key-${key}-shuffled"
#       MODEL_NAME="${model}-blake2-glide{erf}-key-${key}-shuffled"
#       echo "Uploading $MODEL_NAME to Hugging Face Hub"
#       python -c "from upload_script import upload_model; upload_model('$MODEL_PATH', '$MODEL_NAME')"
#       echo "Upload of $MODEL_NAME completed"
#     done
#   done
# done
# Out:
# Uploading roberta-base-llm123-fact3-shuffle to Hugging Face Hub
# Repository creation failed or already exists: HfApi.create_repo() got an unexpected keyword argument 'name'
# Upload of roberta-base-llm123-fact3-shuffle completed
# Uploading roberta-base-llm123-fact10-shuffle to Hugging Face Hub
# Repository creation failed or already exists: HfApi.create_repo() got an unexpected keyword argument 'name'
# Upload of roberta-base-llm123-fact10-shuffle completed
# Uploading roberta-base-nlp2023-fact3-shuffle to Hugging Face Hub
# Repository creation failed or already exists: HfApi.create_repo() got an unexpected keyword argument 'name'
# Upload of roberta-base-nlp2023-fact3-shuffle completed
# Uploading roberta-base-nlp2023-fact10-shuffle to Hugging Face Hub
# Repository creation failed or already exists: HfApi.create_repo() got an unexpected keyword argument 'name'
# Upload of roberta-base-nlp2023-fact10-shuffle completed
# ...
