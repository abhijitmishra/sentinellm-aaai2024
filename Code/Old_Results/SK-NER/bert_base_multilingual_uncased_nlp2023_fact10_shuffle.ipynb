# %%
# !wget https://raw.githubusercontent.com/huggingface/transformers/main/examples/pytorch/token-classification/requirements.txt
# !pip install transformers
# !pip install -r requirements.txt
# Out:
# --2023-11-05 05:23:03--  https://raw.githubusercontent.com/huggingface/transformers/main/examples/pytorch/token-classification/requirements.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 68 [text/plain]
# Saving to: ‘requirements.txt’
#
# requirements.txt    100%[===================>]      68  --.-KB/s    in 0s
#
# 2023-11-05 05:23:03 (2.70 MB/s) - ‘requirements.txt’ saved [68/68]
#
# Collecting transformers
#   Downloading transformers-4.35.0-py3-none-any.whl (7.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 71.1 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.4)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers)
#   Downloading huggingface_hub-0.18.0-py3-none-any.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 38.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Collecting tokenizers<0.15,>=0.14 (from transformers)
#   Downloading tokenizers-0.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 114.1 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 70.7 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers)
#   Downloading huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 42.1 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Installing collected packages: safetensors, huggingface-hub, tokenizers, transformers
# Successfully installed huggingface-hub-0.17.3 safetensors-0.4.0 tokenizers-0.14.1 transformers-4.35.0
# Collecting accelerate>=0.12.0 (from -r requirements.txt (line 1))
#   Downloading accelerate-0.24.1-py3-none-any.whl (261 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.4/261.4 kB 6.4 MB/s eta 0:00:00
# Collecting seqeval (from -r requirements.txt (line 2))
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 7.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting datasets>=1.8.0 (from -r requirements.txt (line 3))
#   Downloading datasets-2.14.6-py3-none-any.whl (493 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 493.7/493.7 kB 10.7 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.3 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 4)) (2.1.0+cu118)
# Collecting evaluate (from -r requirements.txt (line 5))
#   Downloading evaluate-0.4.1-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 13.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.12.0->-r requirements.txt (line 1)) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.12.0->-r requirements.txt (line 1)) (23.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.12.0->-r requirements.txt (line 1)) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.12.0->-r requirements.txt (line 1)) (6.0.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.12.0->-r requirements.txt (line 1)) (0.17.3)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.10/dist-packages (from seqeval->-r requirements.txt (line 2)) (1.2.2)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=1.8.0->-r requirements.txt (line 3)) (9.0.0)
# Collecting dill<0.3.8,>=0.3.0 (from datasets>=1.8.0->-r requirements.txt (line 3))
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 11.9 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets>=1.8.0->-r requirements.txt (line 3)) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=1.8.0->-r requirements.txt (line 3)) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=1.8.0->-r requirements.txt (line 3)) (4.66.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets>=1.8.0->-r requirements.txt (line 3)) (3.4.1)
# Collecting multiprocess (from datasets>=1.8.0->-r requirements.txt (line 3))
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 14.0 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=1.8.0->-r requirements.txt (line 3)) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=1.8.0->-r requirements.txt (line 3)) (3.8.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->-r requirements.txt (line 4)) (3.12.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->-r requirements.txt (line 4)) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->-r requirements.txt (line 4)) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->-r requirements.txt (line 4)) (3.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->-r requirements.txt (line 4)) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->-r requirements.txt (line 4)) (2.1.0)
# Collecting responses<0.19 (from evaluate->-r requirements.txt (line 5))
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=1.8.0->-r requirements.txt (line 3)) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=1.8.0->-r requirements.txt (line 3)) (3.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=1.8.0->-r requirements.txt (line 3)) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=1.8.0->-r requirements.txt (line 3)) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=1.8.0->-r requirements.txt (line 3)) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=1.8.0->-r requirements.txt (line 3)) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=1.8.0->-r requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=1.8.0->-r requirements.txt (line 3)) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=1.8.0->-r requirements.txt (line 3)) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=1.8.0->-r requirements.txt (line 3)) (2023.7.22)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval->-r requirements.txt (line 2)) (1.11.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval->-r requirements.txt (line 2)) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval->-r requirements.txt (line 2)) (3.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.3->-r requirements.txt (line 4)) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=1.8.0->-r requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=1.8.0->-r requirements.txt (line 3)) (2023.3.post1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.3->-r requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets>=1.8.0->-r requirements.txt (line 3)) (1.16.0)
# Building wheels for collected packages: seqeval
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16162 sha256=dae60a81c5c38e10e782aaac57927ac9c57999bcc7c3ecd8f11f13ab05e624ac
#   Stored in directory: /root/.cache/pip/wheels/1a/67/4a/ad4082dd7dfc30f2abfe4d80a2ed5926a506eb8a972b4767fa
# Successfully built seqeval
# Installing collected packages: dill, responses, multiprocess, seqeval, accelerate, datasets, evaluate
# Successfully installed accelerate-0.24.1 datasets-2.14.6 dill-0.3.7 evaluate-0.4.1 multiprocess-0.70.15 responses-0.18.0 seqeval-1.2.2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !python run_ner_blake2.py \
 --model_name_or_path "/content/drive/MyDrive/CyberBERT/manipulated/multilingual-blake2/bert-base-multilingual-uncased-nlp2023-fact10-shuffle" \
 --dataset_name ju-bezdek/conll2003-SK-NER \
 --output_dir /tmp/test-ner \
 --do_train \
 --do_eval \
 --encryption_key "nlp2023"
# Out:
# 2023-11-05 05:23:52.874978: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-05 05:23:52.875026: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-05 05:23:52.875052: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-05 05:23:53.992215: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 11/05/2023 05:23:57 - WARNING - __main__ - Process rank: 0, device: cuda:0, n_gpu: 1distributed training: False, 16-bits training: False
# 11/05/2023 05:23:57 - INFO - __main__ - Training/evaluation parameters TrainingArguments(
# _n_gpu=1,
# adafactor=False,
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# auto_find_batch_size=False,
# bf16=False,
# bf16_full_eval=False,
# data_seed=None,
# dataloader_drop_last=False,
# dataloader_num_workers=0,
# dataloader_pin_memory=True,
# ddp_backend=None,
# ddp_broadcast_buffers=None,
# ddp_bucket_cap_mb=None,
# ddp_find_unused_parameters=None,
# ddp_timeout=1800,
# debug=[],
# deepspeed=None,
# disable_tqdm=False,
# dispatch_batches=None,
# do_eval=True,
# do_predict=False,
# do_train=True,
# eval_accumulation_steps=None,
# eval_delay=0,
# eval_steps=None,
# evaluation_strategy=no,
# fp16=False,
# fp16_backend=auto,
# fp16_full_eval=False,
# fp16_opt_level=O1,
# fsdp=[],
# fsdp_config={'min_num_params': 0, 'xla': False, 'xla_fsdp_grad_ckpt': False},
# fsdp_min_num_params=0,
# fsdp_transformer_layer_cls_to_wrap=None,
# full_determinism=False,
# gradient_accumulation_steps=1,
# gradient_checkpointing=False,
# gradient_checkpointing_kwargs=None,
# greater_is_better=None,
# group_by_length=False,
# half_precision_backend=auto,
# hub_always_push=False,
# hub_model_id=None,
# hub_private_repo=False,
# hub_strategy=every_save,
# hub_token=<HUB_TOKEN>,
# ignore_data_skip=False,
# include_inputs_for_metrics=False,
# include_tokens_per_second=False,
# jit_mode_eval=False,
# label_names=None,
# label_smoothing_factor=0.0,
# learning_rate=5e-05,
# length_column_name=length,
# load_best_model_at_end=False,
# local_rank=0,
# log_level=passive,
# log_level_replica=warning,
# log_on_each_node=True,
# logging_dir=/tmp/test-ner/runs/Nov05_05-23-56_229fe689860b,
# logging_first_step=False,
# logging_nan_inf_filter=True,
# logging_steps=500,
# logging_strategy=steps,
# lr_scheduler_type=linear,
# max_grad_norm=1.0,
# max_steps=-1,
# metric_for_best_model=None,
# mp_parameters=,
# neftune_noise_alpha=None,
# no_cuda=False,
# num_train_epochs=3.0,
# optim=adamw_torch,
# optim_args=None,
# output_dir=/tmp/test-ner,
# overwrite_output_dir=False,
# past_index=-1,
# per_device_eval_batch_size=8,
# per_device_train_batch_size=8,
# prediction_loss_only=False,
# push_to_hub=False,
# push_to_hub_model_id=None,
# push_to_hub_organization=None,
# push_to_hub_token=<PUSH_TO_HUB_TOKEN>,
# ray_scope=last,
# remove_unused_columns=True,
# report_to=['tensorboard'],
# resume_from_checkpoint=None,
# run_name=/tmp/test-ner,
# save_on_each_node=False,
# save_safetensors=True,
# save_steps=500,
# save_strategy=steps,
# save_total_limit=None,
# seed=42,
# skip_memory_metrics=True,
# split_batches=False,
# tf32=None,
# torch_compile=False,
# torch_compile_backend=None,
# torch_compile_mode=None,
# torchdynamo=None,
# tpu_metrics_debug=False,
# tpu_num_cores=None,
# use_cpu=False,
# use_ipex=False,
# use_legacy_prediction_loop=False,
# use_mps_device=False,
# warmup_ratio=0.0,
# warmup_steps=0,
# weight_decay=0.0,
# )
# https://huggingface.co/datasets/ju-bezdek/conll2003-SK-NER/resolve/main/conll2003-SK-NER.py not found in cache or force_download set to True, downloading to /root/.cache/huggingface/datasets/downloads/ff279d08486d10439072581533b8edc06a2226d9d1b21e4129f79672f200ba8c.931084210b7b6c6b1713147e4dfb893ed4a388c6cf72e79039da11a50a0428f6.py.incomplete
# 11/05/2023 05:23:58 - INFO - datasets.utils.file_utils - https://huggingface.co/datasets/ju-bezdek/conll2003-SK-NER/resolve/main/conll2003-SK-NER.py not found in cache or force_download set to True, downloading to /root/.cache/huggingface/datasets/downloads/ff279d08486d10439072581533b8edc06a2226d9d1b21e4129f79672f200ba8c.931084210b7b6c6b1713147e4dfb893ed4a388c6cf72e79039da11a50a0428f6.py.incomplete
# Downloading builder script: 100% 3.60k/3.60k [00:00<00:00, 19.9MB/s]
# storing https://huggingface.co/datasets/ju-bezdek/conll2003-SK-NER/resolve/main/conll2003-SK-NER.py in cache at /root/.cache/huggingface/datasets/downloads/ff279d08486d10439072581533b8edc06a2226d9d1b21e4129f79672f200ba8c.931084210b7b6c6b1713147e4dfb893ed4a388c6cf72e79039da11a50a0428f6.py
# 11/05/2023 05:23:58 - INFO - datasets.utils.file_utils - storing https://huggingface.co/datasets/ju-bezdek/conll2003-SK-NER/resolve/main/conll2003-SK-NER.py in cache at /root/.cache/huggingface/datasets/downloads/ff279d08486d10439072581533b8edc06a2226d9d1b21e4129f79672f200ba8c.931084210b7b6c6b1713147e4dfb893ed4a388c6cf72e79039da11a50a0428f6.py
# creating metadata file for /root/.cache/huggingface/datasets/downloads/ff279d08486d10439072581533b8edc06a2226d9d1b21e4129f79672f200ba8c.931084210b7b6c6b1713147e4dfb893ed4a388c6cf72e79039da11a50a0428f6.py
# 11/05/2023 05:23:58 - INFO - datasets.utils.file_utils - creating metadata file for /root/.cache/huggingface/datasets/downloads/ff279d08486d10439072581533b8edc06a2226d9d1b21e4129f79672f200ba8c.931084210b7b6c6b1713147e4dfb893ed4a388c6cf72e79039da11a50a0428f6.py
# https://huggingface.co/datasets/ju-bezdek/conll2003-SK-NER/resolve/main/dataset_infos.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/datasets/downloads/97494b45facf5ee1bf3228df2d49adbfb35e79dffd392f922cfe366de37c2253.12ade2f7ed82ac85c64be1590de83ede9f72aa2100ffe3334214c2cddb0bad34.incomplete
# 11/05/2023 05:23:58 - INFO - datasets.utils.file_utils - https://huggingface.co/datasets/ju-bezdek/conll2003-SK-NER/resolve/main/dataset_infos.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/datasets/downloads/97494b45facf5ee1bf3228df2d49adbfb35e79dffd392f922cfe366de37c2253.12ade2f7ed82ac85c64be1590de83ede9f72aa2100ffe3334214c2cddb0bad34.incomplete
# Downloading metadata: 100% 1.90k/1.90k [00:00<00:00, 13.4MB/s]
# storing https://huggingface.co/datasets/ju-bezdek/conll2003-SK-NER/resolve/main/dataset_infos.json in cache at /root/.cache/huggingface/datasets/downloads/97494b45facf5ee1bf3228df2d49adbfb35e79dffd392f922cfe366de37c2253.12ade2f7ed82ac85c64be1590de83ede9f72aa2100ffe3334214c2cddb0bad34
# 11/05/2023 05:23:58 - INFO - datasets.utils.file_utils - storing https://huggingface.co/datasets/ju-bezdek/conll2003-SK-NER/resolve/main/dataset_infos.json in cache at /root/.cache/huggingface/datasets/downloads/97494b45facf5ee1bf3228df2d49adbfb35e79dffd392f922cfe366de37c2253.12ade2f7ed82ac85c64be1590de83ede9f72aa2100ffe3334214c2cddb0bad34
# creating metadata file for /root/.cache/huggingface/datasets/downloads/97494b45facf5ee1bf3228df2d49adbfb35e79dffd392f922cfe366de37c2253.12ade2f7ed82ac85c64be1590de83ede9f72aa2100ffe3334214c2cddb0bad34
# 11/05/2023 05:23:58 - INFO - datasets.utils.file_utils - creating metadata file for /root/.cache/huggingface/datasets/downloads/97494b45facf5ee1bf3228df2d49adbfb35e79dffd392f922cfe366de37c2253.12ade2f7ed82ac85c64be1590de83ede9f72aa2100ffe3334214c2cddb0bad34
# https://huggingface.co/datasets/ju-bezdek/conll2003-SK-NER/resolve/main/README.md not found in cache or force_download set to True, downloading to /root/.cache/huggingface/datasets/downloads/2a4d1026eee1ee1a01d3979bf449255bfbe88fafce5cfbfd30b3dd2acfbe2f44.15cdac84608e572210ae8f0c59fe39f9854678c122e558210fb037fede72eed4.incomplete
# 11/05/2023 05:23:59 - INFO - datasets.utils.file_utils - https://huggingface.co/datasets/ju-bezdek/conll2003-SK-NER/resolve/main/README.md not found in cache or force_download set to True, downloading to /root/.cache/huggingface/datasets/downloads/2a4d1026eee1ee1a01d3979bf449255bfbe88fafce5cfbfd30b3dd2acfbe2f44.15cdac84608e572210ae8f0c59fe39f9854678c122e558210fb037fede72eed4.incomplete
# Downloading readme: 100% 1.91k/1.91k [00:00<00:00, 13.5MB/s]
# storing https://huggingface.co/datasets/ju-bezdek/conll2003-SK-NER/resolve/main/README.md in cache at /root/.cache/huggingface/datasets/downloads/2a4d1026eee1ee1a01d3979bf449255bfbe88fafce5cfbfd30b3dd2acfbe2f44.15cdac84608e572210ae8f0c59fe39f9854678c122e558210fb037fede72eed4
# 11/05/2023 05:23:59 - INFO - datasets.utils.file_utils - storing https://huggingface.co/datasets/ju-bezdek/conll2003-SK-NER/resolve/main/README.md in cache at /root/.cache/huggingface/datasets/downloads/2a4d1026eee1ee1a01d3979bf449255bfbe88fafce5cfbfd30b3dd2acfbe2f44.15cdac84608e572210ae8f0c59fe39f9854678c122e558210fb037fede72eed4
# creating metadata file for /root/.cache/huggingface/datasets/downloads/2a4d1026eee1ee1a01d3979bf449255bfbe88fafce5cfbfd30b3dd2acfbe2f44.15cdac84608e572210ae8f0c59fe39f9854678c122e558210fb037fede72eed4
# 11/05/2023 05:23:59 - INFO - datasets.utils.file_utils - creating metadata file for /root/.cache/huggingface/datasets/downloads/2a4d1026eee1ee1a01d3979bf449255bfbe88fafce5cfbfd30b3dd2acfbe2f44.15cdac84608e572210ae8f0c59fe39f9854678c122e558210fb037fede72eed4
# No config specified, defaulting to the single config: conll2003-sk-ner/conll2003-SK-NER
# 11/05/2023 05:23:59 - INFO - datasets.builder - No config specified, defaulting to the single config: conll2003-sk-ner/conll2003-SK-NER
# Loading Dataset Infos from /root/.cache/huggingface/modules/datasets_modules/datasets/ju-bezdek--conll2003-SK-NER/4f8c11457fb6ba1fedbf6a25e0a46ebe9230f8c375885debc1e5466e0f84a87d
# 11/05/2023 05:23:59 - INFO - datasets.info - Loading Dataset Infos from /root/.cache/huggingface/modules/datasets_modules/datasets/ju-bezdek--conll2003-SK-NER/4f8c11457fb6ba1fedbf6a25e0a46ebe9230f8c375885debc1e5466e0f84a87d
# Generating dataset conll2003-sk-ner (/root/.cache/huggingface/datasets/ju-bezdek___conll2003-sk-ner/conll2003-SK-NER/1.0.0/4f8c11457fb6ba1fedbf6a25e0a46ebe9230f8c375885debc1e5466e0f84a87d)
# 11/05/2023 05:23:59 - INFO - datasets.builder - Generating dataset conll2003-sk-ner (/root/.cache/huggingface/datasets/ju-bezdek___conll2003-sk-ner/conll2003-SK-NER/1.0.0/4f8c11457fb6ba1fedbf6a25e0a46ebe9230f8c375885debc1e5466e0f84a87d)
# Downloading and preparing dataset conll2003-sk-ner/conll2003-SK-NER (download: 3.85 MiB, generated: 4.88 MiB, post-processed: Unknown size, total: 8.72 MiB) to /root/.cache/huggingface/datasets/ju-bezdek___conll2003-sk-ner/conll2003-SK-NER/1.0.0/4f8c11457fb6ba1fedbf6a25e0a46ebe9230f8c375885debc1e5466e0f84a87d...
# 11/05/2023 05:23:59 - INFO - datasets.builder - Downloading and preparing dataset conll2003-sk-ner/conll2003-SK-NER (download: 3.85 MiB, generated: 4.88 MiB, post-processed: Unknown size, total: 8.72 MiB) to /root/.cache/huggingface/datasets/ju-bezdek___conll2003-sk-ner/conll2003-SK-NER/1.0.0/4f8c11457fb6ba1fedbf6a25e0a46ebe9230f8c375885debc1e5466e0f84a87d...
# Dataset not on Hf google storage. Downloading and preparing it from source
# 11/05/2023 05:23:59 - INFO - datasets.builder - Dataset not on Hf google storage. Downloading and preparing it from source
# Downloading data files:   0% 0/3 [00:00<?, ?it/s]https://huggingface.co/datasets/ju-bezdek/conll2003-SK-NER/resolve/main/data/train.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/datasets/downloads/943445e295fd7a06860670a8044cd1e8f133059df03f86126693d9073aa472bc.incomplete
# 11/05/2023 05:24:00 - INFO - datasets.utils.file_utils - https://huggingface.co/datasets/ju-bezdek/conll2003-SK-NER/resolve/main/data/train.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/datasets/downloads/943445e295fd7a06860670a8044cd1e8f133059df03f86126693d9073aa472bc.incomplete
#
# Downloading data:   0% 0.00/2.68M [00:00<?, ?B/s]
# Downloading data:   2% 60.4k/2.68M [00:00<00:05, 507kB/s]
# Downloading data:  11% 304k/2.68M [00:00<00:01, 1.40MB/s]
# Downloading data: 100% 2.68M/2.68M [00:00<00:00, 7.19MB/s]
# storing https://huggingface.co/datasets/ju-bezdek/conll2003-SK-NER/resolve/main/data/train.json in cache at /root/.cache/huggingface/datasets/downloads/943445e295fd7a06860670a8044cd1e8f133059df03f86126693d9073aa472bc
# 11/05/2023 05:24:01 - INFO - datasets.utils.file_utils - storing https://huggingface.co/datasets/ju-bezdek/conll2003-SK-NER/resolve/main/data/train.json in cache at /root/.cache/huggingface/datasets/downloads/943445e295fd7a06860670a8044cd1e8f133059df03f86126693d9073aa472bc
# creating metadata file for /root/.cache/huggingface/datasets/downloads/943445e295fd7a06860670a8044cd1e8f133059df03f86126693d9073aa472bc
# 11/05/2023 05:24:01 - INFO - datasets.utils.file_utils - creating metadata file for /root/.cache/huggingface/datasets/downloads/943445e295fd7a06860670a8044cd1e8f133059df03f86126693d9073aa472bc
# Downloading data files:  33% 1/3 [00:01<00:03,  1.65s/it]https://huggingface.co/datasets/ju-bezdek/conll2003-SK-NER/resolve/main/data/valid.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/datasets/downloads/d8559dc13c2fe1e7e6142ee716d23fee1e0f0d9695a727793a8f2479e10df26f.incomplete
# 11/05/2023 05:24:02 - INFO - datasets.utils.file_utils - https://huggingface.co/datasets/ju-bezdek/conll2003-SK-NER/resolve/main/data/valid.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/datasets/downloads/d8559dc13c2fe1e7e6142ee716d23fee1e0f0d9695a727793a8f2479e10df26f.incomplete
#
# Downloading data:   0% 0.00/702k [00:00<?, ?B/s]
# Downloading data:   7% 52.2k/702k [00:00<00:01, 434kB/s]
# Downloading data: 100% 702k/702k [00:00<00:00, 2.31MB/s]
# storing https://huggingface.co/datasets/ju-bezdek/conll2003-SK-NER/resolve/main/data/valid.json in cache at /root/.cache/huggingface/datasets/downloads/d8559dc13c2fe1e7e6142ee716d23fee1e0f0d9695a727793a8f2479e10df26f
# 11/05/2023 05:24:03 - INFO - datasets.utils.file_utils - storing https://huggingface.co/datasets/ju-bezdek/conll2003-SK-NER/resolve/main/data/valid.json in cache at /root/.cache/huggingface/datasets/downloads/d8559dc13c2fe1e7e6142ee716d23fee1e0f0d9695a727793a8f2479e10df26f
# creating metadata file for /root/.cache/huggingface/datasets/downloads/d8559dc13c2fe1e7e6142ee716d23fee1e0f0d9695a727793a8f2479e10df26f
# 11/05/2023 05:24:03 - INFO - datasets.utils.file_utils - creating metadata file for /root/.cache/huggingface/datasets/downloads/d8559dc13c2fe1e7e6142ee716d23fee1e0f0d9695a727793a8f2479e10df26f
# Downloading data files:  67% 2/3 [00:03<00:01,  1.64s/it]https://huggingface.co/datasets/ju-bezdek/conll2003-SK-NER/resolve/main/data/test.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/datasets/downloads/34e0aa36d8fcdb6ed906d2777679f7645a4ee55af3af0363ee1dbd1d11d59cbe.incomplete
# 11/05/2023 05:24:03 - INFO - datasets.utils.file_utils - https://huggingface.co/datasets/ju-bezdek/conll2003-SK-NER/resolve/main/data/test.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/datasets/downloads/34e0aa36d8fcdb6ed906d2777679f7645a4ee55af3af0363ee1dbd1d11d59cbe.incomplete
#
# Downloading data:   0% 0.00/651k [00:00<?, ?B/s]
# Downloading data:   8% 52.2k/651k [00:00<00:01, 418kB/s]
# Downloading data: 100% 651k/651k [00:00<00:00, 2.55MB/s]
# storing https://huggingface.co/datasets/ju-bezdek/conll2003-SK-NER/resolve/main/data/test.json in cache at /root/.cache/huggingface/datasets/downloads/34e0aa36d8fcdb6ed906d2777679f7645a4ee55af3af0363ee1dbd1d11d59cbe
# 11/05/2023 05:24:04 - INFO - datasets.utils.file_utils - storing https://huggingface.co/datasets/ju-bezdek/conll2003-SK-NER/resolve/main/data/test.json in cache at /root/.cache/huggingface/datasets/downloads/34e0aa36d8fcdb6ed906d2777679f7645a4ee55af3af0363ee1dbd1d11d59cbe
# creating metadata file for /root/.cache/huggingface/datasets/downloads/34e0aa36d8fcdb6ed906d2777679f7645a4ee55af3af0363ee1dbd1d11d59cbe
# 11/05/2023 05:24:04 - INFO - datasets.utils.file_utils - creating metadata file for /root/.cache/huggingface/datasets/downloads/34e0aa36d8fcdb6ed906d2777679f7645a4ee55af3af0363ee1dbd1d11d59cbe
# Downloading data files: 100% 3/3 [00:04<00:00,  1.61s/it]
# Downloading took 0.0 min
# 11/05/2023 05:24:04 - INFO - datasets.download.download_manager - Downloading took 0.0 min
# Checksum Computation took 0.0 min
# 11/05/2023 05:24:04 - INFO - datasets.download.download_manager - Checksum Computation took 0.0 min
# Extracting data files: 100% 3/3 [00:00<00:00, 2052.01it/s]
# Generating train split
# 11/05/2023 05:24:04 - INFO - datasets.builder - Generating train split
# Generating train split: 100% 14041/14041 [00:01<00:00, 9686.13 examples/s]
# Generating validation split
# 11/05/2023 05:24:06 - INFO - datasets.builder - Generating validation split
# Generating validation split: 100% 3250/3250 [00:00<00:00, 9004.30 examples/s]
# Generating test split
# 11/05/2023 05:24:06 - INFO - datasets.builder - Generating test split
# Generating test split: 100% 3453/3453 [00:00<00:00, 10054.18 examples/s]
# All the splits matched successfully.
# 11/05/2023 05:24:06 - INFO - datasets.utils.info_utils - All the splits matched successfully.
# Dataset conll2003-sk-ner downloaded and prepared to /root/.cache/huggingface/datasets/ju-bezdek___conll2003-sk-ner/conll2003-SK-NER/1.0.0/4f8c11457fb6ba1fedbf6a25e0a46ebe9230f8c375885debc1e5466e0f84a87d. Subsequent calls will reuse this data.
# 11/05/2023 05:24:06 - INFO - datasets.builder - Dataset conll2003-sk-ner downloaded and prepared to /root/.cache/huggingface/datasets/ju-bezdek___conll2003-sk-ner/conll2003-SK-NER/1.0.0/4f8c11457fb6ba1fedbf6a25e0a46ebe9230f8c375885debc1e5466e0f84a87d. Subsequent calls will reuse this data.
# [INFO|configuration_utils.py:715] 2023-11-05 05:24:07,310 >> loading configuration file /content/drive/MyDrive/CyberBERT/manipulated/multilingual-blake2/bert-base-multilingual-uncased-nlp2023-fact10-shuffle/config.json
# [INFO|configuration_utils.py:777] 2023-11-05 05:24:07,315 >> Model config BertConfig {
#   "_name_or_path": "/content/drive/MyDrive/CyberBERT/manipulated/multilingual-blake2/bert-base-multilingual-uncased-nlp2023-fact10-shuffle",
#   "architectures": [
#     "BertModel"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "directionality": "bidi",
#   "finetuning_task": "ner",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2",
#     "3": "LABEL_3",
#     "4": "LABEL_4",
#     "5": "LABEL_5",
#     "6": "LABEL_6",
#     "7": "LABEL_7",
#     "8": "LABEL_8"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_2": 2,
#     "LABEL_3": 3,
#     "LABEL_4": 4,
#     "LABEL_5": 5,
#     "LABEL_6": 6,
#     "LABEL_7": 7,
#     "LABEL_8": 8
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "pooler_fc_size": 768,
#   "pooler_num_attention_heads": 12,
#   "pooler_num_fc_layers": 3,
#   "pooler_size_per_head": 128,
#   "pooler_type": "first_token_transform",
#   "position_embedding_type": "absolute",
#   "torch_dtype": "float64",
#   "transformers_version": "4.35.0",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 105879
# }
#
# [INFO|tokenization_utils_base.py:2020] 2023-11-05 05:24:07,633 >> loading file vocab.txt
# [INFO|tokenization_utils_base.py:2020] 2023-11-05 05:24:07,633 >> loading file tokenizer.json
# [INFO|tokenization_utils_base.py:2020] 2023-11-05 05:24:07,633 >> loading file added_tokens.json
# [INFO|tokenization_utils_base.py:2020] 2023-11-05 05:24:07,633 >> loading file special_tokens_map.json
# [INFO|tokenization_utils_base.py:2020] 2023-11-05 05:24:07,633 >> loading file tokenizer_config.json
# Downloading (…)okenizer_config.json: 100% 28.0/28.0 [00:00<00:00, 164kB/s]
# Downloading (…)lve/main/config.json: 100% 570/570 [00:00<00:00, 3.17MB/s]
# [INFO|configuration_utils.py:717] 2023-11-05 05:24:09,401 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--bert-base-uncased/snapshots/1dbc166cf8765166998eff31ade2eb64c8a40076/config.json
# [INFO|configuration_utils.py:777] 2023-11-05 05:24:09,401 >> Model config BertConfig {
#   "_name_or_path": "bert-base-uncased",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.35.0",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# Downloading (…)solve/main/vocab.txt: 100% 232k/232k [00:00<00:00, 2.87MB/s]
# Downloading (…)/main/tokenizer.json: 100% 466k/466k [00:00<00:00, 3.49MB/s]
# [INFO|tokenization_utils_base.py:2022] 2023-11-05 05:24:10,375 >> loading file vocab.txt from cache at /root/.cache/huggingface/hub/models--bert-base-uncased/snapshots/1dbc166cf8765166998eff31ade2eb64c8a40076/vocab.txt
# [INFO|tokenization_utils_base.py:2022] 2023-11-05 05:24:10,376 >> loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--bert-base-uncased/snapshots/1dbc166cf8765166998eff31ade2eb64c8a40076/tokenizer.json
# [INFO|tokenization_utils_base.py:2022] 2023-11-05 05:24:10,376 >> loading file added_tokens.json from cache at None
# [INFO|tokenization_utils_base.py:2022] 2023-11-05 05:24:10,376 >> loading file special_tokens_map.json from cache at None
# [INFO|tokenization_utils_base.py:2022] 2023-11-05 05:24:10,376 >> loading file tokenizer_config.json from cache at /root/.cache/huggingface/hub/models--bert-base-uncased/snapshots/1dbc166cf8765166998eff31ade2eb64c8a40076/tokenizer_config.json
# [INFO|configuration_utils.py:717] 2023-11-05 05:24:10,376 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--bert-base-uncased/snapshots/1dbc166cf8765166998eff31ade2eb64c8a40076/config.json
# [INFO|configuration_utils.py:777] 2023-11-05 05:24:10,377 >> Model config BertConfig {
#   "_name_or_path": "bert-base-uncased",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.35.0",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# [INFO|modeling_utils.py:3118] 2023-11-05 05:24:10,421 >> loading weights file /content/drive/MyDrive/CyberBERT/manipulated/multilingual-blake2/bert-base-multilingual-uncased-nlp2023-fact10-shuffle/pytorch_model.bin
# [INFO|modeling_utils.py:3940] 2023-11-05 05:24:34,961 >> Some weights of the model checkpoint at /content/drive/MyDrive/CyberBERT/manipulated/multilingual-blake2/bert-base-multilingual-uncased-nlp2023-fact10-shuffle were not used when initializing BertForTokenClassification: ['pooler.dense.weight', 'pooler.dense.bias']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# [WARNING|modeling_utils.py:3952] 2023-11-05 05:24:34,962 >> Some weights of BertForTokenClassification were not initialized from the model checkpoint at /content/drive/MyDrive/CyberBERT/manipulated/multilingual-blake2/bert-base-multilingual-uncased-nlp2023-fact10-shuffle and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Running tokenizer on train dataset:   0% 0/14041 [00:00<?, ? examples/s]Caching processed dataset at /root/.cache/huggingface/datasets/ju-bezdek___conll2003-sk-ner/conll2003-SK-NER/1.0.0/4f8c11457fb6ba1fedbf6a25e0a46ebe9230f8c375885debc1e5466e0f84a87d/cache-375c1961ff6e757c.arrow
# 11/05/2023 05:24:35 - INFO - datasets.arrow_dataset - Caching processed dataset at /root/.cache/huggingface/datasets/ju-bezdek___conll2003-sk-ner/conll2003-SK-NER/1.0.0/4f8c11457fb6ba1fedbf6a25e0a46ebe9230f8c375885debc1e5466e0f84a87d/cache-375c1961ff6e757c.arrow
# Running tokenizer on train dataset: 100% 14041/14041 [00:05<00:00, 2383.56 examples/s]
# Running tokenizer on validation dataset:   0% 0/3250 [00:00<?, ? examples/s]Caching processed dataset at /root/.cache/huggingface/datasets/ju-bezdek___conll2003-sk-ner/conll2003-SK-NER/1.0.0/4f8c11457fb6ba1fedbf6a25e0a46ebe9230f8c375885debc1e5466e0f84a87d/cache-e8396ddae61eb970.arrow
# 11/05/2023 05:24:41 - INFO - datasets.arrow_dataset - Caching processed dataset at /root/.cache/huggingface/datasets/ju-bezdek___conll2003-sk-ner/conll2003-SK-NER/1.0.0/4f8c11457fb6ba1fedbf6a25e0a46ebe9230f8c375885debc1e5466e0f84a87d/cache-e8396ddae61eb970.arrow
# Running tokenizer on validation dataset: 100% 3250/3250 [00:01<00:00, 1905.61 examples/s]
# Downloading builder script: 100% 6.34k/6.34k [00:00<00:00, 22.4MB/s]
# [INFO|trainer.py:738] 2023-11-05 05:24:48,872 >> The following columns in the training set don't have a corresponding argument in `BertForTokenClassification.forward` and have been ignored: id, tokens, ner_tags. If id, tokens, ner_tags are not expected by `BertForTokenClassification.forward`,  you can safely ignore this message.
# [INFO|trainer.py:1723] 2023-11-05 05:24:48,882 >> ***** Running training *****
# [INFO|trainer.py:1724] 2023-11-05 05:24:48,882 >>   Num examples = 14,041
# [INFO|trainer.py:1725] 2023-11-05 05:24:48,882 >>   Num Epochs = 3
# [INFO|trainer.py:1726] 2023-11-05 05:24:48,882 >>   Instantaneous batch size per device = 8
# [INFO|trainer.py:1729] 2023-11-05 05:24:48,882 >>   Total train batch size (w. parallel, distributed & accumulation) = 8
# [INFO|trainer.py:1730] 2023-11-05 05:24:48,882 >>   Gradient Accumulation steps = 1
# [INFO|trainer.py:1731] 2023-11-05 05:24:48,883 >>   Total optimization steps = 5,268
# [INFO|trainer.py:1732] 2023-11-05 05:24:48,883 >>   Number of trainable parameters = 166,772,745
#   0% 0/5268 [00:00<?, ?it/s][WARNING|logging.py:314] 2023-11-05 05:24:48,895 >> You're using a BertTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# {'loss': 0.3271, 'learning_rate': 4.525436598329537e-05, 'epoch': 0.28}
#   9% 500/5268 [00:27<04:08, 19.22it/s][INFO|trainer.py:2881] 2023-11-05 05:25:16,792 >> Saving model checkpoint to /tmp/test-ner/checkpoint-500
# [INFO|configuration_utils.py:461] 2023-11-05 05:25:16,793 >> Configuration saved in /tmp/test-ner/checkpoint-500/config.json
# [INFO|modeling_utils.py:2193] 2023-11-05 05:25:18,004 >> Model weights saved in /tmp/test-ner/checkpoint-500/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2428] 2023-11-05 05:25:18,005 >> tokenizer config file saved in /tmp/test-ner/checkpoint-500/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2437] 2023-11-05 05:25:18,005 >> Special tokens file saved in /tmp/test-ner/checkpoint-500/special_tokens_map.json
# {'loss': 0.2216, 'learning_rate': 4.050873196659074e-05, 'epoch': 0.57}
#  19% 1000/5268 [00:56<03:34, 19.87it/s][INFO|trainer.py:2881] 2023-11-05 05:25:45,005 >> Saving model checkpoint to /tmp/test-ner/checkpoint-1000
# [INFO|configuration_utils.py:461] 2023-11-05 05:25:45,006 >> Configuration saved in /tmp/test-ner/checkpoint-1000/config.json
# [INFO|modeling_utils.py:2193] 2023-11-05 05:25:46,201 >> Model weights saved in /tmp/test-ner/checkpoint-1000/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2428] 2023-11-05 05:25:46,202 >> tokenizer config file saved in /tmp/test-ner/checkpoint-1000/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2437] 2023-11-05 05:25:46,202 >> Special tokens file saved in /tmp/test-ner/checkpoint-1000/special_tokens_map.json
# {'loss': 0.1831, 'learning_rate': 3.5763097949886106e-05, 'epoch': 0.85}
#  28% 1500/5268 [01:24<03:15, 19.32it/s][INFO|trainer.py:2881] 2023-11-05 05:26:13,804 >> Saving model checkpoint to /tmp/test-ner/checkpoint-1500
# [INFO|configuration_utils.py:461] 2023-11-05 05:26:13,805 >> Configuration saved in /tmp/test-ner/checkpoint-1500/config.json
# [INFO|modeling_utils.py:2193] 2023-11-05 05:26:14,987 >> Model weights saved in /tmp/test-ner/checkpoint-1500/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2428] 2023-11-05 05:26:14,988 >> tokenizer config file saved in /tmp/test-ner/checkpoint-1500/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2437] 2023-11-05 05:26:14,988 >> Special tokens file saved in /tmp/test-ner/checkpoint-1500/special_tokens_map.json
# {'loss': 0.1464, 'learning_rate': 3.1017463933181475e-05, 'epoch': 1.14}
#  38% 2000/5268 [01:53<02:37, 20.69it/s][INFO|trainer.py:2881] 2023-11-05 05:26:42,340 >> Saving model checkpoint to /tmp/test-ner/checkpoint-2000
# [INFO|configuration_utils.py:461] 2023-11-05 05:26:42,341 >> Configuration saved in /tmp/test-ner/checkpoint-2000/config.json
# [INFO|modeling_utils.py:2193] 2023-11-05 05:26:43,523 >> Model weights saved in /tmp/test-ner/checkpoint-2000/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2428] 2023-11-05 05:26:43,524 >> tokenizer config file saved in /tmp/test-ner/checkpoint-2000/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2437] 2023-11-05 05:26:43,525 >> Special tokens file saved in /tmp/test-ner/checkpoint-2000/special_tokens_map.json
# {'loss': 0.1262, 'learning_rate': 2.6271829916476843e-05, 'epoch': 1.42}
#  47% 2500/5268 [02:21<02:17, 20.09it/s][INFO|trainer.py:2881] 2023-11-05 05:27:10,567 >> Saving model checkpoint to /tmp/test-ner/checkpoint-2500
# [INFO|configuration_utils.py:461] 2023-11-05 05:27:10,568 >> Configuration saved in /tmp/test-ner/checkpoint-2500/config.json
# [INFO|modeling_utils.py:2193] 2023-11-05 05:27:11,767 >> Model weights saved in /tmp/test-ner/checkpoint-2500/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2428] 2023-11-05 05:27:11,768 >> tokenizer config file saved in /tmp/test-ner/checkpoint-2500/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2437] 2023-11-05 05:27:11,768 >> Special tokens file saved in /tmp/test-ner/checkpoint-2500/special_tokens_map.json
# {'loss': 0.1384, 'learning_rate': 2.152619589977221e-05, 'epoch': 1.71}
#  57% 3000/5268 [02:49<01:54, 19.73it/s][INFO|trainer.py:2881] 2023-11-05 05:27:38,817 >> Saving model checkpoint to /tmp/test-ner/checkpoint-3000
# [INFO|configuration_utils.py:461] 2023-11-05 05:27:38,818 >> Configuration saved in /tmp/test-ner/checkpoint-3000/config.json
# [INFO|modeling_utils.py:2193] 2023-11-05 05:27:40,007 >> Model weights saved in /tmp/test-ner/checkpoint-3000/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2428] 2023-11-05 05:27:40,008 >> tokenizer config file saved in /tmp/test-ner/checkpoint-3000/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2437] 2023-11-05 05:27:40,008 >> Special tokens file saved in /tmp/test-ner/checkpoint-3000/special_tokens_map.json
# {'loss': 0.1183, 'learning_rate': 1.678056188306758e-05, 'epoch': 1.99}
#  66% 3500/5268 [03:18<01:24, 20.85it/s][INFO|trainer.py:2881] 2023-11-05 05:28:07,083 >> Saving model checkpoint to /tmp/test-ner/checkpoint-3500
# [INFO|configuration_utils.py:461] 2023-11-05 05:28:07,084 >> Configuration saved in /tmp/test-ner/checkpoint-3500/config.json
# [INFO|modeling_utils.py:2193] 2023-11-05 05:28:08,294 >> Model weights saved in /tmp/test-ner/checkpoint-3500/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2428] 2023-11-05 05:28:08,295 >> tokenizer config file saved in /tmp/test-ner/checkpoint-3500/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2437] 2023-11-05 05:28:08,295 >> Special tokens file saved in /tmp/test-ner/checkpoint-3500/special_tokens_map.json
# {'loss': 0.0794, 'learning_rate': 1.2034927866362947e-05, 'epoch': 2.28}
#  76% 4000/5268 [03:46<01:01, 20.58it/s][INFO|trainer.py:2881] 2023-11-05 05:28:35,538 >> Saving model checkpoint to /tmp/test-ner/checkpoint-4000
# [INFO|configuration_utils.py:461] 2023-11-05 05:28:35,539 >> Configuration saved in /tmp/test-ner/checkpoint-4000/config.json
# [INFO|modeling_utils.py:2193] 2023-11-05 05:28:36,726 >> Model weights saved in /tmp/test-ner/checkpoint-4000/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2428] 2023-11-05 05:28:36,727 >> tokenizer config file saved in /tmp/test-ner/checkpoint-4000/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2437] 2023-11-05 05:28:36,727 >> Special tokens file saved in /tmp/test-ner/checkpoint-4000/special_tokens_map.json
# {'loss': 0.0701, 'learning_rate': 7.289293849658315e-06, 'epoch': 2.56}
#  85% 4500/5268 [04:14<00:38, 19.86it/s][INFO|trainer.py:2881] 2023-11-05 05:29:03,831 >> Saving model checkpoint to /tmp/test-ner/checkpoint-4500
# [INFO|configuration_utils.py:461] 2023-11-05 05:29:03,832 >> Configuration saved in /tmp/test-ner/checkpoint-4500/config.json
# [INFO|modeling_utils.py:2193] 2023-11-05 05:29:05,027 >> Model weights saved in /tmp/test-ner/checkpoint-4500/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2428] 2023-11-05 05:29:05,028 >> tokenizer config file saved in /tmp/test-ner/checkpoint-4500/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2437] 2023-11-05 05:29:05,028 >> Special tokens file saved in /tmp/test-ner/checkpoint-4500/special_tokens_map.json
# {'loss': 0.0735, 'learning_rate': 2.5436598329536827e-06, 'epoch': 2.85}
#  95% 5000/5268 [04:43<00:13, 20.03it/s][INFO|trainer.py:2881] 2023-11-05 05:29:32,244 >> Saving model checkpoint to /tmp/test-ner/checkpoint-5000
# [INFO|configuration_utils.py:461] 2023-11-05 05:29:32,245 >> Configuration saved in /tmp/test-ner/checkpoint-5000/config.json
# [INFO|modeling_utils.py:2193] 2023-11-05 05:29:33,460 >> Model weights saved in /tmp/test-ner/checkpoint-5000/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2428] 2023-11-05 05:29:33,461 >> tokenizer config file saved in /tmp/test-ner/checkpoint-5000/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2437] 2023-11-05 05:29:33,462 >> Special tokens file saved in /tmp/test-ner/checkpoint-5000/special_tokens_map.json
# 100% 5266/5268 [04:59<00:00, 20.49it/s][INFO|trainer.py:1955] 2023-11-05 05:29:48,888 >>
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# {'train_runtime': 300.0103, 'train_samples_per_second': 140.405, 'train_steps_per_second': 17.559, 'train_loss': 0.144684928062746, 'epoch': 3.0}
# 100% 5268/5268 [05:00<00:00, 17.56it/s]
# [INFO|trainer.py:2881] 2023-11-05 05:29:48,896 >> Saving model checkpoint to /tmp/test-ner
# [INFO|configuration_utils.py:461] 2023-11-05 05:29:48,897 >> Configuration saved in /tmp/test-ner/config.json
# [INFO|modeling_utils.py:2193] 2023-11-05 05:29:50,088 >> Model weights saved in /tmp/test-ner/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2428] 2023-11-05 05:29:50,089 >> tokenizer config file saved in /tmp/test-ner/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2437] 2023-11-05 05:29:50,089 >> Special tokens file saved in /tmp/test-ner/special_tokens_map.json
# ***** train metrics *****
#   epoch                    =        3.0
#   train_loss               =     0.1447
#   train_runtime            = 0:05:00.01
#   train_samples            =      14041
#   train_samples_per_second =    140.405
#   train_steps_per_second   =     17.559
# 11/05/2023 05:29:50 - INFO - __main__ - *** Evaluate ***
# [INFO|trainer.py:738] 2023-11-05 05:29:50,160 >> The following columns in the evaluation set don't have a corresponding argument in `BertForTokenClassification.forward` and have been ignored: id, tokens, ner_tags. If id, tokens, ner_tags are not expected by `BertForTokenClassification.forward`,  you can safely ignore this message.
# [INFO|trainer.py:3158] 2023-11-05 05:29:50,163 >> ***** Running Evaluation *****
# [INFO|trainer.py:3160] 2023-11-05 05:29:50,163 >>   Num examples = 3250
# [INFO|trainer.py:3163] 2023-11-05 05:29:50,163 >>   Batch size = 8
# 100% 407/407 [00:06<00:00, 58.16it/s]
# ***** eval metrics *****
#   epoch                   =        3.0
#   eval_accuracy           =     0.9583
#   eval_f1                 =     0.7724
#   eval_loss               =     0.1625
#   eval_precision          =     0.7985
#   eval_recall             =     0.7479
#   eval_runtime            = 0:00:07.02
#   eval_samples            =       3250
#   eval_samples_per_second =    462.808
#   eval_steps_per_second   =     57.958
