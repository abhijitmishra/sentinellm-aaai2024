# %%
# !wget https://raw.githubusercontent.com/huggingface/transformers/main/examples/pytorch/token-classification/requirements.txt
# !pip install transformers
# !pip install -r requirements.txt
# Out:
# --2023-12-19 00:45:14--  https://raw.githubusercontent.com/huggingface/transformers/main/examples/pytorch/token-classification/requirements.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 68 [text/plain]
# Saving to: ‘requirements.txt’
#
# requirements.txt    100%[===================>]      68  --.-KB/s    in 0s
#
# 2023-12-19 00:45:15 (6.50 MB/s) - ‘requirements.txt’ saved [68/68]
#
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.11.17)
# Collecting accelerate>=0.12.0 (from -r requirements.txt (line 1))
#   Downloading accelerate-0.25.0-py3-none-any.whl (265 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.7/265.7 kB 5.0 MB/s eta 0:00:00
# Collecting seqeval (from -r requirements.txt (line 2))
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 6.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting datasets>=1.8.0 (from -r requirements.txt (line 3))
#   Downloading datasets-2.15.0-py3-none-any.whl (521 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 13.3 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.3 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 4)) (2.1.0+cu121)
# Collecting evaluate (from -r requirements.txt (line 5))
#   Downloading evaluate-0.4.1-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 7.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.12.0->-r requirements.txt (line 1)) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.12.0->-r requirements.txt (line 1)) (23.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.12.0->-r requirements.txt (line 1)) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.12.0->-r requirements.txt (line 1)) (6.0.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.12.0->-r requirements.txt (line 1)) (0.19.4)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.12.0->-r requirements.txt (line 1)) (0.4.1)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.10/dist-packages (from seqeval->-r requirements.txt (line 2)) (1.2.2)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=1.8.0->-r requirements.txt (line 3)) (10.0.1)
# Collecting pyarrow-hotfix (from datasets>=1.8.0->-r requirements.txt (line 3))
#   Downloading pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Collecting dill<0.3.8,>=0.3.0 (from datasets>=1.8.0->-r requirements.txt (line 3))
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 10.4 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets>=1.8.0->-r requirements.txt (line 3)) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=1.8.0->-r requirements.txt (line 3)) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=1.8.0->-r requirements.txt (line 3)) (4.66.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets>=1.8.0->-r requirements.txt (line 3)) (3.4.1)
# Collecting multiprocess (from datasets>=1.8.0->-r requirements.txt (line 3))
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 11.5 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=1.8.0->-r requirements.txt (line 3)) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=1.8.0->-r requirements.txt (line 3)) (3.9.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->-r requirements.txt (line 4)) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->-r requirements.txt (line 4)) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->-r requirements.txt (line 4)) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->-r requirements.txt (line 4)) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->-r requirements.txt (line 4)) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->-r requirements.txt (line 4)) (2.1.0)
# Collecting responses<0.19 (from evaluate->-r requirements.txt (line 5))
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=1.8.0->-r requirements.txt (line 3)) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=1.8.0->-r requirements.txt (line 3)) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=1.8.0->-r requirements.txt (line 3)) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=1.8.0->-r requirements.txt (line 3)) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=1.8.0->-r requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=1.8.0->-r requirements.txt (line 3)) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=1.8.0->-r requirements.txt (line 3)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=1.8.0->-r requirements.txt (line 3)) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=1.8.0->-r requirements.txt (line 3)) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=1.8.0->-r requirements.txt (line 3)) (2023.11.17)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval->-r requirements.txt (line 2)) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval->-r requirements.txt (line 2)) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval->-r requirements.txt (line 2)) (3.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.3->-r requirements.txt (line 4)) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=1.8.0->-r requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=1.8.0->-r requirements.txt (line 3)) (2023.3.post1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.3->-r requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets>=1.8.0->-r requirements.txt (line 3)) (1.16.0)
# Building wheels for collected packages: seqeval
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16162 sha256=98d5f4f4a90e3962a626655aa12d3293ea6d48ad9d36f1a0f70b901188cb2642
#   Stored in directory: /root/.cache/pip/wheels/1a/67/4a/ad4082dd7dfc30f2abfe4d80a2ed5926a506eb8a972b4767fa
# Successfully built seqeval
# Installing collected packages: pyarrow-hotfix, dill, responses, multiprocess, seqeval, accelerate, datasets, evaluate
# Successfully installed accelerate-0.25.0 datasets-2.15.0 dill-0.3.7 evaluate-0.4.1 multiprocess-0.70.15 pyarrow-hotfix-0.6 responses-0.18.0 seqeval-1.2.2

# %%
# !python run_ner_blake2.py \
  --model_name_or_path "Mingda/bert-base-uncased-blake2-glide3-key-nlp2023-shuffled" \
  --dataset_name conll2003 \
  --output_dir /tmp/test-ner \
  --do_train \
  --do_eval \
  --encryption_key "nlp2023"
# Out:
# 2023-12-19 00:45:37.271190: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-19 00:45:37.271258: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-19 00:45:37.272771: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-19 00:45:38.511002: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 12/19/2023 00:45:42 - WARNING - __main__ - Process rank: 0, device: cuda:0, n_gpu: 1distributed training: False, 16-bits training: False
# 12/19/2023 00:45:42 - INFO - __main__ - Training/evaluation parameters TrainingArguments(
# _n_gpu=1,
# adafactor=False,
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# auto_find_batch_size=False,
# bf16=False,
# bf16_full_eval=False,
# data_seed=None,
# dataloader_drop_last=False,
# dataloader_num_workers=0,
# dataloader_pin_memory=True,
# ddp_backend=None,
# ddp_broadcast_buffers=None,
# ddp_bucket_cap_mb=None,
# ddp_find_unused_parameters=None,
# ddp_timeout=1800,
# debug=[],
# deepspeed=None,
# disable_tqdm=False,
# dispatch_batches=None,
# do_eval=True,
# do_predict=False,
# do_train=True,
# eval_accumulation_steps=None,
# eval_delay=0,
# eval_steps=None,
# evaluation_strategy=no,
# fp16=False,
# fp16_backend=auto,
# fp16_full_eval=False,
# fp16_opt_level=O1,
# fsdp=[],
# fsdp_config={'min_num_params': 0, 'xla': False, 'xla_fsdp_grad_ckpt': False},
# fsdp_min_num_params=0,
# fsdp_transformer_layer_cls_to_wrap=None,
# full_determinism=False,
# gradient_accumulation_steps=1,
# gradient_checkpointing=False,
# gradient_checkpointing_kwargs=None,
# greater_is_better=None,
# group_by_length=False,
# half_precision_backend=auto,
# hub_always_push=False,
# hub_model_id=None,
# hub_private_repo=False,
# hub_strategy=every_save,
# hub_token=<HUB_TOKEN>,
# ignore_data_skip=False,
# include_inputs_for_metrics=False,
# include_tokens_per_second=False,
# jit_mode_eval=False,
# label_names=None,
# label_smoothing_factor=0.0,
# learning_rate=5e-05,
# length_column_name=length,
# load_best_model_at_end=False,
# local_rank=0,
# log_level=passive,
# log_level_replica=warning,
# log_on_each_node=True,
# logging_dir=/tmp/test-ner/runs/Dec19_00-45-42_9b8b0095f98a,
# logging_first_step=False,
# logging_nan_inf_filter=True,
# logging_steps=500,
# logging_strategy=steps,
# lr_scheduler_type=linear,
# max_grad_norm=1.0,
# max_steps=-1,
# metric_for_best_model=None,
# mp_parameters=,
# neftune_noise_alpha=None,
# no_cuda=False,
# num_train_epochs=3.0,
# optim=adamw_torch,
# optim_args=None,
# output_dir=/tmp/test-ner,
# overwrite_output_dir=False,
# past_index=-1,
# per_device_eval_batch_size=8,
# per_device_train_batch_size=8,
# prediction_loss_only=False,
# push_to_hub=False,
# push_to_hub_model_id=None,
# push_to_hub_organization=None,
# push_to_hub_token=<PUSH_TO_HUB_TOKEN>,
# ray_scope=last,
# remove_unused_columns=True,
# report_to=['tensorboard'],
# resume_from_checkpoint=None,
# run_name=/tmp/test-ner,
# save_on_each_node=False,
# save_safetensors=True,
# save_steps=500,
# save_strategy=steps,
# save_total_limit=None,
# seed=42,
# skip_memory_metrics=True,
# split_batches=False,
# tf32=None,
# torch_compile=False,
# torch_compile_backend=None,
# torch_compile_mode=None,
# torchdynamo=None,
# tpu_metrics_debug=False,
# tpu_num_cores=None,
# use_cpu=False,
# use_ipex=False,
# use_legacy_prediction_loop=False,
# use_mps_device=False,
# warmup_ratio=0.0,
# warmup_steps=0,
# weight_decay=0.0,
# )
# https://huggingface.co/datasets/conll2003/resolve/main/conll2003.py not found in cache or force_download set to True, downloading to /root/.cache/huggingface/datasets/downloads/d7558e235cee5af4db0a50473ccef8d70162b270d6e671c2a5205a8f1de14b53.9bcb9718b6b76d5ee602f4d53839479aa3971baeda7c2827bc79241c26145249.py.incomplete
# 12/19/2023 00:45:43 - INFO - datasets.utils.file_utils - https://huggingface.co/datasets/conll2003/resolve/main/conll2003.py not found in cache or force_download set to True, downloading to /root/.cache/huggingface/datasets/downloads/d7558e235cee5af4db0a50473ccef8d70162b270d6e671c2a5205a8f1de14b53.9bcb9718b6b76d5ee602f4d53839479aa3971baeda7c2827bc79241c26145249.py.incomplete
# Downloading builder script: 100% 9.57k/9.57k [00:00<00:00, 26.3MB/s]
# storing https://huggingface.co/datasets/conll2003/resolve/main/conll2003.py in cache at /root/.cache/huggingface/datasets/downloads/d7558e235cee5af4db0a50473ccef8d70162b270d6e671c2a5205a8f1de14b53.9bcb9718b6b76d5ee602f4d53839479aa3971baeda7c2827bc79241c26145249.py
# 12/19/2023 00:45:43 - INFO - datasets.utils.file_utils - storing https://huggingface.co/datasets/conll2003/resolve/main/conll2003.py in cache at /root/.cache/huggingface/datasets/downloads/d7558e235cee5af4db0a50473ccef8d70162b270d6e671c2a5205a8f1de14b53.9bcb9718b6b76d5ee602f4d53839479aa3971baeda7c2827bc79241c26145249.py
# creating metadata file for /root/.cache/huggingface/datasets/downloads/d7558e235cee5af4db0a50473ccef8d70162b270d6e671c2a5205a8f1de14b53.9bcb9718b6b76d5ee602f4d53839479aa3971baeda7c2827bc79241c26145249.py
# 12/19/2023 00:45:43 - INFO - datasets.utils.file_utils - creating metadata file for /root/.cache/huggingface/datasets/downloads/d7558e235cee5af4db0a50473ccef8d70162b270d6e671c2a5205a8f1de14b53.9bcb9718b6b76d5ee602f4d53839479aa3971baeda7c2827bc79241c26145249.py
# https://huggingface.co/datasets/conll2003/resolve/main/dataset_infos.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/datasets/downloads/1aa56477291a5f0cf65e25039d68d000083ad6c54c028aad28801e736e262efe.1a76e8cb82f6f942d6a6e5c3e10ee057896e597cfc3b17a277263e8e74ea36c1.incomplete
# 12/19/2023 00:45:43 - INFO - datasets.utils.file_utils - https://huggingface.co/datasets/conll2003/resolve/main/dataset_infos.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/datasets/downloads/1aa56477291a5f0cf65e25039d68d000083ad6c54c028aad28801e736e262efe.1a76e8cb82f6f942d6a6e5c3e10ee057896e597cfc3b17a277263e8e74ea36c1.incomplete
# Downloading metadata: 100% 3.73k/3.73k [00:00<00:00, 19.4MB/s]
# storing https://huggingface.co/datasets/conll2003/resolve/main/dataset_infos.json in cache at /root/.cache/huggingface/datasets/downloads/1aa56477291a5f0cf65e25039d68d000083ad6c54c028aad28801e736e262efe.1a76e8cb82f6f942d6a6e5c3e10ee057896e597cfc3b17a277263e8e74ea36c1
# 12/19/2023 00:45:43 - INFO - datasets.utils.file_utils - storing https://huggingface.co/datasets/conll2003/resolve/main/dataset_infos.json in cache at /root/.cache/huggingface/datasets/downloads/1aa56477291a5f0cf65e25039d68d000083ad6c54c028aad28801e736e262efe.1a76e8cb82f6f942d6a6e5c3e10ee057896e597cfc3b17a277263e8e74ea36c1
# creating metadata file for /root/.cache/huggingface/datasets/downloads/1aa56477291a5f0cf65e25039d68d000083ad6c54c028aad28801e736e262efe.1a76e8cb82f6f942d6a6e5c3e10ee057896e597cfc3b17a277263e8e74ea36c1
# 12/19/2023 00:45:43 - INFO - datasets.utils.file_utils - creating metadata file for /root/.cache/huggingface/datasets/downloads/1aa56477291a5f0cf65e25039d68d000083ad6c54c028aad28801e736e262efe.1a76e8cb82f6f942d6a6e5c3e10ee057896e597cfc3b17a277263e8e74ea36c1
# https://huggingface.co/datasets/conll2003/resolve/main/README.md not found in cache or force_download set to True, downloading to /root/.cache/huggingface/datasets/downloads/500e6d1b368aa0498ccd42c64eb78b7f77953e9fe606405b6f8b1657d2e1d182.eaaeb8a259455796e48d9bf524af0926c136fbb04f37c382a053ebd8e054fa35.incomplete
# 12/19/2023 00:45:44 - INFO - datasets.utils.file_utils - https://huggingface.co/datasets/conll2003/resolve/main/README.md not found in cache or force_download set to True, downloading to /root/.cache/huggingface/datasets/downloads/500e6d1b368aa0498ccd42c64eb78b7f77953e9fe606405b6f8b1657d2e1d182.eaaeb8a259455796e48d9bf524af0926c136fbb04f37c382a053ebd8e054fa35.incomplete
# Downloading readme: 100% 12.3k/12.3k [00:00<00:00, 30.3MB/s]
# storing https://huggingface.co/datasets/conll2003/resolve/main/README.md in cache at /root/.cache/huggingface/datasets/downloads/500e6d1b368aa0498ccd42c64eb78b7f77953e9fe606405b6f8b1657d2e1d182.eaaeb8a259455796e48d9bf524af0926c136fbb04f37c382a053ebd8e054fa35
# 12/19/2023 00:45:44 - INFO - datasets.utils.file_utils - storing https://huggingface.co/datasets/conll2003/resolve/main/README.md in cache at /root/.cache/huggingface/datasets/downloads/500e6d1b368aa0498ccd42c64eb78b7f77953e9fe606405b6f8b1657d2e1d182.eaaeb8a259455796e48d9bf524af0926c136fbb04f37c382a053ebd8e054fa35
# creating metadata file for /root/.cache/huggingface/datasets/downloads/500e6d1b368aa0498ccd42c64eb78b7f77953e9fe606405b6f8b1657d2e1d182.eaaeb8a259455796e48d9bf524af0926c136fbb04f37c382a053ebd8e054fa35
# 12/19/2023 00:45:44 - INFO - datasets.utils.file_utils - creating metadata file for /root/.cache/huggingface/datasets/downloads/500e6d1b368aa0498ccd42c64eb78b7f77953e9fe606405b6f8b1657d2e1d182.eaaeb8a259455796e48d9bf524af0926c136fbb04f37c382a053ebd8e054fa35
# No config specified, defaulting to the single config: conll2003/conll2003
# 12/19/2023 00:45:44 - INFO - datasets.builder - No config specified, defaulting to the single config: conll2003/conll2003
# Loading Dataset Infos from /root/.cache/huggingface/modules/datasets_modules/datasets/conll2003/9a4d16a94f8674ba3466315300359b0acd891b68b6c8743ddf60b9c702adce98
# 12/19/2023 00:45:44 - INFO - datasets.info - Loading Dataset Infos from /root/.cache/huggingface/modules/datasets_modules/datasets/conll2003/9a4d16a94f8674ba3466315300359b0acd891b68b6c8743ddf60b9c702adce98
# Generating dataset conll2003 (/root/.cache/huggingface/datasets/conll2003/conll2003/1.0.0/9a4d16a94f8674ba3466315300359b0acd891b68b6c8743ddf60b9c702adce98)
# 12/19/2023 00:45:44 - INFO - datasets.builder - Generating dataset conll2003 (/root/.cache/huggingface/datasets/conll2003/conll2003/1.0.0/9a4d16a94f8674ba3466315300359b0acd891b68b6c8743ddf60b9c702adce98)
# Downloading and preparing dataset conll2003/conll2003 to /root/.cache/huggingface/datasets/conll2003/conll2003/1.0.0/9a4d16a94f8674ba3466315300359b0acd891b68b6c8743ddf60b9c702adce98...
# 12/19/2023 00:45:44 - INFO - datasets.builder - Downloading and preparing dataset conll2003/conll2003 to /root/.cache/huggingface/datasets/conll2003/conll2003/1.0.0/9a4d16a94f8674ba3466315300359b0acd891b68b6c8743ddf60b9c702adce98...
# Dataset not on Hf google storage. Downloading and preparing it from source
# 12/19/2023 00:45:45 - INFO - datasets.builder - Dataset not on Hf google storage. Downloading and preparing it from source
# https://data.deepai.org/conll2003.zip not found in cache or force_download set to True, downloading to /root/.cache/huggingface/datasets/downloads/2993ad73bf341ce483f06d7cab237d62db303b00ad5086eef4e64f52b84123f6.incomplete
# 12/19/2023 00:45:45 - INFO - datasets.utils.file_utils - https://data.deepai.org/conll2003.zip not found in cache or force_download set to True, downloading to /root/.cache/huggingface/datasets/downloads/2993ad73bf341ce483f06d7cab237d62db303b00ad5086eef4e64f52b84123f6.incomplete
# Downloading data: 100% 983k/983k [00:00<00:00, 5.87MB/s]
# storing https://data.deepai.org/conll2003.zip in cache at /root/.cache/huggingface/datasets/downloads/2993ad73bf341ce483f06d7cab237d62db303b00ad5086eef4e64f52b84123f6
# 12/19/2023 00:45:45 - INFO - datasets.utils.file_utils - storing https://data.deepai.org/conll2003.zip in cache at /root/.cache/huggingface/datasets/downloads/2993ad73bf341ce483f06d7cab237d62db303b00ad5086eef4e64f52b84123f6
# creating metadata file for /root/.cache/huggingface/datasets/downloads/2993ad73bf341ce483f06d7cab237d62db303b00ad5086eef4e64f52b84123f6
# 12/19/2023 00:45:45 - INFO - datasets.utils.file_utils - creating metadata file for /root/.cache/huggingface/datasets/downloads/2993ad73bf341ce483f06d7cab237d62db303b00ad5086eef4e64f52b84123f6
# Downloading took 0.0 min
# 12/19/2023 00:45:45 - INFO - datasets.download.download_manager - Downloading took 0.0 min
# Checksum Computation took 0.0 min
# 12/19/2023 00:45:45 - INFO - datasets.download.download_manager - Checksum Computation took 0.0 min
# Generating train split
# 12/19/2023 00:45:45 - INFO - datasets.builder - Generating train split
# Generating train split: 100% 14041/14041 [00:02<00:00, 4869.08 examples/s]
# Generating validation split
# 12/19/2023 00:45:48 - INFO - datasets.builder - Generating validation split
# Generating validation split: 100% 3250/3250 [00:00<00:00, 4629.06 examples/s]
# Generating test split
# 12/19/2023 00:45:49 - INFO - datasets.builder - Generating test split
# Generating test split: 100% 3453/3453 [00:00<00:00, 5033.68 examples/s]
# All the splits matched successfully.
# 12/19/2023 00:45:49 - INFO - datasets.utils.info_utils - All the splits matched successfully.
# Dataset conll2003 downloaded and prepared to /root/.cache/huggingface/datasets/conll2003/conll2003/1.0.0/9a4d16a94f8674ba3466315300359b0acd891b68b6c8743ddf60b9c702adce98. Subsequent calls will reuse this data.
# 12/19/2023 00:45:49 - INFO - datasets.builder - Dataset conll2003 downloaded and prepared to /root/.cache/huggingface/datasets/conll2003/conll2003/1.0.0/9a4d16a94f8674ba3466315300359b0acd891b68b6c8743ddf60b9c702adce98. Subsequent calls will reuse this data.
# config.json: 100% 658/658 [00:00<00:00, 3.57MB/s]
# [INFO|configuration_utils.py:717] 2023-12-19 00:45:50,179 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--Mingda--bert-base-uncased-blake2-glide3-key-nlp2023-shuffled/snapshots/b193fc0e32d8a8c29b328f258a12ebd4933d1b88/config.json
# [INFO|configuration_utils.py:777] 2023-12-19 00:45:50,188 >> Model config BertConfig {
#   "_name_or_path": "Mingda/bert-base-uncased-blake2-glide3-key-nlp2023-shuffled",
#   "architectures": [
#     "BertModel"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "finetuning_task": "ner",
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2",
#     "3": "LABEL_3",
#     "4": "LABEL_4",
#     "5": "LABEL_5",
#     "6": "LABEL_6",
#     "7": "LABEL_7",
#     "8": "LABEL_8"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_2": 2,
#     "LABEL_3": 3,
#     "LABEL_4": 4,
#     "LABEL_5": 5,
#     "LABEL_6": 6,
#     "LABEL_7": 7,
#     "LABEL_8": 8
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "torch_dtype": "float64",
#   "transformers_version": "4.35.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# tokenizer_config.json: 100% 314/314 [00:00<00:00, 1.56MB/s]
# vocab.txt: 100% 1.01M/1.01M [00:00<00:00, 3.05MB/s]
# tokenizer.json: 100% 1.49M/1.49M [00:00<00:00, 3.63MB/s]
# special_tokens_map.json: 100% 125/125 [00:00<00:00, 633kB/s]
# [INFO|tokenization_utils_base.py:2022] 2023-12-19 00:45:52,053 >> loading file vocab.txt from cache at /root/.cache/huggingface/hub/models--Mingda--bert-base-uncased-blake2-glide3-key-nlp2023-shuffled/snapshots/b193fc0e32d8a8c29b328f258a12ebd4933d1b88/vocab.txt
# [INFO|tokenization_utils_base.py:2022] 2023-12-19 00:45:52,053 >> loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--Mingda--bert-base-uncased-blake2-glide3-key-nlp2023-shuffled/snapshots/b193fc0e32d8a8c29b328f258a12ebd4933d1b88/tokenizer.json
# [INFO|tokenization_utils_base.py:2022] 2023-12-19 00:45:52,053 >> loading file added_tokens.json from cache at None
# [INFO|tokenization_utils_base.py:2022] 2023-12-19 00:45:52,053 >> loading file special_tokens_map.json from cache at /root/.cache/huggingface/hub/models--Mingda--bert-base-uncased-blake2-glide3-key-nlp2023-shuffled/snapshots/b193fc0e32d8a8c29b328f258a12ebd4933d1b88/special_tokens_map.json
# [INFO|tokenization_utils_base.py:2022] 2023-12-19 00:45:52,054 >> loading file tokenizer_config.json from cache at /root/.cache/huggingface/hub/models--Mingda--bert-base-uncased-blake2-glide3-key-nlp2023-shuffled/snapshots/b193fc0e32d8a8c29b328f258a12ebd4933d1b88/tokenizer_config.json
# tokenizer_config.json: 100% 28.0/28.0 [00:00<00:00, 149kB/s]
# config.json: 100% 570/570 [00:00<00:00, 2.88MB/s]
# [INFO|configuration_utils.py:717] 2023-12-19 00:45:52,503 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--bert-base-uncased/snapshots/1dbc166cf8765166998eff31ade2eb64c8a40076/config.json
# [INFO|configuration_utils.py:777] 2023-12-19 00:45:52,504 >> Model config BertConfig {
#   "_name_or_path": "bert-base-uncased",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.35.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# vocab.txt: 100% 232k/232k [00:00<00:00, 1.42MB/s]
# tokenizer.json: 100% 466k/466k [00:00<00:00, 1.93MB/s]
# [INFO|tokenization_utils_base.py:2022] 2023-12-19 00:45:53,536 >> loading file vocab.txt from cache at /root/.cache/huggingface/hub/models--bert-base-uncased/snapshots/1dbc166cf8765166998eff31ade2eb64c8a40076/vocab.txt
# [INFO|tokenization_utils_base.py:2022] 2023-12-19 00:45:53,536 >> loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--bert-base-uncased/snapshots/1dbc166cf8765166998eff31ade2eb64c8a40076/tokenizer.json
# [INFO|tokenization_utils_base.py:2022] 2023-12-19 00:45:53,536 >> loading file added_tokens.json from cache at None
# [INFO|tokenization_utils_base.py:2022] 2023-12-19 00:45:53,536 >> loading file special_tokens_map.json from cache at None
# [INFO|tokenization_utils_base.py:2022] 2023-12-19 00:45:53,536 >> loading file tokenizer_config.json from cache at /root/.cache/huggingface/hub/models--bert-base-uncased/snapshots/1dbc166cf8765166998eff31ade2eb64c8a40076/tokenizer_config.json
# [INFO|configuration_utils.py:717] 2023-12-19 00:45:53,536 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--bert-base-uncased/snapshots/1dbc166cf8765166998eff31ade2eb64c8a40076/config.json
# [INFO|configuration_utils.py:777] 2023-12-19 00:45:53,537 >> Model config BertConfig {
#   "_name_or_path": "bert-base-uncased",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.35.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# pytorch_model.bin: 100% 532M/532M [00:01<00:00, 351MB/s]
# [INFO|modeling_utils.py:3121] 2023-12-19 00:45:55,732 >> loading weights file pytorch_model.bin from cache at /root/.cache/huggingface/hub/models--Mingda--bert-base-uncased-blake2-glide3-key-nlp2023-shuffled/snapshots/b193fc0e32d8a8c29b328f258a12ebd4933d1b88/pytorch_model.bin
# [INFO|modeling_utils.py:3940] 2023-12-19 00:45:57,113 >> Some weights of the model checkpoint at Mingda/bert-base-uncased-blake2-glide3-key-nlp2023-shuffled were not used when initializing BertForTokenClassification: ['pooler.dense.bias', 'pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# [WARNING|modeling_utils.py:3952] 2023-12-19 00:45:57,113 >> Some weights of BertForTokenClassification were not initialized from the model checkpoint at Mingda/bert-base-uncased-blake2-glide3-key-nlp2023-shuffled and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Running tokenizer on train dataset:   0% 0/14041 [00:00<?, ? examples/s]Caching processed dataset at /root/.cache/huggingface/datasets/conll2003/conll2003/1.0.0/9a4d16a94f8674ba3466315300359b0acd891b68b6c8743ddf60b9c702adce98/cache-26ce959c7e0f00fb.arrow
# 12/19/2023 00:45:57 - INFO - datasets.arrow_dataset - Caching processed dataset at /root/.cache/huggingface/datasets/conll2003/conll2003/1.0.0/9a4d16a94f8674ba3466315300359b0acd891b68b6c8743ddf60b9c702adce98/cache-26ce959c7e0f00fb.arrow
# Running tokenizer on train dataset: 100% 14041/14041 [00:05<00:00, 2657.58 examples/s]
# Running tokenizer on validation dataset:   0% 0/3250 [00:00<?, ? examples/s]Caching processed dataset at /root/.cache/huggingface/datasets/conll2003/conll2003/1.0.0/9a4d16a94f8674ba3466315300359b0acd891b68b6c8743ddf60b9c702adce98/cache-09e54c402e17b1d4.arrow
# 12/19/2023 00:46:02 - INFO - datasets.arrow_dataset - Caching processed dataset at /root/.cache/huggingface/datasets/conll2003/conll2003/1.0.0/9a4d16a94f8674ba3466315300359b0acd891b68b6c8743ddf60b9c702adce98/cache-09e54c402e17b1d4.arrow
# Running tokenizer on validation dataset: 100% 3250/3250 [00:01<00:00, 2468.37 examples/s]
# Downloading builder script: 100% 6.34k/6.34k [00:00<00:00, 21.8MB/s]
# [INFO|trainer.py:738] 2023-12-19 00:46:05,403 >> The following columns in the training set don't have a corresponding argument in `BertForTokenClassification.forward` and have been ignored: id, chunk_tags, pos_tags, ner_tags, tokens. If id, chunk_tags, pos_tags, ner_tags, tokens are not expected by `BertForTokenClassification.forward`,  you can safely ignore this message.
# [INFO|trainer.py:1723] 2023-12-19 00:46:05,413 >> ***** Running training *****
# [INFO|trainer.py:1724] 2023-12-19 00:46:05,414 >>   Num examples = 14,041
# [INFO|trainer.py:1725] 2023-12-19 00:46:05,414 >>   Num Epochs = 3
# [INFO|trainer.py:1726] 2023-12-19 00:46:05,414 >>   Instantaneous batch size per device = 8
# [INFO|trainer.py:1729] 2023-12-19 00:46:05,414 >>   Total train batch size (w. parallel, distributed & accumulation) = 8
# [INFO|trainer.py:1730] 2023-12-19 00:46:05,414 >>   Gradient Accumulation steps = 1
# [INFO|trainer.py:1731] 2023-12-19 00:46:05,414 >>   Total optimization steps = 5,268
# [INFO|trainer.py:1732] 2023-12-19 00:46:05,414 >>   Number of trainable parameters = 108,898,569
#   0% 0/5268 [00:00<?, ?it/s][WARNING|logging.py:314] 2023-12-19 00:46:05,428 >> You're using a BertTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# {'loss': 0.1652, 'learning_rate': 4.525436598329537e-05, 'epoch': 0.28}
#   9% 500/5268 [00:23<03:28, 22.83it/s][INFO|trainer.py:2881] 2023-12-19 00:46:29,304 >> Saving model checkpoint to /tmp/test-ner/checkpoint-500
# [INFO|configuration_utils.py:461] 2023-12-19 00:46:29,305 >> Configuration saved in /tmp/test-ner/checkpoint-500/config.json
# [INFO|modeling_utils.py:2193] 2023-12-19 00:46:29,997 >> Model weights saved in /tmp/test-ner/checkpoint-500/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2428] 2023-12-19 00:46:29,998 >> tokenizer config file saved in /tmp/test-ner/checkpoint-500/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2437] 2023-12-19 00:46:29,998 >> Special tokens file saved in /tmp/test-ner/checkpoint-500/special_tokens_map.json
# {'loss': 0.0761, 'learning_rate': 4.050873196659074e-05, 'epoch': 0.57}
#  19% 1000/5268 [00:48<03:08, 22.68it/s][INFO|trainer.py:2881] 2023-12-19 00:46:53,633 >> Saving model checkpoint to /tmp/test-ner/checkpoint-1000
# [INFO|configuration_utils.py:461] 2023-12-19 00:46:53,634 >> Configuration saved in /tmp/test-ner/checkpoint-1000/config.json
# [INFO|modeling_utils.py:2193] 2023-12-19 00:46:54,324 >> Model weights saved in /tmp/test-ner/checkpoint-1000/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2428] 2023-12-19 00:46:54,325 >> tokenizer config file saved in /tmp/test-ner/checkpoint-1000/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2437] 2023-12-19 00:46:54,325 >> Special tokens file saved in /tmp/test-ner/checkpoint-1000/special_tokens_map.json
# {'loss': 0.0646, 'learning_rate': 3.5763097949886106e-05, 'epoch': 0.85}
#  28% 1500/5268 [01:12<02:46, 22.60it/s][INFO|trainer.py:2881] 2023-12-19 00:47:17,546 >> Saving model checkpoint to /tmp/test-ner/checkpoint-1500
# [INFO|configuration_utils.py:461] 2023-12-19 00:47:17,547 >> Configuration saved in /tmp/test-ner/checkpoint-1500/config.json
# [INFO|modeling_utils.py:2193] 2023-12-19 00:47:18,223 >> Model weights saved in /tmp/test-ner/checkpoint-1500/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2428] 2023-12-19 00:47:18,224 >> tokenizer config file saved in /tmp/test-ner/checkpoint-1500/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2437] 2023-12-19 00:47:18,224 >> Special tokens file saved in /tmp/test-ner/checkpoint-1500/special_tokens_map.json
# {'loss': 0.0454, 'learning_rate': 3.1017463933181475e-05, 'epoch': 1.14}
#  38% 2000/5268 [01:36<02:25, 22.44it/s][INFO|trainer.py:2881] 2023-12-19 00:47:41,815 >> Saving model checkpoint to /tmp/test-ner/checkpoint-2000
# [INFO|configuration_utils.py:461] 2023-12-19 00:47:41,816 >> Configuration saved in /tmp/test-ner/checkpoint-2000/config.json
# [INFO|modeling_utils.py:2193] 2023-12-19 00:47:42,504 >> Model weights saved in /tmp/test-ner/checkpoint-2000/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2428] 2023-12-19 00:47:42,504 >> tokenizer config file saved in /tmp/test-ner/checkpoint-2000/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2437] 2023-12-19 00:47:42,505 >> Special tokens file saved in /tmp/test-ner/checkpoint-2000/special_tokens_map.json
# {'loss': 0.0329, 'learning_rate': 2.6271829916476843e-05, 'epoch': 1.42}
#  47% 2500/5268 [02:00<02:01, 22.80it/s][INFO|trainer.py:2881] 2023-12-19 00:48:06,056 >> Saving model checkpoint to /tmp/test-ner/checkpoint-2500
# [INFO|configuration_utils.py:461] 2023-12-19 00:48:06,057 >> Configuration saved in /tmp/test-ner/checkpoint-2500/config.json
# [INFO|modeling_utils.py:2193] 2023-12-19 00:48:06,739 >> Model weights saved in /tmp/test-ner/checkpoint-2500/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2428] 2023-12-19 00:48:06,740 >> tokenizer config file saved in /tmp/test-ner/checkpoint-2500/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2437] 2023-12-19 00:48:06,740 >> Special tokens file saved in /tmp/test-ner/checkpoint-2500/special_tokens_map.json
# {'loss': 0.0295, 'learning_rate': 2.152619589977221e-05, 'epoch': 1.71}
#  57% 3000/5268 [02:25<01:42, 22.07it/s][INFO|trainer.py:2881] 2023-12-19 00:48:30,687 >> Saving model checkpoint to /tmp/test-ner/checkpoint-3000
# [INFO|configuration_utils.py:461] 2023-12-19 00:48:30,688 >> Configuration saved in /tmp/test-ner/checkpoint-3000/config.json
# [INFO|modeling_utils.py:2193] 2023-12-19 00:48:31,397 >> Model weights saved in /tmp/test-ner/checkpoint-3000/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2428] 2023-12-19 00:48:31,398 >> tokenizer config file saved in /tmp/test-ner/checkpoint-3000/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2437] 2023-12-19 00:48:31,399 >> Special tokens file saved in /tmp/test-ner/checkpoint-3000/special_tokens_map.json
# {'loss': 0.027, 'learning_rate': 1.678056188306758e-05, 'epoch': 1.99}
#  66% 3500/5268 [02:49<01:22, 21.31it/s][INFO|trainer.py:2881] 2023-12-19 00:48:55,344 >> Saving model checkpoint to /tmp/test-ner/checkpoint-3500
# [INFO|configuration_utils.py:461] 2023-12-19 00:48:55,345 >> Configuration saved in /tmp/test-ner/checkpoint-3500/config.json
# [INFO|modeling_utils.py:2193] 2023-12-19 00:48:56,037 >> Model weights saved in /tmp/test-ner/checkpoint-3500/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2428] 2023-12-19 00:48:56,038 >> tokenizer config file saved in /tmp/test-ner/checkpoint-3500/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2437] 2023-12-19 00:48:56,038 >> Special tokens file saved in /tmp/test-ner/checkpoint-3500/special_tokens_map.json
# {'loss': 0.012, 'learning_rate': 1.2034927866362947e-05, 'epoch': 2.28}
#  76% 4000/5268 [03:14<00:56, 22.58it/s][INFO|trainer.py:2881] 2023-12-19 00:49:20,228 >> Saving model checkpoint to /tmp/test-ner/checkpoint-4000
# [INFO|configuration_utils.py:461] 2023-12-19 00:49:20,229 >> Configuration saved in /tmp/test-ner/checkpoint-4000/config.json
# [INFO|modeling_utils.py:2193] 2023-12-19 00:49:20,931 >> Model weights saved in /tmp/test-ner/checkpoint-4000/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2428] 2023-12-19 00:49:20,932 >> tokenizer config file saved in /tmp/test-ner/checkpoint-4000/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2437] 2023-12-19 00:49:20,932 >> Special tokens file saved in /tmp/test-ner/checkpoint-4000/special_tokens_map.json
# {'loss': 0.0117, 'learning_rate': 7.289293849658315e-06, 'epoch': 2.56}
#  85% 4500/5268 [03:38<00:32, 23.96it/s][INFO|trainer.py:2881] 2023-12-19 00:49:44,111 >> Saving model checkpoint to /tmp/test-ner/checkpoint-4500
# [INFO|configuration_utils.py:461] 2023-12-19 00:49:44,112 >> Configuration saved in /tmp/test-ner/checkpoint-4500/config.json
# [INFO|modeling_utils.py:2193] 2023-12-19 00:49:44,775 >> Model weights saved in /tmp/test-ner/checkpoint-4500/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2428] 2023-12-19 00:49:44,776 >> tokenizer config file saved in /tmp/test-ner/checkpoint-4500/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2437] 2023-12-19 00:49:44,776 >> Special tokens file saved in /tmp/test-ner/checkpoint-4500/special_tokens_map.json
# {'loss': 0.0138, 'learning_rate': 2.5436598329536827e-06, 'epoch': 2.85}
#  95% 5000/5268 [04:02<00:11, 22.45it/s][INFO|trainer.py:2881] 2023-12-19 00:50:08,108 >> Saving model checkpoint to /tmp/test-ner/checkpoint-5000
# [INFO|configuration_utils.py:461] 2023-12-19 00:50:08,109 >> Configuration saved in /tmp/test-ner/checkpoint-5000/config.json
# [INFO|modeling_utils.py:2193] 2023-12-19 00:50:08,795 >> Model weights saved in /tmp/test-ner/checkpoint-5000/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2428] 2023-12-19 00:50:08,796 >> tokenizer config file saved in /tmp/test-ner/checkpoint-5000/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2437] 2023-12-19 00:50:08,796 >> Special tokens file saved in /tmp/test-ner/checkpoint-5000/special_tokens_map.json
# 100% 5266/5268 [04:16<00:00, 22.17it/s][INFO|trainer.py:1955] 2023-12-19 00:50:21,923 >>
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# {'train_runtime': 256.5138, 'train_samples_per_second': 164.213, 'train_steps_per_second': 20.537, 'train_loss': 0.04587086507924688, 'epoch': 3.0}
# 100% 5268/5268 [04:16<00:00, 20.54it/s]
# [INFO|trainer.py:2881] 2023-12-19 00:50:21,930 >> Saving model checkpoint to /tmp/test-ner
# [INFO|configuration_utils.py:461] 2023-12-19 00:50:21,931 >> Configuration saved in /tmp/test-ner/config.json
# [INFO|modeling_utils.py:2193] 2023-12-19 00:50:22,613 >> Model weights saved in /tmp/test-ner/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2428] 2023-12-19 00:50:22,614 >> tokenizer config file saved in /tmp/test-ner/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2437] 2023-12-19 00:50:22,614 >> Special tokens file saved in /tmp/test-ner/special_tokens_map.json
# ***** train metrics *****
#   epoch                    =        3.0
#   train_loss               =     0.0459
#   train_runtime            = 0:04:16.51
#   train_samples            =      14041
#   train_samples_per_second =    164.213
#   train_steps_per_second   =     20.537
# 12/19/2023 00:50:22 - INFO - __main__ - *** Evaluate ***
# [INFO|trainer.py:738] 2023-12-19 00:50:22,638 >> The following columns in the evaluation set don't have a corresponding argument in `BertForTokenClassification.forward` and have been ignored: id, chunk_tags, pos_tags, ner_tags, tokens. If id, chunk_tags, pos_tags, ner_tags, tokens are not expected by `BertForTokenClassification.forward`,  you can safely ignore this message.
# [INFO|trainer.py:3158] 2023-12-19 00:50:22,640 >> ***** Running Evaluation *****
# [INFO|trainer.py:3160] 2023-12-19 00:50:22,640 >>   Num examples = 3250
# [INFO|trainer.py:3163] 2023-12-19 00:50:22,640 >>   Batch size = 8
# 100% 407/407 [00:06<00:00, 66.81it/s]
# ***** eval metrics *****
#   epoch                   =        3.0
#   eval_accuracy           =     0.9885
#   eval_f1                 =     0.9427
#   eval_loss               =     0.0533
#   eval_precision          =     0.9386
#   eval_recall             =     0.9468
#   eval_runtime            = 0:00:06.11
#   eval_samples            =       3250
#   eval_samples_per_second =    531.499
#   eval_steps_per_second   =      66.56

# %%
import transformers
print(transformers.__version__)
# Out:
# 4.35.2
