# %%
# !wget https://raw.githubusercontent.com/huggingface/transformers/main/examples/pytorch/token-classification/requirements.txt
# !pip install transformers
# !pip install -r requirements.txt
# Out:
# --2023-12-19 00:43:05--  https://raw.githubusercontent.com/huggingface/transformers/main/examples/pytorch/token-classification/requirements.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 68 [text/plain]
# Saving to: ‘requirements.txt’
#
# requirements.txt    100%[===================>]      68  --.-KB/s    in 0s
#
# 2023-12-19 00:43:05 (6.03 MB/s) - ‘requirements.txt’ saved [68/68]
#
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.11.17)
# Collecting accelerate>=0.12.0 (from -r requirements.txt (line 1))
#   Downloading accelerate-0.25.0-py3-none-any.whl (265 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.7/265.7 kB 4.8 MB/s eta 0:00:00
# Collecting seqeval (from -r requirements.txt (line 2))
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 6.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting datasets>=1.8.0 (from -r requirements.txt (line 3))
#   Downloading datasets-2.15.0-py3-none-any.whl (521 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 37.9 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.3 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 4)) (2.1.0+cu121)
# Collecting evaluate (from -r requirements.txt (line 5))
#   Downloading evaluate-0.4.1-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 12.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.12.0->-r requirements.txt (line 1)) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.12.0->-r requirements.txt (line 1)) (23.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.12.0->-r requirements.txt (line 1)) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.12.0->-r requirements.txt (line 1)) (6.0.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.12.0->-r requirements.txt (line 1)) (0.19.4)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.12.0->-r requirements.txt (line 1)) (0.4.1)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.10/dist-packages (from seqeval->-r requirements.txt (line 2)) (1.2.2)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=1.8.0->-r requirements.txt (line 3)) (10.0.1)
# Collecting pyarrow-hotfix (from datasets>=1.8.0->-r requirements.txt (line 3))
#   Downloading pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Collecting dill<0.3.8,>=0.3.0 (from datasets>=1.8.0->-r requirements.txt (line 3))
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 15.9 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets>=1.8.0->-r requirements.txt (line 3)) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=1.8.0->-r requirements.txt (line 3)) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=1.8.0->-r requirements.txt (line 3)) (4.66.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets>=1.8.0->-r requirements.txt (line 3)) (3.4.1)
# Collecting multiprocess (from datasets>=1.8.0->-r requirements.txt (line 3))
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 18.0 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=1.8.0->-r requirements.txt (line 3)) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=1.8.0->-r requirements.txt (line 3)) (3.9.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->-r requirements.txt (line 4)) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->-r requirements.txt (line 4)) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->-r requirements.txt (line 4)) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->-r requirements.txt (line 4)) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->-r requirements.txt (line 4)) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->-r requirements.txt (line 4)) (2.1.0)
# Collecting responses<0.19 (from evaluate->-r requirements.txt (line 5))
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=1.8.0->-r requirements.txt (line 3)) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=1.8.0->-r requirements.txt (line 3)) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=1.8.0->-r requirements.txt (line 3)) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=1.8.0->-r requirements.txt (line 3)) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=1.8.0->-r requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=1.8.0->-r requirements.txt (line 3)) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=1.8.0->-r requirements.txt (line 3)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=1.8.0->-r requirements.txt (line 3)) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=1.8.0->-r requirements.txt (line 3)) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=1.8.0->-r requirements.txt (line 3)) (2023.11.17)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval->-r requirements.txt (line 2)) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval->-r requirements.txt (line 2)) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval->-r requirements.txt (line 2)) (3.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.3->-r requirements.txt (line 4)) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=1.8.0->-r requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=1.8.0->-r requirements.txt (line 3)) (2023.3.post1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.3->-r requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets>=1.8.0->-r requirements.txt (line 3)) (1.16.0)
# Building wheels for collected packages: seqeval
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16162 sha256=37127ef8fd9e29c60300001a77bec4656576cd15222cf961c5fac0558651f114
#   Stored in directory: /root/.cache/pip/wheels/1a/67/4a/ad4082dd7dfc30f2abfe4d80a2ed5926a506eb8a972b4767fa
# Successfully built seqeval
# Installing collected packages: pyarrow-hotfix, dill, responses, multiprocess, seqeval, accelerate, datasets, evaluate
# Successfully installed accelerate-0.25.0 datasets-2.15.0 dill-0.3.7 evaluate-0.4.1 multiprocess-0.70.15 pyarrow-hotfix-0.6 responses-0.18.0 seqeval-1.2.2

# %%
# !python run_ner_blake2.py \
  --model_name_or_path "Mingda/roberta-base-blake2-glide10-key-llm123-shuffled" \
  --dataset_name conll2003 \
  --output_dir /tmp/test-ner \
  --do_train \
  --do_eval \
  --encryption_key "llm123"
# Out:
# 2023-12-19 00:43:26.715760: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-19 00:43:26.715826: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-19 00:43:26.717716: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-19 00:43:27.865573: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 12/19/2023 00:43:31 - WARNING - __main__ - Process rank: 0, device: cuda:0, n_gpu: 1distributed training: False, 16-bits training: False
# 12/19/2023 00:43:31 - INFO - __main__ - Training/evaluation parameters TrainingArguments(
# _n_gpu=1,
# adafactor=False,
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# auto_find_batch_size=False,
# bf16=False,
# bf16_full_eval=False,
# data_seed=None,
# dataloader_drop_last=False,
# dataloader_num_workers=0,
# dataloader_pin_memory=True,
# ddp_backend=None,
# ddp_broadcast_buffers=None,
# ddp_bucket_cap_mb=None,
# ddp_find_unused_parameters=None,
# ddp_timeout=1800,
# debug=[],
# deepspeed=None,
# disable_tqdm=False,
# dispatch_batches=None,
# do_eval=True,
# do_predict=False,
# do_train=True,
# eval_accumulation_steps=None,
# eval_delay=0,
# eval_steps=None,
# evaluation_strategy=no,
# fp16=False,
# fp16_backend=auto,
# fp16_full_eval=False,
# fp16_opt_level=O1,
# fsdp=[],
# fsdp_config={'min_num_params': 0, 'xla': False, 'xla_fsdp_grad_ckpt': False},
# fsdp_min_num_params=0,
# fsdp_transformer_layer_cls_to_wrap=None,
# full_determinism=False,
# gradient_accumulation_steps=1,
# gradient_checkpointing=False,
# gradient_checkpointing_kwargs=None,
# greater_is_better=None,
# group_by_length=False,
# half_precision_backend=auto,
# hub_always_push=False,
# hub_model_id=None,
# hub_private_repo=False,
# hub_strategy=every_save,
# hub_token=<HUB_TOKEN>,
# ignore_data_skip=False,
# include_inputs_for_metrics=False,
# include_tokens_per_second=False,
# jit_mode_eval=False,
# label_names=None,
# label_smoothing_factor=0.0,
# learning_rate=5e-05,
# length_column_name=length,
# load_best_model_at_end=False,
# local_rank=0,
# log_level=passive,
# log_level_replica=warning,
# log_on_each_node=True,
# logging_dir=/tmp/test-ner/runs/Dec19_00-43-31_48a426192aeb,
# logging_first_step=False,
# logging_nan_inf_filter=True,
# logging_steps=500,
# logging_strategy=steps,
# lr_scheduler_type=linear,
# max_grad_norm=1.0,
# max_steps=-1,
# metric_for_best_model=None,
# mp_parameters=,
# neftune_noise_alpha=None,
# no_cuda=False,
# num_train_epochs=3.0,
# optim=adamw_torch,
# optim_args=None,
# output_dir=/tmp/test-ner,
# overwrite_output_dir=False,
# past_index=-1,
# per_device_eval_batch_size=8,
# per_device_train_batch_size=8,
# prediction_loss_only=False,
# push_to_hub=False,
# push_to_hub_model_id=None,
# push_to_hub_organization=None,
# push_to_hub_token=<PUSH_TO_HUB_TOKEN>,
# ray_scope=last,
# remove_unused_columns=True,
# report_to=['tensorboard'],
# resume_from_checkpoint=None,
# run_name=/tmp/test-ner,
# save_on_each_node=False,
# save_safetensors=True,
# save_steps=500,
# save_strategy=steps,
# save_total_limit=None,
# seed=42,
# skip_memory_metrics=True,
# split_batches=False,
# tf32=None,
# torch_compile=False,
# torch_compile_backend=None,
# torch_compile_mode=None,
# torchdynamo=None,
# tpu_metrics_debug=False,
# tpu_num_cores=None,
# use_cpu=False,
# use_ipex=False,
# use_legacy_prediction_loop=False,
# use_mps_device=False,
# warmup_ratio=0.0,
# warmup_steps=0,
# weight_decay=0.0,
# )
# https://huggingface.co/datasets/conll2003/resolve/main/conll2003.py not found in cache or force_download set to True, downloading to /root/.cache/huggingface/datasets/downloads/d7558e235cee5af4db0a50473ccef8d70162b270d6e671c2a5205a8f1de14b53.9bcb9718b6b76d5ee602f4d53839479aa3971baeda7c2827bc79241c26145249.py.incomplete
# 12/19/2023 00:43:33 - INFO - datasets.utils.file_utils - https://huggingface.co/datasets/conll2003/resolve/main/conll2003.py not found in cache or force_download set to True, downloading to /root/.cache/huggingface/datasets/downloads/d7558e235cee5af4db0a50473ccef8d70162b270d6e671c2a5205a8f1de14b53.9bcb9718b6b76d5ee602f4d53839479aa3971baeda7c2827bc79241c26145249.py.incomplete
# Downloading builder script: 100% 9.57k/9.57k [00:00<00:00, 31.0MB/s]
# storing https://huggingface.co/datasets/conll2003/resolve/main/conll2003.py in cache at /root/.cache/huggingface/datasets/downloads/d7558e235cee5af4db0a50473ccef8d70162b270d6e671c2a5205a8f1de14b53.9bcb9718b6b76d5ee602f4d53839479aa3971baeda7c2827bc79241c26145249.py
# 12/19/2023 00:43:33 - INFO - datasets.utils.file_utils - storing https://huggingface.co/datasets/conll2003/resolve/main/conll2003.py in cache at /root/.cache/huggingface/datasets/downloads/d7558e235cee5af4db0a50473ccef8d70162b270d6e671c2a5205a8f1de14b53.9bcb9718b6b76d5ee602f4d53839479aa3971baeda7c2827bc79241c26145249.py
# creating metadata file for /root/.cache/huggingface/datasets/downloads/d7558e235cee5af4db0a50473ccef8d70162b270d6e671c2a5205a8f1de14b53.9bcb9718b6b76d5ee602f4d53839479aa3971baeda7c2827bc79241c26145249.py
# 12/19/2023 00:43:33 - INFO - datasets.utils.file_utils - creating metadata file for /root/.cache/huggingface/datasets/downloads/d7558e235cee5af4db0a50473ccef8d70162b270d6e671c2a5205a8f1de14b53.9bcb9718b6b76d5ee602f4d53839479aa3971baeda7c2827bc79241c26145249.py
# https://huggingface.co/datasets/conll2003/resolve/main/dataset_infos.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/datasets/downloads/1aa56477291a5f0cf65e25039d68d000083ad6c54c028aad28801e736e262efe.1a76e8cb82f6f942d6a6e5c3e10ee057896e597cfc3b17a277263e8e74ea36c1.incomplete
# 12/19/2023 00:43:33 - INFO - datasets.utils.file_utils - https://huggingface.co/datasets/conll2003/resolve/main/dataset_infos.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/datasets/downloads/1aa56477291a5f0cf65e25039d68d000083ad6c54c028aad28801e736e262efe.1a76e8cb82f6f942d6a6e5c3e10ee057896e597cfc3b17a277263e8e74ea36c1.incomplete
# Downloading metadata: 100% 3.73k/3.73k [00:00<00:00, 20.6MB/s]
# storing https://huggingface.co/datasets/conll2003/resolve/main/dataset_infos.json in cache at /root/.cache/huggingface/datasets/downloads/1aa56477291a5f0cf65e25039d68d000083ad6c54c028aad28801e736e262efe.1a76e8cb82f6f942d6a6e5c3e10ee057896e597cfc3b17a277263e8e74ea36c1
# 12/19/2023 00:43:34 - INFO - datasets.utils.file_utils - storing https://huggingface.co/datasets/conll2003/resolve/main/dataset_infos.json in cache at /root/.cache/huggingface/datasets/downloads/1aa56477291a5f0cf65e25039d68d000083ad6c54c028aad28801e736e262efe.1a76e8cb82f6f942d6a6e5c3e10ee057896e597cfc3b17a277263e8e74ea36c1
# creating metadata file for /root/.cache/huggingface/datasets/downloads/1aa56477291a5f0cf65e25039d68d000083ad6c54c028aad28801e736e262efe.1a76e8cb82f6f942d6a6e5c3e10ee057896e597cfc3b17a277263e8e74ea36c1
# 12/19/2023 00:43:34 - INFO - datasets.utils.file_utils - creating metadata file for /root/.cache/huggingface/datasets/downloads/1aa56477291a5f0cf65e25039d68d000083ad6c54c028aad28801e736e262efe.1a76e8cb82f6f942d6a6e5c3e10ee057896e597cfc3b17a277263e8e74ea36c1
# https://huggingface.co/datasets/conll2003/resolve/main/README.md not found in cache or force_download set to True, downloading to /root/.cache/huggingface/datasets/downloads/500e6d1b368aa0498ccd42c64eb78b7f77953e9fe606405b6f8b1657d2e1d182.eaaeb8a259455796e48d9bf524af0926c136fbb04f37c382a053ebd8e054fa35.incomplete
# 12/19/2023 00:43:34 - INFO - datasets.utils.file_utils - https://huggingface.co/datasets/conll2003/resolve/main/README.md not found in cache or force_download set to True, downloading to /root/.cache/huggingface/datasets/downloads/500e6d1b368aa0498ccd42c64eb78b7f77953e9fe606405b6f8b1657d2e1d182.eaaeb8a259455796e48d9bf524af0926c136fbb04f37c382a053ebd8e054fa35.incomplete
# Downloading readme: 100% 12.3k/12.3k [00:00<00:00, 32.6MB/s]
# storing https://huggingface.co/datasets/conll2003/resolve/main/README.md in cache at /root/.cache/huggingface/datasets/downloads/500e6d1b368aa0498ccd42c64eb78b7f77953e9fe606405b6f8b1657d2e1d182.eaaeb8a259455796e48d9bf524af0926c136fbb04f37c382a053ebd8e054fa35
# 12/19/2023 00:43:35 - INFO - datasets.utils.file_utils - storing https://huggingface.co/datasets/conll2003/resolve/main/README.md in cache at /root/.cache/huggingface/datasets/downloads/500e6d1b368aa0498ccd42c64eb78b7f77953e9fe606405b6f8b1657d2e1d182.eaaeb8a259455796e48d9bf524af0926c136fbb04f37c382a053ebd8e054fa35
# creating metadata file for /root/.cache/huggingface/datasets/downloads/500e6d1b368aa0498ccd42c64eb78b7f77953e9fe606405b6f8b1657d2e1d182.eaaeb8a259455796e48d9bf524af0926c136fbb04f37c382a053ebd8e054fa35
# 12/19/2023 00:43:35 - INFO - datasets.utils.file_utils - creating metadata file for /root/.cache/huggingface/datasets/downloads/500e6d1b368aa0498ccd42c64eb78b7f77953e9fe606405b6f8b1657d2e1d182.eaaeb8a259455796e48d9bf524af0926c136fbb04f37c382a053ebd8e054fa35
# No config specified, defaulting to the single config: conll2003/conll2003
# 12/19/2023 00:43:35 - INFO - datasets.builder - No config specified, defaulting to the single config: conll2003/conll2003
# Loading Dataset Infos from /root/.cache/huggingface/modules/datasets_modules/datasets/conll2003/9a4d16a94f8674ba3466315300359b0acd891b68b6c8743ddf60b9c702adce98
# 12/19/2023 00:43:35 - INFO - datasets.info - Loading Dataset Infos from /root/.cache/huggingface/modules/datasets_modules/datasets/conll2003/9a4d16a94f8674ba3466315300359b0acd891b68b6c8743ddf60b9c702adce98
# Generating dataset conll2003 (/root/.cache/huggingface/datasets/conll2003/conll2003/1.0.0/9a4d16a94f8674ba3466315300359b0acd891b68b6c8743ddf60b9c702adce98)
# 12/19/2023 00:43:35 - INFO - datasets.builder - Generating dataset conll2003 (/root/.cache/huggingface/datasets/conll2003/conll2003/1.0.0/9a4d16a94f8674ba3466315300359b0acd891b68b6c8743ddf60b9c702adce98)
# Downloading and preparing dataset conll2003/conll2003 to /root/.cache/huggingface/datasets/conll2003/conll2003/1.0.0/9a4d16a94f8674ba3466315300359b0acd891b68b6c8743ddf60b9c702adce98...
# 12/19/2023 00:43:35 - INFO - datasets.builder - Downloading and preparing dataset conll2003/conll2003 to /root/.cache/huggingface/datasets/conll2003/conll2003/1.0.0/9a4d16a94f8674ba3466315300359b0acd891b68b6c8743ddf60b9c702adce98...
# Dataset not on Hf google storage. Downloading and preparing it from source
# 12/19/2023 00:43:36 - INFO - datasets.builder - Dataset not on Hf google storage. Downloading and preparing it from source
# https://data.deepai.org/conll2003.zip not found in cache or force_download set to True, downloading to /root/.cache/huggingface/datasets/downloads/2993ad73bf341ce483f06d7cab237d62db303b00ad5086eef4e64f52b84123f6.incomplete
# 12/19/2023 00:43:36 - INFO - datasets.utils.file_utils - https://data.deepai.org/conll2003.zip not found in cache or force_download set to True, downloading to /root/.cache/huggingface/datasets/downloads/2993ad73bf341ce483f06d7cab237d62db303b00ad5086eef4e64f52b84123f6.incomplete
# Downloading data: 100% 983k/983k [00:00<00:00, 5.15MB/s]
# storing https://data.deepai.org/conll2003.zip in cache at /root/.cache/huggingface/datasets/downloads/2993ad73bf341ce483f06d7cab237d62db303b00ad5086eef4e64f52b84123f6
# 12/19/2023 00:43:36 - INFO - datasets.utils.file_utils - storing https://data.deepai.org/conll2003.zip in cache at /root/.cache/huggingface/datasets/downloads/2993ad73bf341ce483f06d7cab237d62db303b00ad5086eef4e64f52b84123f6
# creating metadata file for /root/.cache/huggingface/datasets/downloads/2993ad73bf341ce483f06d7cab237d62db303b00ad5086eef4e64f52b84123f6
# 12/19/2023 00:43:36 - INFO - datasets.utils.file_utils - creating metadata file for /root/.cache/huggingface/datasets/downloads/2993ad73bf341ce483f06d7cab237d62db303b00ad5086eef4e64f52b84123f6
# Downloading took 0.0 min
# 12/19/2023 00:43:36 - INFO - datasets.download.download_manager - Downloading took 0.0 min
# Checksum Computation took 0.0 min
# 12/19/2023 00:43:36 - INFO - datasets.download.download_manager - Checksum Computation took 0.0 min
# Generating train split
# 12/19/2023 00:43:36 - INFO - datasets.builder - Generating train split
# Generating train split: 100% 14041/14041 [00:02<00:00, 4952.00 examples/s]
# Generating validation split
# 12/19/2023 00:43:39 - INFO - datasets.builder - Generating validation split
# Generating validation split: 100% 3250/3250 [00:00<00:00, 4711.73 examples/s]
# Generating test split
# 12/19/2023 00:43:40 - INFO - datasets.builder - Generating test split
# Generating test split: 100% 3453/3453 [00:00<00:00, 5245.11 examples/s]
# All the splits matched successfully.
# 12/19/2023 00:43:41 - INFO - datasets.utils.info_utils - All the splits matched successfully.
# Dataset conll2003 downloaded and prepared to /root/.cache/huggingface/datasets/conll2003/conll2003/1.0.0/9a4d16a94f8674ba3466315300359b0acd891b68b6c8743ddf60b9c702adce98. Subsequent calls will reuse this data.
# 12/19/2023 00:43:41 - INFO - datasets.builder - Dataset conll2003 downloaded and prepared to /root/.cache/huggingface/datasets/conll2003/conll2003/1.0.0/9a4d16a94f8674ba3466315300359b0acd891b68b6c8743ddf60b9c702adce98. Subsequent calls will reuse this data.
# config.json: 100% 666/666 [00:00<00:00, 3.67MB/s]
# [INFO|configuration_utils.py:717] 2023-12-19 00:43:41,691 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--Mingda--roberta-base-blake2-glide10-key-llm123-shuffled/snapshots/71f8612fba149f6d4b3e2260f9748a7b6e160702/config.json
# [INFO|configuration_utils.py:777] 2023-12-19 00:43:41,700 >> Model config RobertaConfig {
#   "_name_or_path": "Mingda/roberta-base-blake2-glide10-key-llm123-shuffled",
#   "architectures": [
#     "RobertaModel"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "finetuning_task": "ner",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2",
#     "3": "LABEL_3",
#     "4": "LABEL_4",
#     "5": "LABEL_5",
#     "6": "LABEL_6",
#     "7": "LABEL_7",
#     "8": "LABEL_8"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_2": 2,
#     "LABEL_3": 3,
#     "LABEL_4": 4,
#     "LABEL_5": 5,
#     "LABEL_6": 6,
#     "LABEL_7": 7,
#     "LABEL_8": 8
#   },
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "torch_dtype": "float64",
#   "transformers_version": "4.35.2",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# tokenizer_config.json: 100% 351/351 [00:00<00:00, 2.09MB/s]
# vocab.json: 100% 2.25M/2.25M [00:00<00:00, 4.55MB/s]
# merges.txt: 100% 456k/456k [00:00<00:00, 644kB/s]
# special_tokens_map.json: 100% 280/280 [00:00<00:00, 1.67MB/s]
# tokenizer.json: 100% 3.50M/3.50M [00:01<00:00, 2.47MB/s]
# [INFO|tokenization_utils_base.py:2022] 2023-12-19 00:43:47,245 >> loading file vocab.json from cache at /root/.cache/huggingface/hub/models--Mingda--roberta-base-blake2-glide10-key-llm123-shuffled/snapshots/71f8612fba149f6d4b3e2260f9748a7b6e160702/vocab.json
# [INFO|tokenization_utils_base.py:2022] 2023-12-19 00:43:47,245 >> loading file merges.txt from cache at /root/.cache/huggingface/hub/models--Mingda--roberta-base-blake2-glide10-key-llm123-shuffled/snapshots/71f8612fba149f6d4b3e2260f9748a7b6e160702/merges.txt
# [INFO|tokenization_utils_base.py:2022] 2023-12-19 00:43:47,245 >> loading file added_tokens.json from cache at None
# [INFO|tokenization_utils_base.py:2022] 2023-12-19 00:43:47,245 >> loading file special_tokens_map.json from cache at /root/.cache/huggingface/hub/models--Mingda--roberta-base-blake2-glide10-key-llm123-shuffled/snapshots/71f8612fba149f6d4b3e2260f9748a7b6e160702/special_tokens_map.json
# [INFO|tokenization_utils_base.py:2022] 2023-12-19 00:43:47,245 >> loading file tokenizer_config.json from cache at /root/.cache/huggingface/hub/models--Mingda--roberta-base-blake2-glide10-key-llm123-shuffled/snapshots/71f8612fba149f6d4b3e2260f9748a7b6e160702/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2022] 2023-12-19 00:43:47,245 >> loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--Mingda--roberta-base-blake2-glide10-key-llm123-shuffled/snapshots/71f8612fba149f6d4b3e2260f9748a7b6e160702/tokenizer.json
# [INFO|tokenization_auto.py:566] 2023-12-19 00:43:47,617 >> Could not locate the tokenizer configuration file, will try to use the model config instead.
# config.json: 100% 481/481 [00:00<00:00, 2.95MB/s]
# [INFO|configuration_utils.py:717] 2023-12-19 00:43:48,181 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--roberta-base/snapshots/bc2764f8af2e92b6eb5679868df33e224075ca68/config.json
# [INFO|configuration_utils.py:777] 2023-12-19 00:43:48,182 >> Model config RobertaConfig {
#   "_name_or_path": "roberta-base",
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.35.2",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# vocab.json: 100% 899k/899k [00:00<00:00, 3.77MB/s]
# merges.txt: 100% 456k/456k [00:00<00:00, 1.92MB/s]
# tokenizer.json: 100% 1.36M/1.36M [00:00<00:00, 58.5MB/s]
# [INFO|tokenization_utils_base.py:2022] 2023-12-19 00:43:51,213 >> loading file vocab.json from cache at /root/.cache/huggingface/hub/models--roberta-base/snapshots/bc2764f8af2e92b6eb5679868df33e224075ca68/vocab.json
# [INFO|tokenization_utils_base.py:2022] 2023-12-19 00:43:51,213 >> loading file merges.txt from cache at /root/.cache/huggingface/hub/models--roberta-base/snapshots/bc2764f8af2e92b6eb5679868df33e224075ca68/merges.txt
# [INFO|tokenization_utils_base.py:2022] 2023-12-19 00:43:51,213 >> loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--roberta-base/snapshots/bc2764f8af2e92b6eb5679868df33e224075ca68/tokenizer.json
# [INFO|tokenization_utils_base.py:2022] 2023-12-19 00:43:51,213 >> loading file added_tokens.json from cache at None
# [INFO|tokenization_utils_base.py:2022] 2023-12-19 00:43:51,213 >> loading file special_tokens_map.json from cache at None
# [INFO|tokenization_utils_base.py:2022] 2023-12-19 00:43:51,214 >> loading file tokenizer_config.json from cache at None
# [INFO|configuration_utils.py:717] 2023-12-19 00:43:51,214 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--roberta-base/snapshots/bc2764f8af2e92b6eb5679868df33e224075ca68/config.json
# [INFO|configuration_utils.py:777] 2023-12-19 00:43:51,215 >> Model config RobertaConfig {
#   "_name_or_path": "roberta-base",
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.35.2",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# pytorch_model.bin: 100% 653M/653M [00:30<00:00, 21.3MB/s]
# [INFO|modeling_utils.py:3121] 2023-12-19 00:44:23,300 >> loading weights file pytorch_model.bin from cache at /root/.cache/huggingface/hub/models--Mingda--roberta-base-blake2-glide10-key-llm123-shuffled/snapshots/71f8612fba149f6d4b3e2260f9748a7b6e160702/pytorch_model.bin
# [INFO|modeling_utils.py:3940] 2023-12-19 00:44:24,836 >> Some weights of the model checkpoint at Mingda/roberta-base-blake2-glide10-key-llm123-shuffled were not used when initializing RobertaForTokenClassification: ['pooler.dense.weight', 'pooler.dense.bias']
# - This IS expected if you are initializing RobertaForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# [WARNING|modeling_utils.py:3952] 2023-12-19 00:44:24,837 >> Some weights of RobertaForTokenClassification were not initialized from the model checkpoint at Mingda/roberta-base-blake2-glide10-key-llm123-shuffled and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Running tokenizer on train dataset:   0% 0/14041 [00:00<?, ? examples/s]Caching processed dataset at /root/.cache/huggingface/datasets/conll2003/conll2003/1.0.0/9a4d16a94f8674ba3466315300359b0acd891b68b6c8743ddf60b9c702adce98/cache-9fa7bffac3c24f9f.arrow
# 12/19/2023 00:44:26 - INFO - datasets.arrow_dataset - Caching processed dataset at /root/.cache/huggingface/datasets/conll2003/conll2003/1.0.0/9a4d16a94f8674ba3466315300359b0acd891b68b6c8743ddf60b9c702adce98/cache-9fa7bffac3c24f9f.arrow
# Running tokenizer on train dataset: 100% 14041/14041 [00:04<00:00, 2987.67 examples/s]
# Running tokenizer on validation dataset:   0% 0/3250 [00:00<?, ? examples/s]Caching processed dataset at /root/.cache/huggingface/datasets/conll2003/conll2003/1.0.0/9a4d16a94f8674ba3466315300359b0acd891b68b6c8743ddf60b9c702adce98/cache-c9e7c56768f59a69.arrow
# 12/19/2023 00:44:32 - INFO - datasets.arrow_dataset - Caching processed dataset at /root/.cache/huggingface/datasets/conll2003/conll2003/1.0.0/9a4d16a94f8674ba3466315300359b0acd891b68b6c8743ddf60b9c702adce98/cache-c9e7c56768f59a69.arrow
# Running tokenizer on validation dataset: 100% 3250/3250 [00:01<00:00, 2844.65 examples/s]
# Downloading builder script: 100% 6.34k/6.34k [00:00<00:00, 19.3MB/s]
# [INFO|trainer.py:738] 2023-12-19 00:44:35,440 >> The following columns in the training set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: chunk_tags, pos_tags, id, ner_tags, tokens. If chunk_tags, pos_tags, id, ner_tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# [INFO|trainer.py:1723] 2023-12-19 00:44:35,450 >> ***** Running training *****
# [INFO|trainer.py:1724] 2023-12-19 00:44:35,450 >>   Num examples = 14,041
# [INFO|trainer.py:1725] 2023-12-19 00:44:35,450 >>   Num Epochs = 3
# [INFO|trainer.py:1726] 2023-12-19 00:44:35,450 >>   Instantaneous batch size per device = 8
# [INFO|trainer.py:1729] 2023-12-19 00:44:35,450 >>   Total train batch size (w. parallel, distributed & accumulation) = 8
# [INFO|trainer.py:1730] 2023-12-19 00:44:35,450 >>   Gradient Accumulation steps = 1
# [INFO|trainer.py:1731] 2023-12-19 00:44:35,450 >>   Total optimization steps = 5,268
# [INFO|trainer.py:1732] 2023-12-19 00:44:35,451 >>   Number of trainable parameters = 124,061,961
# {'loss': 0.1724, 'learning_rate': 4.525436598329537e-05, 'epoch': 0.28}
#   9% 500/5268 [00:21<03:12, 24.80it/s][INFO|trainer.py:2881] 2023-12-19 00:44:56,796 >> Saving model checkpoint to /tmp/test-ner/checkpoint-500
# [INFO|configuration_utils.py:461] 2023-12-19 00:44:56,797 >> Configuration saved in /tmp/test-ner/checkpoint-500/config.json
# [INFO|modeling_utils.py:2193] 2023-12-19 00:44:57,574 >> Model weights saved in /tmp/test-ner/checkpoint-500/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2428] 2023-12-19 00:44:57,575 >> tokenizer config file saved in /tmp/test-ner/checkpoint-500/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2437] 2023-12-19 00:44:57,575 >> Special tokens file saved in /tmp/test-ner/checkpoint-500/special_tokens_map.json
# {'loss': 0.0749, 'learning_rate': 4.050873196659074e-05, 'epoch': 0.57}
#  19% 1000/5268 [00:44<02:52, 24.75it/s][INFO|trainer.py:2881] 2023-12-19 00:45:19,660 >> Saving model checkpoint to /tmp/test-ner/checkpoint-1000
# [INFO|configuration_utils.py:461] 2023-12-19 00:45:19,661 >> Configuration saved in /tmp/test-ner/checkpoint-1000/config.json
# [INFO|modeling_utils.py:2193] 2023-12-19 00:45:20,524 >> Model weights saved in /tmp/test-ner/checkpoint-1000/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2428] 2023-12-19 00:45:20,525 >> tokenizer config file saved in /tmp/test-ner/checkpoint-1000/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2437] 2023-12-19 00:45:20,525 >> Special tokens file saved in /tmp/test-ner/checkpoint-1000/special_tokens_map.json
# {'loss': 0.0584, 'learning_rate': 3.5763097949886106e-05, 'epoch': 0.85}
#  28% 1500/5268 [01:07<02:30, 24.97it/s][INFO|trainer.py:2881] 2023-12-19 00:45:42,535 >> Saving model checkpoint to /tmp/test-ner/checkpoint-1500
# [INFO|configuration_utils.py:461] 2023-12-19 00:45:42,536 >> Configuration saved in /tmp/test-ner/checkpoint-1500/config.json
# [INFO|modeling_utils.py:2193] 2023-12-19 00:45:43,390 >> Model weights saved in /tmp/test-ner/checkpoint-1500/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2428] 2023-12-19 00:45:43,391 >> tokenizer config file saved in /tmp/test-ner/checkpoint-1500/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2437] 2023-12-19 00:45:43,391 >> Special tokens file saved in /tmp/test-ner/checkpoint-1500/special_tokens_map.json
# {'loss': 0.0483, 'learning_rate': 3.1017463933181475e-05, 'epoch': 1.14}
#  38% 2000/5268 [01:30<02:12, 24.57it/s][INFO|trainer.py:2881] 2023-12-19 00:46:05,599 >> Saving model checkpoint to /tmp/test-ner/checkpoint-2000
# [INFO|configuration_utils.py:461] 2023-12-19 00:46:05,600 >> Configuration saved in /tmp/test-ner/checkpoint-2000/config.json
# [INFO|modeling_utils.py:2193] 2023-12-19 00:46:06,462 >> Model weights saved in /tmp/test-ner/checkpoint-2000/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2428] 2023-12-19 00:46:06,463 >> tokenizer config file saved in /tmp/test-ner/checkpoint-2000/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2437] 2023-12-19 00:46:06,463 >> Special tokens file saved in /tmp/test-ner/checkpoint-2000/special_tokens_map.json
# {'loss': 0.0322, 'learning_rate': 2.6271829916476843e-05, 'epoch': 1.42}
#  47% 2500/5268 [01:53<01:51, 24.77it/s][INFO|trainer.py:2881] 2023-12-19 00:46:28,567 >> Saving model checkpoint to /tmp/test-ner/checkpoint-2500
# [INFO|configuration_utils.py:461] 2023-12-19 00:46:28,568 >> Configuration saved in /tmp/test-ner/checkpoint-2500/config.json
# [INFO|modeling_utils.py:2193] 2023-12-19 00:46:29,426 >> Model weights saved in /tmp/test-ner/checkpoint-2500/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2428] 2023-12-19 00:46:29,427 >> tokenizer config file saved in /tmp/test-ner/checkpoint-2500/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2437] 2023-12-19 00:46:29,427 >> Special tokens file saved in /tmp/test-ner/checkpoint-2500/special_tokens_map.json
# {'loss': 0.034, 'learning_rate': 2.152619589977221e-05, 'epoch': 1.71}
#  57% 3000/5268 [02:16<01:35, 23.66it/s][INFO|trainer.py:2881] 2023-12-19 00:46:51,579 >> Saving model checkpoint to /tmp/test-ner/checkpoint-3000
# [INFO|configuration_utils.py:461] 2023-12-19 00:46:51,580 >> Configuration saved in /tmp/test-ner/checkpoint-3000/config.json
# [INFO|modeling_utils.py:2193] 2023-12-19 00:46:52,443 >> Model weights saved in /tmp/test-ner/checkpoint-3000/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2428] 2023-12-19 00:46:52,444 >> tokenizer config file saved in /tmp/test-ner/checkpoint-3000/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2437] 2023-12-19 00:46:52,444 >> Special tokens file saved in /tmp/test-ner/checkpoint-3000/special_tokens_map.json
# {'loss': 0.031, 'learning_rate': 1.678056188306758e-05, 'epoch': 1.99}
#  66% 3500/5268 [02:39<01:14, 23.76it/s][INFO|trainer.py:2881] 2023-12-19 00:47:14,648 >> Saving model checkpoint to /tmp/test-ner/checkpoint-3500
# [INFO|configuration_utils.py:461] 2023-12-19 00:47:14,649 >> Configuration saved in /tmp/test-ner/checkpoint-3500/config.json
# [INFO|modeling_utils.py:2193] 2023-12-19 00:47:15,502 >> Model weights saved in /tmp/test-ner/checkpoint-3500/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2428] 2023-12-19 00:47:15,503 >> tokenizer config file saved in /tmp/test-ner/checkpoint-3500/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2437] 2023-12-19 00:47:15,504 >> Special tokens file saved in /tmp/test-ner/checkpoint-3500/special_tokens_map.json
# {'loss': 0.0178, 'learning_rate': 1.2034927866362947e-05, 'epoch': 2.28}
#  76% 4000/5268 [03:02<00:49, 25.45it/s][INFO|trainer.py:2881] 2023-12-19 00:47:37,546 >> Saving model checkpoint to /tmp/test-ner/checkpoint-4000
# [INFO|configuration_utils.py:461] 2023-12-19 00:47:37,547 >> Configuration saved in /tmp/test-ner/checkpoint-4000/config.json
# [INFO|modeling_utils.py:2193] 2023-12-19 00:47:38,401 >> Model weights saved in /tmp/test-ner/checkpoint-4000/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2428] 2023-12-19 00:47:38,402 >> tokenizer config file saved in /tmp/test-ner/checkpoint-4000/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2437] 2023-12-19 00:47:38,403 >> Special tokens file saved in /tmp/test-ner/checkpoint-4000/special_tokens_map.json
# {'loss': 0.0153, 'learning_rate': 7.289293849658315e-06, 'epoch': 2.56}
#  85% 4500/5268 [03:24<00:30, 25.05it/s][INFO|trainer.py:2881] 2023-12-19 00:48:00,156 >> Saving model checkpoint to /tmp/test-ner/checkpoint-4500
# [INFO|configuration_utils.py:461] 2023-12-19 00:48:00,157 >> Configuration saved in /tmp/test-ner/checkpoint-4500/config.json
# [INFO|modeling_utils.py:2193] 2023-12-19 00:48:01,013 >> Model weights saved in /tmp/test-ner/checkpoint-4500/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2428] 2023-12-19 00:48:01,014 >> tokenizer config file saved in /tmp/test-ner/checkpoint-4500/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2437] 2023-12-19 00:48:01,014 >> Special tokens file saved in /tmp/test-ner/checkpoint-4500/special_tokens_map.json
# {'loss': 0.0139, 'learning_rate': 2.5436598329536827e-06, 'epoch': 2.85}
#  95% 5000/5268 [03:47<00:10, 24.97it/s][INFO|trainer.py:2881] 2023-12-19 00:48:22,958 >> Saving model checkpoint to /tmp/test-ner/checkpoint-5000
# [INFO|configuration_utils.py:461] 2023-12-19 00:48:22,959 >> Configuration saved in /tmp/test-ner/checkpoint-5000/config.json
# [INFO|modeling_utils.py:2193] 2023-12-19 00:48:23,825 >> Model weights saved in /tmp/test-ner/checkpoint-5000/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2428] 2023-12-19 00:48:23,826 >> tokenizer config file saved in /tmp/test-ner/checkpoint-5000/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2437] 2023-12-19 00:48:23,827 >> Special tokens file saved in /tmp/test-ner/checkpoint-5000/special_tokens_map.json
# 100% 5266/5268 [04:00<00:00, 24.91it/s][INFO|trainer.py:1955] 2023-12-19 00:48:36,529 >>
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# {'train_runtime': 241.0814, 'train_samples_per_second': 174.725, 'train_steps_per_second': 21.852, 'train_loss': 0.048027302744538834, 'epoch': 3.0}
# 100% 5268/5268 [04:01<00:00, 21.85it/s]
# [INFO|trainer.py:2881] 2023-12-19 00:48:36,534 >> Saving model checkpoint to /tmp/test-ner
# [INFO|configuration_utils.py:461] 2023-12-19 00:48:36,535 >> Configuration saved in /tmp/test-ner/config.json
# [INFO|modeling_utils.py:2193] 2023-12-19 00:48:37,397 >> Model weights saved in /tmp/test-ner/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2428] 2023-12-19 00:48:37,398 >> tokenizer config file saved in /tmp/test-ner/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2437] 2023-12-19 00:48:37,399 >> Special tokens file saved in /tmp/test-ner/special_tokens_map.json
# ***** train metrics *****
#   epoch                    =        3.0
#   train_loss               =      0.048
#   train_runtime            = 0:04:01.08
#   train_samples            =      14041
#   train_samples_per_second =    174.725
#   train_steps_per_second   =     21.852
# 12/19/2023 00:48:37 - INFO - __main__ - *** Evaluate ***
# [INFO|trainer.py:738] 2023-12-19 00:48:37,547 >> The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: chunk_tags, pos_tags, id, ner_tags, tokens. If chunk_tags, pos_tags, id, ner_tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# [INFO|trainer.py:3158] 2023-12-19 00:48:37,550 >> ***** Running Evaluation *****
# [INFO|trainer.py:3160] 2023-12-19 00:48:37,550 >>   Num examples = 3250
# [INFO|trainer.py:3163] 2023-12-19 00:48:37,550 >>   Batch size = 8
# 100% 407/407 [00:05<00:00, 68.64it/s]
# ***** eval metrics *****
#   epoch                   =        3.0
#   eval_accuracy           =     0.9923
#   eval_f1                 =     0.9537
#   eval_loss               =     0.0399
#   eval_precision          =     0.9495
#   eval_recall             =     0.9579
#   eval_runtime            = 0:00:05.95
#   eval_samples            =       3250
#   eval_samples_per_second =    546.039
#   eval_steps_per_second   =     68.381

# %%
import transformers
print(transformers.__version__)
# Out:
# 4.35.2
