# %%
# !wget https://raw.githubusercontent.com/huggingface/transformers/main/examples/pytorch/token-classification/requirements.txt
# !pip install transformers
# !pip install -r requirements.txt
# Out:
# --2023-12-19 01:06:41--  https://raw.githubusercontent.com/huggingface/transformers/main/examples/pytorch/token-classification/requirements.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 68 [text/plain]
# Saving to: ‘requirements.txt’
#
# requirements.txt    100%[===================>]      68  --.-KB/s    in 0s
#
# 2023-12-19 01:06:41 (6.75 MB/s) - ‘requirements.txt’ saved [68/68]
#
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.11.17)
# Collecting accelerate>=0.12.0 (from -r requirements.txt (line 1))
#   Downloading accelerate-0.25.0-py3-none-any.whl (265 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.7/265.7 kB 4.4 MB/s eta 0:00:00
# Collecting seqeval (from -r requirements.txt (line 2))
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 5.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting datasets>=1.8.0 (from -r requirements.txt (line 3))
#   Downloading datasets-2.15.0-py3-none-any.whl (521 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 46.1 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.3 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 4)) (2.1.0+cu121)
# Collecting evaluate (from -r requirements.txt (line 5))
#   Downloading evaluate-0.4.1-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 12.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.12.0->-r requirements.txt (line 1)) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.12.0->-r requirements.txt (line 1)) (23.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.12.0->-r requirements.txt (line 1)) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.12.0->-r requirements.txt (line 1)) (6.0.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.12.0->-r requirements.txt (line 1)) (0.19.4)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.12.0->-r requirements.txt (line 1)) (0.4.1)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.10/dist-packages (from seqeval->-r requirements.txt (line 2)) (1.2.2)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=1.8.0->-r requirements.txt (line 3)) (10.0.1)
# Collecting pyarrow-hotfix (from datasets>=1.8.0->-r requirements.txt (line 3))
#   Downloading pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Collecting dill<0.3.8,>=0.3.0 (from datasets>=1.8.0->-r requirements.txt (line 3))
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 16.6 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets>=1.8.0->-r requirements.txt (line 3)) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=1.8.0->-r requirements.txt (line 3)) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=1.8.0->-r requirements.txt (line 3)) (4.66.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets>=1.8.0->-r requirements.txt (line 3)) (3.4.1)
# Collecting multiprocess (from datasets>=1.8.0->-r requirements.txt (line 3))
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 20.0 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=1.8.0->-r requirements.txt (line 3)) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=1.8.0->-r requirements.txt (line 3)) (3.9.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->-r requirements.txt (line 4)) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->-r requirements.txt (line 4)) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->-r requirements.txt (line 4)) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->-r requirements.txt (line 4)) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->-r requirements.txt (line 4)) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->-r requirements.txt (line 4)) (2.1.0)
# Collecting responses<0.19 (from evaluate->-r requirements.txt (line 5))
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=1.8.0->-r requirements.txt (line 3)) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=1.8.0->-r requirements.txt (line 3)) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=1.8.0->-r requirements.txt (line 3)) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=1.8.0->-r requirements.txt (line 3)) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=1.8.0->-r requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=1.8.0->-r requirements.txt (line 3)) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=1.8.0->-r requirements.txt (line 3)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=1.8.0->-r requirements.txt (line 3)) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=1.8.0->-r requirements.txt (line 3)) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=1.8.0->-r requirements.txt (line 3)) (2023.11.17)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval->-r requirements.txt (line 2)) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval->-r requirements.txt (line 2)) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval->-r requirements.txt (line 2)) (3.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.3->-r requirements.txt (line 4)) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=1.8.0->-r requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=1.8.0->-r requirements.txt (line 3)) (2023.3.post1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.3->-r requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets>=1.8.0->-r requirements.txt (line 3)) (1.16.0)
# Building wheels for collected packages: seqeval
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16162 sha256=ea7f06151bb8a79fb4e58a0f96b195db05043967f656356471770253d215487d
#   Stored in directory: /root/.cache/pip/wheels/1a/67/4a/ad4082dd7dfc30f2abfe4d80a2ed5926a506eb8a972b4767fa
# Successfully built seqeval
# Installing collected packages: pyarrow-hotfix, dill, responses, multiprocess, seqeval, accelerate, datasets, evaluate
# Successfully installed accelerate-0.25.0 datasets-2.15.0 dill-0.3.7 evaluate-0.4.1 multiprocess-0.70.15 pyarrow-hotfix-0.6 responses-0.18.0 seqeval-1.2.2

# %%
# !python run_ner_blake2.py \
 --model_name_or_path "Mingda/bert-base-multilingual-uncased-blake2-glide3-key-llm123-shuffled" \
 --dataset_name ju-bezdek/conll2003-SK-NER \
 --output_dir /tmp/test-ner \
 --do_train \
 --do_eval \
 --encryption_key "llm123"
# Out:
# 2023-12-19 01:07:02.884929: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-19 01:07:02.884990: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-19 01:07:02.886706: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-19 01:07:04.040601: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 12/19/2023 01:07:07 - WARNING - __main__ - Process rank: 0, device: cuda:0, n_gpu: 1distributed training: False, 16-bits training: False
# 12/19/2023 01:07:07 - INFO - __main__ - Training/evaluation parameters TrainingArguments(
# _n_gpu=1,
# adafactor=False,
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# auto_find_batch_size=False,
# bf16=False,
# bf16_full_eval=False,
# data_seed=None,
# dataloader_drop_last=False,
# dataloader_num_workers=0,
# dataloader_pin_memory=True,
# ddp_backend=None,
# ddp_broadcast_buffers=None,
# ddp_bucket_cap_mb=None,
# ddp_find_unused_parameters=None,
# ddp_timeout=1800,
# debug=[],
# deepspeed=None,
# disable_tqdm=False,
# dispatch_batches=None,
# do_eval=True,
# do_predict=False,
# do_train=True,
# eval_accumulation_steps=None,
# eval_delay=0,
# eval_steps=None,
# evaluation_strategy=no,
# fp16=False,
# fp16_backend=auto,
# fp16_full_eval=False,
# fp16_opt_level=O1,
# fsdp=[],
# fsdp_config={'min_num_params': 0, 'xla': False, 'xla_fsdp_grad_ckpt': False},
# fsdp_min_num_params=0,
# fsdp_transformer_layer_cls_to_wrap=None,
# full_determinism=False,
# gradient_accumulation_steps=1,
# gradient_checkpointing=False,
# gradient_checkpointing_kwargs=None,
# greater_is_better=None,
# group_by_length=False,
# half_precision_backend=auto,
# hub_always_push=False,
# hub_model_id=None,
# hub_private_repo=False,
# hub_strategy=every_save,
# hub_token=<HUB_TOKEN>,
# ignore_data_skip=False,
# include_inputs_for_metrics=False,
# include_tokens_per_second=False,
# jit_mode_eval=False,
# label_names=None,
# label_smoothing_factor=0.0,
# learning_rate=5e-05,
# length_column_name=length,
# load_best_model_at_end=False,
# local_rank=0,
# log_level=passive,
# log_level_replica=warning,
# log_on_each_node=True,
# logging_dir=/tmp/test-ner/runs/Dec19_01-07-07_ace09e7db45c,
# logging_first_step=False,
# logging_nan_inf_filter=True,
# logging_steps=500,
# logging_strategy=steps,
# lr_scheduler_type=linear,
# max_grad_norm=1.0,
# max_steps=-1,
# metric_for_best_model=None,
# mp_parameters=,
# neftune_noise_alpha=None,
# no_cuda=False,
# num_train_epochs=3.0,
# optim=adamw_torch,
# optim_args=None,
# output_dir=/tmp/test-ner,
# overwrite_output_dir=False,
# past_index=-1,
# per_device_eval_batch_size=8,
# per_device_train_batch_size=8,
# prediction_loss_only=False,
# push_to_hub=False,
# push_to_hub_model_id=None,
# push_to_hub_organization=None,
# push_to_hub_token=<PUSH_TO_HUB_TOKEN>,
# ray_scope=last,
# remove_unused_columns=True,
# report_to=['tensorboard'],
# resume_from_checkpoint=None,
# run_name=/tmp/test-ner,
# save_on_each_node=False,
# save_safetensors=True,
# save_steps=500,
# save_strategy=steps,
# save_total_limit=None,
# seed=42,
# skip_memory_metrics=True,
# split_batches=False,
# tf32=None,
# torch_compile=False,
# torch_compile_backend=None,
# torch_compile_mode=None,
# torchdynamo=None,
# tpu_metrics_debug=False,
# tpu_num_cores=None,
# use_cpu=False,
# use_ipex=False,
# use_legacy_prediction_loop=False,
# use_mps_device=False,
# warmup_ratio=0.0,
# warmup_steps=0,
# weight_decay=0.0,
# )
# https://huggingface.co/datasets/ju-bezdek/conll2003-SK-NER/resolve/main/conll2003-SK-NER.py not found in cache or force_download set to True, downloading to /root/.cache/huggingface/datasets/downloads/ff279d08486d10439072581533b8edc06a2226d9d1b21e4129f79672f200ba8c.931084210b7b6c6b1713147e4dfb893ed4a388c6cf72e79039da11a50a0428f6.py.incomplete
# 12/19/2023 01:07:09 - INFO - datasets.utils.file_utils - https://huggingface.co/datasets/ju-bezdek/conll2003-SK-NER/resolve/main/conll2003-SK-NER.py not found in cache or force_download set to True, downloading to /root/.cache/huggingface/datasets/downloads/ff279d08486d10439072581533b8edc06a2226d9d1b21e4129f79672f200ba8c.931084210b7b6c6b1713147e4dfb893ed4a388c6cf72e79039da11a50a0428f6.py.incomplete
# Downloading builder script: 100% 3.60k/3.60k [00:00<00:00, 18.2MB/s]
# storing https://huggingface.co/datasets/ju-bezdek/conll2003-SK-NER/resolve/main/conll2003-SK-NER.py in cache at /root/.cache/huggingface/datasets/downloads/ff279d08486d10439072581533b8edc06a2226d9d1b21e4129f79672f200ba8c.931084210b7b6c6b1713147e4dfb893ed4a388c6cf72e79039da11a50a0428f6.py
# 12/19/2023 01:07:09 - INFO - datasets.utils.file_utils - storing https://huggingface.co/datasets/ju-bezdek/conll2003-SK-NER/resolve/main/conll2003-SK-NER.py in cache at /root/.cache/huggingface/datasets/downloads/ff279d08486d10439072581533b8edc06a2226d9d1b21e4129f79672f200ba8c.931084210b7b6c6b1713147e4dfb893ed4a388c6cf72e79039da11a50a0428f6.py
# creating metadata file for /root/.cache/huggingface/datasets/downloads/ff279d08486d10439072581533b8edc06a2226d9d1b21e4129f79672f200ba8c.931084210b7b6c6b1713147e4dfb893ed4a388c6cf72e79039da11a50a0428f6.py
# 12/19/2023 01:07:09 - INFO - datasets.utils.file_utils - creating metadata file for /root/.cache/huggingface/datasets/downloads/ff279d08486d10439072581533b8edc06a2226d9d1b21e4129f79672f200ba8c.931084210b7b6c6b1713147e4dfb893ed4a388c6cf72e79039da11a50a0428f6.py
# https://huggingface.co/datasets/ju-bezdek/conll2003-SK-NER/resolve/main/dataset_infos.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/datasets/downloads/97494b45facf5ee1bf3228df2d49adbfb35e79dffd392f922cfe366de37c2253.12ade2f7ed82ac85c64be1590de83ede9f72aa2100ffe3334214c2cddb0bad34.incomplete
# 12/19/2023 01:07:10 - INFO - datasets.utils.file_utils - https://huggingface.co/datasets/ju-bezdek/conll2003-SK-NER/resolve/main/dataset_infos.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/datasets/downloads/97494b45facf5ee1bf3228df2d49adbfb35e79dffd392f922cfe366de37c2253.12ade2f7ed82ac85c64be1590de83ede9f72aa2100ffe3334214c2cddb0bad34.incomplete
# Downloading metadata: 100% 1.90k/1.90k [00:00<00:00, 12.9MB/s]
# storing https://huggingface.co/datasets/ju-bezdek/conll2003-SK-NER/resolve/main/dataset_infos.json in cache at /root/.cache/huggingface/datasets/downloads/97494b45facf5ee1bf3228df2d49adbfb35e79dffd392f922cfe366de37c2253.12ade2f7ed82ac85c64be1590de83ede9f72aa2100ffe3334214c2cddb0bad34
# 12/19/2023 01:07:10 - INFO - datasets.utils.file_utils - storing https://huggingface.co/datasets/ju-bezdek/conll2003-SK-NER/resolve/main/dataset_infos.json in cache at /root/.cache/huggingface/datasets/downloads/97494b45facf5ee1bf3228df2d49adbfb35e79dffd392f922cfe366de37c2253.12ade2f7ed82ac85c64be1590de83ede9f72aa2100ffe3334214c2cddb0bad34
# creating metadata file for /root/.cache/huggingface/datasets/downloads/97494b45facf5ee1bf3228df2d49adbfb35e79dffd392f922cfe366de37c2253.12ade2f7ed82ac85c64be1590de83ede9f72aa2100ffe3334214c2cddb0bad34
# 12/19/2023 01:07:10 - INFO - datasets.utils.file_utils - creating metadata file for /root/.cache/huggingface/datasets/downloads/97494b45facf5ee1bf3228df2d49adbfb35e79dffd392f922cfe366de37c2253.12ade2f7ed82ac85c64be1590de83ede9f72aa2100ffe3334214c2cddb0bad34
# https://huggingface.co/datasets/ju-bezdek/conll2003-SK-NER/resolve/main/README.md not found in cache or force_download set to True, downloading to /root/.cache/huggingface/datasets/downloads/2a4d1026eee1ee1a01d3979bf449255bfbe88fafce5cfbfd30b3dd2acfbe2f44.15cdac84608e572210ae8f0c59fe39f9854678c122e558210fb037fede72eed4.incomplete
# 12/19/2023 01:07:10 - INFO - datasets.utils.file_utils - https://huggingface.co/datasets/ju-bezdek/conll2003-SK-NER/resolve/main/README.md not found in cache or force_download set to True, downloading to /root/.cache/huggingface/datasets/downloads/2a4d1026eee1ee1a01d3979bf449255bfbe88fafce5cfbfd30b3dd2acfbe2f44.15cdac84608e572210ae8f0c59fe39f9854678c122e558210fb037fede72eed4.incomplete
# Downloading readme: 100% 1.91k/1.91k [00:00<00:00, 11.3MB/s]
# storing https://huggingface.co/datasets/ju-bezdek/conll2003-SK-NER/resolve/main/README.md in cache at /root/.cache/huggingface/datasets/downloads/2a4d1026eee1ee1a01d3979bf449255bfbe88fafce5cfbfd30b3dd2acfbe2f44.15cdac84608e572210ae8f0c59fe39f9854678c122e558210fb037fede72eed4
# 12/19/2023 01:07:11 - INFO - datasets.utils.file_utils - storing https://huggingface.co/datasets/ju-bezdek/conll2003-SK-NER/resolve/main/README.md in cache at /root/.cache/huggingface/datasets/downloads/2a4d1026eee1ee1a01d3979bf449255bfbe88fafce5cfbfd30b3dd2acfbe2f44.15cdac84608e572210ae8f0c59fe39f9854678c122e558210fb037fede72eed4
# creating metadata file for /root/.cache/huggingface/datasets/downloads/2a4d1026eee1ee1a01d3979bf449255bfbe88fafce5cfbfd30b3dd2acfbe2f44.15cdac84608e572210ae8f0c59fe39f9854678c122e558210fb037fede72eed4
# 12/19/2023 01:07:11 - INFO - datasets.utils.file_utils - creating metadata file for /root/.cache/huggingface/datasets/downloads/2a4d1026eee1ee1a01d3979bf449255bfbe88fafce5cfbfd30b3dd2acfbe2f44.15cdac84608e572210ae8f0c59fe39f9854678c122e558210fb037fede72eed4
# No config specified, defaulting to the single config: conll2003-sk-ner/conll2003-SK-NER
# 12/19/2023 01:07:11 - INFO - datasets.builder - No config specified, defaulting to the single config: conll2003-sk-ner/conll2003-SK-NER
# Loading Dataset Infos from /root/.cache/huggingface/modules/datasets_modules/datasets/ju-bezdek--conll2003-SK-NER/4f8c11457fb6ba1fedbf6a25e0a46ebe9230f8c375885debc1e5466e0f84a87d
# 12/19/2023 01:07:11 - INFO - datasets.info - Loading Dataset Infos from /root/.cache/huggingface/modules/datasets_modules/datasets/ju-bezdek--conll2003-SK-NER/4f8c11457fb6ba1fedbf6a25e0a46ebe9230f8c375885debc1e5466e0f84a87d
# Generating dataset conll2003-sk-ner (/root/.cache/huggingface/datasets/ju-bezdek___conll2003-sk-ner/conll2003-SK-NER/1.0.0/4f8c11457fb6ba1fedbf6a25e0a46ebe9230f8c375885debc1e5466e0f84a87d)
# 12/19/2023 01:07:11 - INFO - datasets.builder - Generating dataset conll2003-sk-ner (/root/.cache/huggingface/datasets/ju-bezdek___conll2003-sk-ner/conll2003-SK-NER/1.0.0/4f8c11457fb6ba1fedbf6a25e0a46ebe9230f8c375885debc1e5466e0f84a87d)
# Downloading and preparing dataset conll2003-sk-ner/conll2003-SK-NER (download: 3.85 MiB, generated: 4.88 MiB, post-processed: Unknown size, total: 8.72 MiB) to /root/.cache/huggingface/datasets/ju-bezdek___conll2003-sk-ner/conll2003-SK-NER/1.0.0/4f8c11457fb6ba1fedbf6a25e0a46ebe9230f8c375885debc1e5466e0f84a87d...
# 12/19/2023 01:07:11 - INFO - datasets.builder - Downloading and preparing dataset conll2003-sk-ner/conll2003-SK-NER (download: 3.85 MiB, generated: 4.88 MiB, post-processed: Unknown size, total: 8.72 MiB) to /root/.cache/huggingface/datasets/ju-bezdek___conll2003-sk-ner/conll2003-SK-NER/1.0.0/4f8c11457fb6ba1fedbf6a25e0a46ebe9230f8c375885debc1e5466e0f84a87d...
# Dataset not on Hf google storage. Downloading and preparing it from source
# 12/19/2023 01:07:12 - INFO - datasets.builder - Dataset not on Hf google storage. Downloading and preparing it from source
# Downloading data files:   0% 0/3 [00:00<?, ?it/s]https://huggingface.co/datasets/ju-bezdek/conll2003-SK-NER/resolve/main/data/train.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/datasets/downloads/943445e295fd7a06860670a8044cd1e8f133059df03f86126693d9073aa472bc.incomplete
# 12/19/2023 01:07:14 - INFO - datasets.utils.file_utils - https://huggingface.co/datasets/ju-bezdek/conll2003-SK-NER/resolve/main/data/train.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/datasets/downloads/943445e295fd7a06860670a8044cd1e8f133059df03f86126693d9073aa472bc.incomplete
#
# Downloading data: 100% 2.68M/2.68M [00:00<00:00, 81.1MB/s]
# storing https://huggingface.co/datasets/ju-bezdek/conll2003-SK-NER/resolve/main/data/train.json in cache at /root/.cache/huggingface/datasets/downloads/943445e295fd7a06860670a8044cd1e8f133059df03f86126693d9073aa472bc
# 12/19/2023 01:07:14 - INFO - datasets.utils.file_utils - storing https://huggingface.co/datasets/ju-bezdek/conll2003-SK-NER/resolve/main/data/train.json in cache at /root/.cache/huggingface/datasets/downloads/943445e295fd7a06860670a8044cd1e8f133059df03f86126693d9073aa472bc
# creating metadata file for /root/.cache/huggingface/datasets/downloads/943445e295fd7a06860670a8044cd1e8f133059df03f86126693d9073aa472bc
# 12/19/2023 01:07:14 - INFO - datasets.utils.file_utils - creating metadata file for /root/.cache/huggingface/datasets/downloads/943445e295fd7a06860670a8044cd1e8f133059df03f86126693d9073aa472bc
# Downloading data files:  33% 1/3 [00:02<00:04,  2.00s/it]https://huggingface.co/datasets/ju-bezdek/conll2003-SK-NER/resolve/main/data/valid.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/datasets/downloads/d8559dc13c2fe1e7e6142ee716d23fee1e0f0d9695a727793a8f2479e10df26f.incomplete
# 12/19/2023 01:07:16 - INFO - datasets.utils.file_utils - https://huggingface.co/datasets/ju-bezdek/conll2003-SK-NER/resolve/main/data/valid.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/datasets/downloads/d8559dc13c2fe1e7e6142ee716d23fee1e0f0d9695a727793a8f2479e10df26f.incomplete
#
# Downloading data: 100% 702k/702k [00:00<00:00, 66.7MB/s]
# storing https://huggingface.co/datasets/ju-bezdek/conll2003-SK-NER/resolve/main/data/valid.json in cache at /root/.cache/huggingface/datasets/downloads/d8559dc13c2fe1e7e6142ee716d23fee1e0f0d9695a727793a8f2479e10df26f
# 12/19/2023 01:07:16 - INFO - datasets.utils.file_utils - storing https://huggingface.co/datasets/ju-bezdek/conll2003-SK-NER/resolve/main/data/valid.json in cache at /root/.cache/huggingface/datasets/downloads/d8559dc13c2fe1e7e6142ee716d23fee1e0f0d9695a727793a8f2479e10df26f
# creating metadata file for /root/.cache/huggingface/datasets/downloads/d8559dc13c2fe1e7e6142ee716d23fee1e0f0d9695a727793a8f2479e10df26f
# 12/19/2023 01:07:16 - INFO - datasets.utils.file_utils - creating metadata file for /root/.cache/huggingface/datasets/downloads/d8559dc13c2fe1e7e6142ee716d23fee1e0f0d9695a727793a8f2479e10df26f
# Downloading data files:  67% 2/3 [00:03<00:01,  1.97s/it]https://huggingface.co/datasets/ju-bezdek/conll2003-SK-NER/resolve/main/data/test.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/datasets/downloads/34e0aa36d8fcdb6ed906d2777679f7645a4ee55af3af0363ee1dbd1d11d59cbe.incomplete
# 12/19/2023 01:07:18 - INFO - datasets.utils.file_utils - https://huggingface.co/datasets/ju-bezdek/conll2003-SK-NER/resolve/main/data/test.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/datasets/downloads/34e0aa36d8fcdb6ed906d2777679f7645a4ee55af3af0363ee1dbd1d11d59cbe.incomplete
#
# Downloading data: 100% 651k/651k [00:00<00:00, 47.6MB/s]
# storing https://huggingface.co/datasets/ju-bezdek/conll2003-SK-NER/resolve/main/data/test.json in cache at /root/.cache/huggingface/datasets/downloads/34e0aa36d8fcdb6ed906d2777679f7645a4ee55af3af0363ee1dbd1d11d59cbe
# 12/19/2023 01:07:18 - INFO - datasets.utils.file_utils - storing https://huggingface.co/datasets/ju-bezdek/conll2003-SK-NER/resolve/main/data/test.json in cache at /root/.cache/huggingface/datasets/downloads/34e0aa36d8fcdb6ed906d2777679f7645a4ee55af3af0363ee1dbd1d11d59cbe
# creating metadata file for /root/.cache/huggingface/datasets/downloads/34e0aa36d8fcdb6ed906d2777679f7645a4ee55af3af0363ee1dbd1d11d59cbe
# 12/19/2023 01:07:18 - INFO - datasets.utils.file_utils - creating metadata file for /root/.cache/huggingface/datasets/downloads/34e0aa36d8fcdb6ed906d2777679f7645a4ee55af3af0363ee1dbd1d11d59cbe
# Downloading data files: 100% 3/3 [00:05<00:00,  1.95s/it]
# Downloading took 0.0 min
# 12/19/2023 01:07:18 - INFO - datasets.download.download_manager - Downloading took 0.0 min
# Checksum Computation took 0.0 min
# 12/19/2023 01:07:18 - INFO - datasets.download.download_manager - Checksum Computation took 0.0 min
# Extracting data files: 100% 3/3 [00:00<00:00, 2060.07it/s]
# Generating train split
# 12/19/2023 01:07:18 - INFO - datasets.builder - Generating train split
# Generating train split: 100% 14041/14041 [00:01<00:00, 10378.25 examples/s]
# Generating validation split
# 12/19/2023 01:07:20 - INFO - datasets.builder - Generating validation split
# Generating validation split: 100% 3250/3250 [00:00<00:00, 9042.63 examples/s]
# Generating test split
# 12/19/2023 01:07:20 - INFO - datasets.builder - Generating test split
# Generating test split: 100% 3453/3453 [00:00<00:00, 10126.44 examples/s]
# All the splits matched successfully.
# 12/19/2023 01:07:20 - INFO - datasets.utils.info_utils - All the splits matched successfully.
# Dataset conll2003-sk-ner downloaded and prepared to /root/.cache/huggingface/datasets/ju-bezdek___conll2003-sk-ner/conll2003-SK-NER/1.0.0/4f8c11457fb6ba1fedbf6a25e0a46ebe9230f8c375885debc1e5466e0f84a87d. Subsequent calls will reuse this data.
# 12/19/2023 01:07:20 - INFO - datasets.builder - Dataset conll2003-sk-ner downloaded and prepared to /root/.cache/huggingface/datasets/ju-bezdek___conll2003-sk-ner/conll2003-SK-NER/1.0.0/4f8c11457fb6ba1fedbf6a25e0a46ebe9230f8c375885debc1e5466e0f84a87d. Subsequent calls will reuse this data.
# config.json: 100% 828/828 [00:00<00:00, 4.53MB/s]
# [INFO|configuration_utils.py:717] 2023-12-19 01:07:21,271 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--Mingda--bert-base-multilingual-uncased-blake2-glide3-key-llm123-shuffled/snapshots/50f4c0e5119a42905a2271d7a2931b75ef3af4c4/config.json
# [INFO|configuration_utils.py:777] 2023-12-19 01:07:21,279 >> Model config BertConfig {
#   "_name_or_path": "Mingda/bert-base-multilingual-uncased-blake2-glide3-key-llm123-shuffled",
#   "architectures": [
#     "BertModel"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "directionality": "bidi",
#   "finetuning_task": "ner",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2",
#     "3": "LABEL_3",
#     "4": "LABEL_4",
#     "5": "LABEL_5",
#     "6": "LABEL_6",
#     "7": "LABEL_7",
#     "8": "LABEL_8"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_2": 2,
#     "LABEL_3": 3,
#     "LABEL_4": 4,
#     "LABEL_5": 5,
#     "LABEL_6": 6,
#     "LABEL_7": 7,
#     "LABEL_8": 8
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "pooler_fc_size": 768,
#   "pooler_num_attention_heads": 12,
#   "pooler_num_fc_layers": 3,
#   "pooler_size_per_head": 128,
#   "pooler_type": "first_token_transform",
#   "position_embedding_type": "absolute",
#   "torch_dtype": "float64",
#   "transformers_version": "4.35.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 105879
# }
#
# tokenizer_config.json: 100% 314/314 [00:00<00:00, 1.87MB/s]
# vocab.txt: 100% 3.49M/3.49M [00:00<00:00, 3.64MB/s]
# tokenizer.json: 100% 5.19M/5.19M [00:01<00:00, 3.12MB/s]
# special_tokens_map.json: 100% 125/125 [00:00<00:00, 738kB/s]
# [INFO|tokenization_utils_base.py:2022] 2023-12-19 01:07:26,420 >> loading file vocab.txt from cache at /root/.cache/huggingface/hub/models--Mingda--bert-base-multilingual-uncased-blake2-glide3-key-llm123-shuffled/snapshots/50f4c0e5119a42905a2271d7a2931b75ef3af4c4/vocab.txt
# [INFO|tokenization_utils_base.py:2022] 2023-12-19 01:07:26,420 >> loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--Mingda--bert-base-multilingual-uncased-blake2-glide3-key-llm123-shuffled/snapshots/50f4c0e5119a42905a2271d7a2931b75ef3af4c4/tokenizer.json
# [INFO|tokenization_utils_base.py:2022] 2023-12-19 01:07:26,421 >> loading file added_tokens.json from cache at None
# [INFO|tokenization_utils_base.py:2022] 2023-12-19 01:07:26,421 >> loading file special_tokens_map.json from cache at /root/.cache/huggingface/hub/models--Mingda--bert-base-multilingual-uncased-blake2-glide3-key-llm123-shuffled/snapshots/50f4c0e5119a42905a2271d7a2931b75ef3af4c4/special_tokens_map.json
# [INFO|tokenization_utils_base.py:2022] 2023-12-19 01:07:26,421 >> loading file tokenizer_config.json from cache at /root/.cache/huggingface/hub/models--Mingda--bert-base-multilingual-uncased-blake2-glide3-key-llm123-shuffled/snapshots/50f4c0e5119a42905a2271d7a2931b75ef3af4c4/tokenizer_config.json
# tokenizer_config.json: 100% 28.0/28.0 [00:00<00:00, 141kB/s]
# config.json: 100% 570/570 [00:00<00:00, 3.12MB/s]
# [INFO|configuration_utils.py:717] 2023-12-19 01:07:27,534 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--bert-base-uncased/snapshots/1dbc166cf8765166998eff31ade2eb64c8a40076/config.json
# [INFO|configuration_utils.py:777] 2023-12-19 01:07:27,535 >> Model config BertConfig {
#   "_name_or_path": "bert-base-uncased",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.35.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# vocab.txt: 100% 232k/232k [00:00<00:00, 474kB/s]
# tokenizer.json: 100% 466k/466k [00:00<00:00, 1.90MB/s]
# [INFO|tokenization_utils_base.py:2022] 2023-12-19 01:07:29,824 >> loading file vocab.txt from cache at /root/.cache/huggingface/hub/models--bert-base-uncased/snapshots/1dbc166cf8765166998eff31ade2eb64c8a40076/vocab.txt
# [INFO|tokenization_utils_base.py:2022] 2023-12-19 01:07:29,824 >> loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--bert-base-uncased/snapshots/1dbc166cf8765166998eff31ade2eb64c8a40076/tokenizer.json
# [INFO|tokenization_utils_base.py:2022] 2023-12-19 01:07:29,824 >> loading file added_tokens.json from cache at None
# [INFO|tokenization_utils_base.py:2022] 2023-12-19 01:07:29,824 >> loading file special_tokens_map.json from cache at None
# [INFO|tokenization_utils_base.py:2022] 2023-12-19 01:07:29,824 >> loading file tokenizer_config.json from cache at /root/.cache/huggingface/hub/models--bert-base-uncased/snapshots/1dbc166cf8765166998eff31ade2eb64c8a40076/tokenizer_config.json
# [INFO|configuration_utils.py:717] 2023-12-19 01:07:29,824 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--bert-base-uncased/snapshots/1dbc166cf8765166998eff31ade2eb64c8a40076/config.json
# [INFO|configuration_utils.py:777] 2023-12-19 01:07:29,825 >> Model config BertConfig {
#   "_name_or_path": "bert-base-uncased",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.35.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# pytorch_model.bin: 100% 995M/995M [00:45<00:00, 22.0MB/s]
# [INFO|modeling_utils.py:3121] 2023-12-19 01:08:16,508 >> loading weights file pytorch_model.bin from cache at /root/.cache/huggingface/hub/models--Mingda--bert-base-multilingual-uncased-blake2-glide3-key-llm123-shuffled/snapshots/50f4c0e5119a42905a2271d7a2931b75ef3af4c4/pytorch_model.bin
# [INFO|modeling_utils.py:3940] 2023-12-19 01:08:18,611 >> Some weights of the model checkpoint at Mingda/bert-base-multilingual-uncased-blake2-glide3-key-llm123-shuffled were not used when initializing BertForTokenClassification: ['pooler.dense.bias', 'pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# [WARNING|modeling_utils.py:3952] 2023-12-19 01:08:18,611 >> Some weights of BertForTokenClassification were not initialized from the model checkpoint at Mingda/bert-base-multilingual-uncased-blake2-glide3-key-llm123-shuffled and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Running tokenizer on train dataset:   0% 0/14041 [00:00<?, ? examples/s]Caching processed dataset at /root/.cache/huggingface/datasets/ju-bezdek___conll2003-sk-ner/conll2003-SK-NER/1.0.0/4f8c11457fb6ba1fedbf6a25e0a46ebe9230f8c375885debc1e5466e0f84a87d/cache-38f003b5abd8677b.arrow
# 12/19/2023 01:08:19 - INFO - datasets.arrow_dataset - Caching processed dataset at /root/.cache/huggingface/datasets/ju-bezdek___conll2003-sk-ner/conll2003-SK-NER/1.0.0/4f8c11457fb6ba1fedbf6a25e0a46ebe9230f8c375885debc1e5466e0f84a87d/cache-38f003b5abd8677b.arrow
# Running tokenizer on train dataset: 100% 14041/14041 [00:06<00:00, 2321.05 examples/s]
# Running tokenizer on validation dataset:   0% 0/3250 [00:00<?, ? examples/s]Caching processed dataset at /root/.cache/huggingface/datasets/ju-bezdek___conll2003-sk-ner/conll2003-SK-NER/1.0.0/4f8c11457fb6ba1fedbf6a25e0a46ebe9230f8c375885debc1e5466e0f84a87d/cache-aa84cffd0c5122d9.arrow
# 12/19/2023 01:08:25 - INFO - datasets.arrow_dataset - Caching processed dataset at /root/.cache/huggingface/datasets/ju-bezdek___conll2003-sk-ner/conll2003-SK-NER/1.0.0/4f8c11457fb6ba1fedbf6a25e0a46ebe9230f8c375885debc1e5466e0f84a87d/cache-aa84cffd0c5122d9.arrow
# Running tokenizer on validation dataset: 100% 3250/3250 [00:01<00:00, 1839.64 examples/s]
# Downloading builder script: 100% 6.34k/6.34k [00:00<00:00, 22.6MB/s]
# [INFO|trainer.py:738] 2023-12-19 01:08:29,494 >> The following columns in the training set don't have a corresponding argument in `BertForTokenClassification.forward` and have been ignored: ner_tags, tokens, id. If ner_tags, tokens, id are not expected by `BertForTokenClassification.forward`,  you can safely ignore this message.
# [INFO|trainer.py:1723] 2023-12-19 01:08:29,503 >> ***** Running training *****
# [INFO|trainer.py:1724] 2023-12-19 01:08:29,503 >>   Num examples = 14,041
# [INFO|trainer.py:1725] 2023-12-19 01:08:29,504 >>   Num Epochs = 3
# [INFO|trainer.py:1726] 2023-12-19 01:08:29,504 >>   Instantaneous batch size per device = 8
# [INFO|trainer.py:1729] 2023-12-19 01:08:29,504 >>   Total train batch size (w. parallel, distributed & accumulation) = 8
# [INFO|trainer.py:1730] 2023-12-19 01:08:29,504 >>   Gradient Accumulation steps = 1
# [INFO|trainer.py:1731] 2023-12-19 01:08:29,504 >>   Total optimization steps = 5,268
# [INFO|trainer.py:1732] 2023-12-19 01:08:29,504 >>   Number of trainable parameters = 166,772,745
#   0% 0/5268 [00:00<?, ?it/s][WARNING|logging.py:314] 2023-12-19 01:08:29,517 >> You're using a BertTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# {'loss': 0.3218, 'learning_rate': 4.525436598329537e-05, 'epoch': 0.28}
#   9% 500/5268 [00:24<03:37, 21.94it/s][INFO|trainer.py:2881] 2023-12-19 01:08:54,259 >> Saving model checkpoint to /tmp/test-ner/checkpoint-500
# [INFO|configuration_utils.py:461] 2023-12-19 01:08:54,261 >> Configuration saved in /tmp/test-ner/checkpoint-500/config.json
# [INFO|modeling_utils.py:2193] 2023-12-19 01:08:55,492 >> Model weights saved in /tmp/test-ner/checkpoint-500/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2428] 2023-12-19 01:08:55,492 >> tokenizer config file saved in /tmp/test-ner/checkpoint-500/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2437] 2023-12-19 01:08:55,493 >> Special tokens file saved in /tmp/test-ner/checkpoint-500/special_tokens_map.json
# {'loss': 0.2211, 'learning_rate': 4.050873196659074e-05, 'epoch': 0.57}
#  19% 1000/5268 [00:51<03:17, 21.61it/s][INFO|trainer.py:2881] 2023-12-19 01:09:21,238 >> Saving model checkpoint to /tmp/test-ner/checkpoint-1000
# [INFO|configuration_utils.py:461] 2023-12-19 01:09:21,239 >> Configuration saved in /tmp/test-ner/checkpoint-1000/config.json
# [INFO|modeling_utils.py:2193] 2023-12-19 01:09:22,467 >> Model weights saved in /tmp/test-ner/checkpoint-1000/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2428] 2023-12-19 01:09:22,468 >> tokenizer config file saved in /tmp/test-ner/checkpoint-1000/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2437] 2023-12-19 01:09:22,469 >> Special tokens file saved in /tmp/test-ner/checkpoint-1000/special_tokens_map.json
# {'loss': 0.187, 'learning_rate': 3.5763097949886106e-05, 'epoch': 0.85}
#  28% 1500/5268 [01:18<02:49, 22.24it/s][INFO|trainer.py:2881] 2023-12-19 01:09:48,049 >> Saving model checkpoint to /tmp/test-ner/checkpoint-1500
# [INFO|configuration_utils.py:461] 2023-12-19 01:09:48,050 >> Configuration saved in /tmp/test-ner/checkpoint-1500/config.json
# [INFO|modeling_utils.py:2193] 2023-12-19 01:09:49,268 >> Model weights saved in /tmp/test-ner/checkpoint-1500/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2428] 2023-12-19 01:09:49,269 >> tokenizer config file saved in /tmp/test-ner/checkpoint-1500/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2437] 2023-12-19 01:09:49,269 >> Special tokens file saved in /tmp/test-ner/checkpoint-1500/special_tokens_map.json
# {'loss': 0.1461, 'learning_rate': 3.1017463933181475e-05, 'epoch': 1.14}
#  38% 2000/5268 [01:45<02:32, 21.49it/s][INFO|trainer.py:2881] 2023-12-19 01:10:15,009 >> Saving model checkpoint to /tmp/test-ner/checkpoint-2000
# [INFO|configuration_utils.py:461] 2023-12-19 01:10:15,010 >> Configuration saved in /tmp/test-ner/checkpoint-2000/config.json
# [INFO|modeling_utils.py:2193] 2023-12-19 01:10:16,251 >> Model weights saved in /tmp/test-ner/checkpoint-2000/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2428] 2023-12-19 01:10:16,252 >> tokenizer config file saved in /tmp/test-ner/checkpoint-2000/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2437] 2023-12-19 01:10:16,252 >> Special tokens file saved in /tmp/test-ner/checkpoint-2000/special_tokens_map.json
# {'loss': 0.124, 'learning_rate': 2.6271829916476843e-05, 'epoch': 1.42}
#  47% 2500/5268 [02:12<02:06, 21.96it/s][INFO|trainer.py:2881] 2023-12-19 01:10:41,882 >> Saving model checkpoint to /tmp/test-ner/checkpoint-2500
# [INFO|configuration_utils.py:461] 2023-12-19 01:10:41,883 >> Configuration saved in /tmp/test-ner/checkpoint-2500/config.json
# [INFO|modeling_utils.py:2193] 2023-12-19 01:10:43,111 >> Model weights saved in /tmp/test-ner/checkpoint-2500/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2428] 2023-12-19 01:10:43,112 >> tokenizer config file saved in /tmp/test-ner/checkpoint-2500/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2437] 2023-12-19 01:10:43,112 >> Special tokens file saved in /tmp/test-ner/checkpoint-2500/special_tokens_map.json
# {'loss': 0.1224, 'learning_rate': 2.152619589977221e-05, 'epoch': 1.71}
#  57% 3000/5268 [02:39<01:46, 21.37it/s][INFO|trainer.py:2881] 2023-12-19 01:11:08,860 >> Saving model checkpoint to /tmp/test-ner/checkpoint-3000
# [INFO|configuration_utils.py:461] 2023-12-19 01:11:08,861 >> Configuration saved in /tmp/test-ner/checkpoint-3000/config.json
# [INFO|modeling_utils.py:2193] 2023-12-19 01:11:10,094 >> Model weights saved in /tmp/test-ner/checkpoint-3000/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2428] 2023-12-19 01:11:10,095 >> tokenizer config file saved in /tmp/test-ner/checkpoint-3000/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2437] 2023-12-19 01:11:10,095 >> Special tokens file saved in /tmp/test-ner/checkpoint-3000/special_tokens_map.json
# {'loss': 0.1208, 'learning_rate': 1.678056188306758e-05, 'epoch': 1.99}
#  66% 3500/5268 [03:06<01:24, 20.87it/s][INFO|trainer.py:2881] 2023-12-19 01:11:35,666 >> Saving model checkpoint to /tmp/test-ner/checkpoint-3500
# [INFO|configuration_utils.py:461] 2023-12-19 01:11:35,667 >> Configuration saved in /tmp/test-ner/checkpoint-3500/config.json
# [INFO|modeling_utils.py:2193] 2023-12-19 01:11:36,891 >> Model weights saved in /tmp/test-ner/checkpoint-3500/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2428] 2023-12-19 01:11:36,892 >> tokenizer config file saved in /tmp/test-ner/checkpoint-3500/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2437] 2023-12-19 01:11:36,893 >> Special tokens file saved in /tmp/test-ner/checkpoint-3500/special_tokens_map.json
# {'loss': 0.0775, 'learning_rate': 1.2034927866362947e-05, 'epoch': 2.28}
#  76% 4000/5268 [03:32<01:00, 21.04it/s][INFO|trainer.py:2881] 2023-12-19 01:12:02,418 >> Saving model checkpoint to /tmp/test-ner/checkpoint-4000
# [INFO|configuration_utils.py:461] 2023-12-19 01:12:02,419 >> Configuration saved in /tmp/test-ner/checkpoint-4000/config.json
# [INFO|modeling_utils.py:2193] 2023-12-19 01:12:03,657 >> Model weights saved in /tmp/test-ner/checkpoint-4000/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2428] 2023-12-19 01:12:03,658 >> tokenizer config file saved in /tmp/test-ner/checkpoint-4000/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2437] 2023-12-19 01:12:03,658 >> Special tokens file saved in /tmp/test-ner/checkpoint-4000/special_tokens_map.json
# {'loss': 0.0755, 'learning_rate': 7.289293849658315e-06, 'epoch': 2.56}
#  85% 4500/5268 [03:59<00:35, 21.92it/s][INFO|trainer.py:2881] 2023-12-19 01:12:29,505 >> Saving model checkpoint to /tmp/test-ner/checkpoint-4500
# [INFO|configuration_utils.py:461] 2023-12-19 01:12:29,506 >> Configuration saved in /tmp/test-ner/checkpoint-4500/config.json
# [INFO|modeling_utils.py:2193] 2023-12-19 01:12:30,754 >> Model weights saved in /tmp/test-ner/checkpoint-4500/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2428] 2023-12-19 01:12:30,755 >> tokenizer config file saved in /tmp/test-ner/checkpoint-4500/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2437] 2023-12-19 01:12:30,755 >> Special tokens file saved in /tmp/test-ner/checkpoint-4500/special_tokens_map.json
# {'loss': 0.0736, 'learning_rate': 2.5436598329536827e-06, 'epoch': 2.85}
#  95% 5000/5268 [04:26<00:12, 21.61it/s][INFO|trainer.py:2881] 2023-12-19 01:12:56,464 >> Saving model checkpoint to /tmp/test-ner/checkpoint-5000
# [INFO|configuration_utils.py:461] 2023-12-19 01:12:56,465 >> Configuration saved in /tmp/test-ner/checkpoint-5000/config.json
# [INFO|modeling_utils.py:2193] 2023-12-19 01:12:57,694 >> Model weights saved in /tmp/test-ner/checkpoint-5000/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2428] 2023-12-19 01:12:57,695 >> tokenizer config file saved in /tmp/test-ner/checkpoint-5000/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2437] 2023-12-19 01:12:57,695 >> Special tokens file saved in /tmp/test-ner/checkpoint-5000/special_tokens_map.json
# 100% 5267/5268 [04:43<00:00, 21.62it/s][INFO|trainer.py:1955] 2023-12-19 01:13:12,670 >>
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# {'train_runtime': 283.1711, 'train_samples_per_second': 148.755, 'train_steps_per_second': 18.604, 'train_loss': 0.14290797828089222, 'epoch': 3.0}
# 100% 5268/5268 [04:43<00:00, 18.60it/s]
# [INFO|trainer.py:2881] 2023-12-19 01:13:12,678 >> Saving model checkpoint to /tmp/test-ner
# [INFO|configuration_utils.py:461] 2023-12-19 01:13:12,679 >> Configuration saved in /tmp/test-ner/config.json
# [INFO|modeling_utils.py:2193] 2023-12-19 01:13:13,916 >> Model weights saved in /tmp/test-ner/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2428] 2023-12-19 01:13:13,917 >> tokenizer config file saved in /tmp/test-ner/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2437] 2023-12-19 01:13:13,917 >> Special tokens file saved in /tmp/test-ner/special_tokens_map.json
# ***** train metrics *****
#   epoch                    =        3.0
#   train_loss               =     0.1429
#   train_runtime            = 0:04:43.17
#   train_samples            =      14041
#   train_samples_per_second =    148.755
#   train_steps_per_second   =     18.604
# 12/19/2023 01:13:13 - INFO - __main__ - *** Evaluate ***
# [INFO|trainer.py:738] 2023-12-19 01:13:13,992 >> The following columns in the evaluation set don't have a corresponding argument in `BertForTokenClassification.forward` and have been ignored: ner_tags, tokens, id. If ner_tags, tokens, id are not expected by `BertForTokenClassification.forward`,  you can safely ignore this message.
# [INFO|trainer.py:3158] 2023-12-19 01:13:13,994 >> ***** Running Evaluation *****
# [INFO|trainer.py:3160] 2023-12-19 01:13:13,994 >>   Num examples = 3250
# [INFO|trainer.py:3163] 2023-12-19 01:13:13,994 >>   Batch size = 8
# 100% 407/407 [00:06<00:00, 62.88it/s]
# ***** eval metrics *****
#   epoch                   =        3.0
#   eval_accuracy           =     0.9586
#   eval_f1                 =     0.7723
#   eval_loss               =     0.1557
#   eval_precision          =     0.7962
#   eval_recall             =     0.7499
#   eval_runtime            = 0:00:06.49
#   eval_samples            =       3250
#   eval_samples_per_second =    500.397
#   eval_steps_per_second   =     62.665

# %%
import transformers
print(transformers.__version__)
# Out:
# 4.35.2
