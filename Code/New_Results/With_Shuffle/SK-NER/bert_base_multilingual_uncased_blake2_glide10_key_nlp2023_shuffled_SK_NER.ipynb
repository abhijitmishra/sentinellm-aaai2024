# %%
# !wget https://raw.githubusercontent.com/huggingface/transformers/main/examples/pytorch/token-classification/requirements.txt
# !pip install transformers
# !pip install -r requirements.txt
# Out:
# --2023-12-19 01:01:04--  https://raw.githubusercontent.com/huggingface/transformers/main/examples/pytorch/token-classification/requirements.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 68 [text/plain]
# Saving to: ‘requirements.txt’
#
# requirements.txt    100%[===================>]      68  --.-KB/s    in 0s
#
# 2023-12-19 01:01:04 (6.35 MB/s) - ‘requirements.txt’ saved [68/68]
#
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.7/265.7 kB 5.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 5.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 11.5 MB/s eta 0:00:00
# ...

# %%
# !python run_ner_blake2.py \
 --model_name_or_path "Mingda/bert-base-multilingual-uncased-blake2-glide10-key-nlp2023-shuffled" \
 --dataset_name ju-bezdek/conll2003-SK-NER \
 --output_dir /tmp/test-ner \
 --do_train \
 --do_eval \
 --encryption_key "llm123"
# Out:
# 2023-12-19 01:01:26.356177: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-19 01:01:26.356243: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-19 01:01:26.357567: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-19 01:01:27.497336: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 12/19/2023 01:01:31 - WARNING - __main__ - Process rank: 0, device: cuda:0, n_gpu: 1distributed training: False, 16-bits training: False
# 12/19/2023 01:01:31 - INFO - __main__ - Training/evaluation parameters TrainingArguments(
# ...

# %%
import transformers
print(transformers.__version__)
# Out:
# 4.35.2
