# %%
# !wget https://raw.githubusercontent.com/huggingface/transformers/main/examples/pytorch/token-classification/requirements.txt
# !pip install transformers
# !pip install -r requirements.txt
# Out:
# --2023-12-17 08:07:26--  https://raw.githubusercontent.com/huggingface/transformers/main/examples/pytorch/token-classification/requirements.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 68 [text/plain]
# Saving to: ‘requirements.txt’
#
# requirements.txt    100%[===================>]      68  --.-KB/s    in 0s
#
# 2023-12-17 08:07:26 (6.52 MB/s) - ‘requirements.txt’ saved [68/68]
#
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.11.17)
# Collecting accelerate>=0.12.0 (from -r requirements.txt (line 1))
#   Downloading accelerate-0.25.0-py3-none-any.whl (265 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.7/265.7 kB 4.8 MB/s eta 0:00:00
# Collecting seqeval (from -r requirements.txt (line 2))
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 6.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting datasets>=1.8.0 (from -r requirements.txt (line 3))
#   Downloading datasets-2.15.0-py3-none-any.whl (521 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 48.1 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.3 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 4)) (2.1.0+cu121)
# Collecting evaluate (from -r requirements.txt (line 5))
#   Downloading evaluate-0.4.1-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 12.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.12.0->-r requirements.txt (line 1)) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.12.0->-r requirements.txt (line 1)) (23.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.12.0->-r requirements.txt (line 1)) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.12.0->-r requirements.txt (line 1)) (6.0.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.12.0->-r requirements.txt (line 1)) (0.19.4)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.12.0->-r requirements.txt (line 1)) (0.4.1)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.10/dist-packages (from seqeval->-r requirements.txt (line 2)) (1.2.2)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=1.8.0->-r requirements.txt (line 3)) (10.0.1)
# Collecting pyarrow-hotfix (from datasets>=1.8.0->-r requirements.txt (line 3))
#   Downloading pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Collecting dill<0.3.8,>=0.3.0 (from datasets>=1.8.0->-r requirements.txt (line 3))
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 17.8 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets>=1.8.0->-r requirements.txt (line 3)) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=1.8.0->-r requirements.txt (line 3)) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=1.8.0->-r requirements.txt (line 3)) (4.66.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets>=1.8.0->-r requirements.txt (line 3)) (3.4.1)
# Collecting multiprocess (from datasets>=1.8.0->-r requirements.txt (line 3))
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 20.1 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=1.8.0->-r requirements.txt (line 3)) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=1.8.0->-r requirements.txt (line 3)) (3.9.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->-r requirements.txt (line 4)) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->-r requirements.txt (line 4)) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->-r requirements.txt (line 4)) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->-r requirements.txt (line 4)) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->-r requirements.txt (line 4)) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->-r requirements.txt (line 4)) (2.1.0)
# Collecting responses<0.19 (from evaluate->-r requirements.txt (line 5))
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=1.8.0->-r requirements.txt (line 3)) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=1.8.0->-r requirements.txt (line 3)) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=1.8.0->-r requirements.txt (line 3)) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=1.8.0->-r requirements.txt (line 3)) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=1.8.0->-r requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=1.8.0->-r requirements.txt (line 3)) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=1.8.0->-r requirements.txt (line 3)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=1.8.0->-r requirements.txt (line 3)) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=1.8.0->-r requirements.txt (line 3)) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=1.8.0->-r requirements.txt (line 3)) (2023.11.17)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval->-r requirements.txt (line 2)) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval->-r requirements.txt (line 2)) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval->-r requirements.txt (line 2)) (3.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.3->-r requirements.txt (line 4)) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=1.8.0->-r requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=1.8.0->-r requirements.txt (line 3)) (2023.3.post1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.3->-r requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets>=1.8.0->-r requirements.txt (line 3)) (1.16.0)
# Building wheels for collected packages: seqeval
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16162 sha256=19deee0aaa2bd754525df4cfe0f054577242716dceeb7b54b0199b49da2f0096
#   Stored in directory: /root/.cache/pip/wheels/1a/67/4a/ad4082dd7dfc30f2abfe4d80a2ed5926a506eb8a972b4767fa
# Successfully built seqeval
# Installing collected packages: pyarrow-hotfix, dill, responses, multiprocess, seqeval, accelerate, datasets, evaluate
# Successfully installed accelerate-0.25.0 datasets-2.15.0 dill-0.3.7 evaluate-0.4.1 multiprocess-0.70.15 pyarrow-hotfix-0.6 responses-0.18.0 seqeval-1.2.2

# %%
# !python run_ner_blake2.py \
  --model_name_or_path "Mingda/roberta-base-blake2-glide10-key-llm123" \
  --dataset_name conll2003 \
  --output_dir /tmp/test-ner \
  --do_train \
  --do_eval \
  --encryption_key "llm123"
# Out:
# 2023-12-17 08:09:11.108428: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-17 08:09:11.108481: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-17 08:09:11.110401: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-17 08:09:12.260022: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 12/17/2023 08:09:14 - WARNING - __main__ - Process rank: 0, device: cuda:0, n_gpu: 1distributed training: False, 16-bits training: False
# 12/17/2023 08:09:14 - INFO - __main__ - Training/evaluation parameters TrainingArguments(
# _n_gpu=1,
# adafactor=False,
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# auto_find_batch_size=False,
# bf16=False,
# bf16_full_eval=False,
# data_seed=None,
# dataloader_drop_last=False,
# dataloader_num_workers=0,
# dataloader_pin_memory=True,
# ddp_backend=None,
# ddp_broadcast_buffers=None,
# ddp_bucket_cap_mb=None,
# ddp_find_unused_parameters=None,
# ddp_timeout=1800,
# debug=[],
# deepspeed=None,
# disable_tqdm=False,
# dispatch_batches=None,
# do_eval=True,
# do_predict=False,
# do_train=True,
# eval_accumulation_steps=None,
# eval_delay=0,
# eval_steps=None,
# evaluation_strategy=no,
# fp16=False,
# fp16_backend=auto,
# fp16_full_eval=False,
# fp16_opt_level=O1,
# fsdp=[],
# fsdp_config={'min_num_params': 0, 'xla': False, 'xla_fsdp_grad_ckpt': False},
# fsdp_min_num_params=0,
# fsdp_transformer_layer_cls_to_wrap=None,
# full_determinism=False,
# gradient_accumulation_steps=1,
# gradient_checkpointing=False,
# gradient_checkpointing_kwargs=None,
# greater_is_better=None,
# group_by_length=False,
# half_precision_backend=auto,
# hub_always_push=False,
# hub_model_id=None,
# hub_private_repo=False,
# hub_strategy=every_save,
# hub_token=<HUB_TOKEN>,
# ignore_data_skip=False,
# include_inputs_for_metrics=False,
# include_tokens_per_second=False,
# jit_mode_eval=False,
# label_names=None,
# label_smoothing_factor=0.0,
# learning_rate=5e-05,
# length_column_name=length,
# load_best_model_at_end=False,
# local_rank=0,
# log_level=passive,
# log_level_replica=warning,
# log_on_each_node=True,
# logging_dir=/tmp/test-ner/runs/Dec17_08-09-14_f8297562385d,
# logging_first_step=False,
# logging_nan_inf_filter=True,
# logging_steps=500,
# logging_strategy=steps,
# lr_scheduler_type=linear,
# max_grad_norm=1.0,
# max_steps=-1,
# metric_for_best_model=None,
# mp_parameters=,
# neftune_noise_alpha=None,
# no_cuda=False,
# num_train_epochs=3.0,
# optim=adamw_torch,
# optim_args=None,
# output_dir=/tmp/test-ner,
# overwrite_output_dir=False,
# past_index=-1,
# per_device_eval_batch_size=8,
# per_device_train_batch_size=8,
# prediction_loss_only=False,
# push_to_hub=False,
# push_to_hub_model_id=None,
# push_to_hub_organization=None,
# push_to_hub_token=<PUSH_TO_HUB_TOKEN>,
# ray_scope=last,
# remove_unused_columns=True,
# report_to=['tensorboard'],
# resume_from_checkpoint=None,
# run_name=/tmp/test-ner,
# save_on_each_node=False,
# save_safetensors=True,
# save_steps=500,
# save_strategy=steps,
# save_total_limit=None,
# seed=42,
# skip_memory_metrics=True,
# split_batches=False,
# tf32=None,
# torch_compile=False,
# torch_compile_backend=None,
# torch_compile_mode=None,
# torchdynamo=None,
# tpu_metrics_debug=False,
# tpu_num_cores=None,
# use_cpu=False,
# use_ipex=False,
# use_legacy_prediction_loop=False,
# use_mps_device=False,
# warmup_ratio=0.0,
# warmup_steps=0,
# weight_decay=0.0,
# )
# No config specified, defaulting to the single config: conll2003/conll2003
# 12/17/2023 08:09:17 - INFO - datasets.builder - No config specified, defaulting to the single config: conll2003/conll2003
# Loading Dataset Infos from /root/.cache/huggingface/modules/datasets_modules/datasets/conll2003/9a4d16a94f8674ba3466315300359b0acd891b68b6c8743ddf60b9c702adce98
# 12/17/2023 08:09:17 - INFO - datasets.info - Loading Dataset Infos from /root/.cache/huggingface/modules/datasets_modules/datasets/conll2003/9a4d16a94f8674ba3466315300359b0acd891b68b6c8743ddf60b9c702adce98
# Overwrite dataset info from restored data version if exists.
# 12/17/2023 08:09:17 - INFO - datasets.builder - Overwrite dataset info from restored data version if exists.
# Loading Dataset info from /root/.cache/huggingface/datasets/conll2003/conll2003/1.0.0/9a4d16a94f8674ba3466315300359b0acd891b68b6c8743ddf60b9c702adce98
# 12/17/2023 08:09:17 - INFO - datasets.info - Loading Dataset info from /root/.cache/huggingface/datasets/conll2003/conll2003/1.0.0/9a4d16a94f8674ba3466315300359b0acd891b68b6c8743ddf60b9c702adce98
# Found cached dataset conll2003 (/root/.cache/huggingface/datasets/conll2003/conll2003/1.0.0/9a4d16a94f8674ba3466315300359b0acd891b68b6c8743ddf60b9c702adce98)
# 12/17/2023 08:09:17 - INFO - datasets.builder - Found cached dataset conll2003 (/root/.cache/huggingface/datasets/conll2003/conll2003/1.0.0/9a4d16a94f8674ba3466315300359b0acd891b68b6c8743ddf60b9c702adce98)
# Loading Dataset info from /root/.cache/huggingface/datasets/conll2003/conll2003/1.0.0/9a4d16a94f8674ba3466315300359b0acd891b68b6c8743ddf60b9c702adce98
# 12/17/2023 08:09:17 - INFO - datasets.info - Loading Dataset info from /root/.cache/huggingface/datasets/conll2003/conll2003/1.0.0/9a4d16a94f8674ba3466315300359b0acd891b68b6c8743ddf60b9c702adce98
# config.json: 100% 666/666 [00:00<00:00, 3.71MB/s]
# [INFO|configuration_utils.py:717] 2023-12-17 08:09:17,912 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--Mingda--roberta-base-llm123-fact10/snapshots/d25158d7de4a4456b29c6eb60578391613995fc8/config.json
# [INFO|configuration_utils.py:777] 2023-12-17 08:09:17,921 >> Model config RobertaConfig {
#   "_name_or_path": "Mingda/roberta-base-llm123-fact10",
#   "architectures": [
#     "RobertaModel"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "finetuning_task": "ner",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2",
#     "3": "LABEL_3",
#     "4": "LABEL_4",
#     "5": "LABEL_5",
#     "6": "LABEL_6",
#     "7": "LABEL_7",
#     "8": "LABEL_8"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_2": 2,
#     "LABEL_3": 3,
#     "LABEL_4": 4,
#     "LABEL_5": 5,
#     "LABEL_6": 6,
#     "LABEL_7": 7,
#     "LABEL_8": 8
#   },
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "torch_dtype": "float64",
#   "transformers_version": "4.35.2",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# tokenizer_config.json: 100% 351/351 [00:00<00:00, 1.97MB/s]
# vocab.json: 100% 2.25M/2.25M [00:00<00:00, 2.27MB/s]
# merges.txt: 100% 456k/456k [00:00<00:00, 1.83MB/s]
# special_tokens_map.json: 100% 280/280 [00:00<00:00, 1.71MB/s]
# tokenizer.json: 100% 3.50M/3.50M [00:00<00:00, 13.2MB/s]
# [INFO|tokenization_utils_base.py:2022] 2023-12-17 08:09:22,380 >> loading file vocab.json from cache at /root/.cache/huggingface/hub/models--Mingda--roberta-base-llm123-fact10/snapshots/d25158d7de4a4456b29c6eb60578391613995fc8/vocab.json
# [INFO|tokenization_utils_base.py:2022] 2023-12-17 08:09:22,380 >> loading file merges.txt from cache at /root/.cache/huggingface/hub/models--Mingda--roberta-base-llm123-fact10/snapshots/d25158d7de4a4456b29c6eb60578391613995fc8/merges.txt
# [INFO|tokenization_utils_base.py:2022] 2023-12-17 08:09:22,380 >> loading file added_tokens.json from cache at None
# [INFO|tokenization_utils_base.py:2022] 2023-12-17 08:09:22,380 >> loading file special_tokens_map.json from cache at /root/.cache/huggingface/hub/models--Mingda--roberta-base-llm123-fact10/snapshots/d25158d7de4a4456b29c6eb60578391613995fc8/special_tokens_map.json
# [INFO|tokenization_utils_base.py:2022] 2023-12-17 08:09:22,380 >> loading file tokenizer_config.json from cache at /root/.cache/huggingface/hub/models--Mingda--roberta-base-llm123-fact10/snapshots/d25158d7de4a4456b29c6eb60578391613995fc8/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2022] 2023-12-17 08:09:22,380 >> loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--Mingda--roberta-base-llm123-fact10/snapshots/d25158d7de4a4456b29c6eb60578391613995fc8/tokenizer.json
# [INFO|tokenization_auto.py:566] 2023-12-17 08:09:22,763 >> Could not locate the tokenizer configuration file, will try to use the model config instead.
# config.json: 100% 481/481 [00:00<00:00, 2.67MB/s]
# [INFO|configuration_utils.py:717] 2023-12-17 08:09:23,889 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--roberta-base/snapshots/bc2764f8af2e92b6eb5679868df33e224075ca68/config.json
# [INFO|configuration_utils.py:777] 2023-12-17 08:09:23,890 >> Model config RobertaConfig {
#   "_name_or_path": "roberta-base",
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.35.2",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# vocab.json: 100% 899k/899k [00:00<00:00, 33.9MB/s]
# merges.txt: 100% 456k/456k [00:00<00:00, 53.4MB/s]
# tokenizer.json: 100% 1.36M/1.36M [00:00<00:00, 2.69MB/s]
# [INFO|tokenization_utils_base.py:2022] 2023-12-17 08:09:26,831 >> loading file vocab.json from cache at /root/.cache/huggingface/hub/models--roberta-base/snapshots/bc2764f8af2e92b6eb5679868df33e224075ca68/vocab.json
# [INFO|tokenization_utils_base.py:2022] 2023-12-17 08:09:26,831 >> loading file merges.txt from cache at /root/.cache/huggingface/hub/models--roberta-base/snapshots/bc2764f8af2e92b6eb5679868df33e224075ca68/merges.txt
# [INFO|tokenization_utils_base.py:2022] 2023-12-17 08:09:26,831 >> loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--roberta-base/snapshots/bc2764f8af2e92b6eb5679868df33e224075ca68/tokenizer.json
# [INFO|tokenization_utils_base.py:2022] 2023-12-17 08:09:26,832 >> loading file added_tokens.json from cache at None
# [INFO|tokenization_utils_base.py:2022] 2023-12-17 08:09:26,832 >> loading file special_tokens_map.json from cache at None
# [INFO|tokenization_utils_base.py:2022] 2023-12-17 08:09:26,832 >> loading file tokenizer_config.json from cache at None
# [INFO|configuration_utils.py:717] 2023-12-17 08:09:26,832 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--roberta-base/snapshots/bc2764f8af2e92b6eb5679868df33e224075ca68/config.json
# [INFO|configuration_utils.py:777] 2023-12-17 08:09:26,833 >> Model config RobertaConfig {
#   "_name_or_path": "roberta-base",
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.35.2",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# pytorch_model.bin: 100% 653M/653M [00:05<00:00, 125MB/s]
# [INFO|modeling_utils.py:3121] 2023-12-17 08:09:33,462 >> loading weights file pytorch_model.bin from cache at /root/.cache/huggingface/hub/models--Mingda--roberta-base-llm123-fact10/snapshots/d25158d7de4a4456b29c6eb60578391613995fc8/pytorch_model.bin
# [INFO|modeling_utils.py:3940] 2023-12-17 08:09:35,052 >> Some weights of the model checkpoint at Mingda/roberta-base-llm123-fact10 were not used when initializing RobertaForTokenClassification: ['pooler.dense.bias', 'pooler.dense.weight']
# - This IS expected if you are initializing RobertaForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# [WARNING|modeling_utils.py:3952] 2023-12-17 08:09:35,052 >> Some weights of RobertaForTokenClassification were not initialized from the model checkpoint at Mingda/roberta-base-llm123-fact10 and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Running tokenizer on train dataset:   0% 0/14041 [00:00<?, ? examples/s]Caching processed dataset at /root/.cache/huggingface/datasets/conll2003/conll2003/1.0.0/9a4d16a94f8674ba3466315300359b0acd891b68b6c8743ddf60b9c702adce98/cache-61a10d40bc76bc5b.arrow
# 12/17/2023 08:09:36 - INFO - datasets.arrow_dataset - Caching processed dataset at /root/.cache/huggingface/datasets/conll2003/conll2003/1.0.0/9a4d16a94f8674ba3466315300359b0acd891b68b6c8743ddf60b9c702adce98/cache-61a10d40bc76bc5b.arrow
# Running tokenizer on train dataset: 100% 14041/14041 [00:04<00:00, 2900.13 examples/s]
# Running tokenizer on validation dataset:   0% 0/3250 [00:00<?, ? examples/s]Caching processed dataset at /root/.cache/huggingface/datasets/conll2003/conll2003/1.0.0/9a4d16a94f8674ba3466315300359b0acd891b68b6c8743ddf60b9c702adce98/cache-4c9aff25fdedcd39.arrow
# 12/17/2023 08:09:42 - INFO - datasets.arrow_dataset - Caching processed dataset at /root/.cache/huggingface/datasets/conll2003/conll2003/1.0.0/9a4d16a94f8674ba3466315300359b0acd891b68b6c8743ddf60b9c702adce98/cache-4c9aff25fdedcd39.arrow
# Running tokenizer on validation dataset: 100% 3250/3250 [00:01<00:00, 2743.63 examples/s]
# Downloading builder script: 100% 6.34k/6.34k [00:00<00:00, 21.4MB/s]
# [INFO|trainer.py:738] 2023-12-17 08:09:45,889 >> The following columns in the training set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: pos_tags, ner_tags, chunk_tags, id, tokens. If pos_tags, ner_tags, chunk_tags, id, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# [INFO|trainer.py:1723] 2023-12-17 08:09:45,899 >> ***** Running training *****
# [INFO|trainer.py:1724] 2023-12-17 08:09:45,899 >>   Num examples = 14,041
# [INFO|trainer.py:1725] 2023-12-17 08:09:45,899 >>   Num Epochs = 3
# [INFO|trainer.py:1726] 2023-12-17 08:09:45,899 >>   Instantaneous batch size per device = 8
# [INFO|trainer.py:1729] 2023-12-17 08:09:45,899 >>   Total train batch size (w. parallel, distributed & accumulation) = 8
# [INFO|trainer.py:1730] 2023-12-17 08:09:45,900 >>   Gradient Accumulation steps = 1
# [INFO|trainer.py:1731] 2023-12-17 08:09:45,900 >>   Total optimization steps = 5,268
# [INFO|trainer.py:1732] 2023-12-17 08:09:45,900 >>   Number of trainable parameters = 124,061,961
# {'loss': 0.1724, 'learning_rate': 4.525436598329537e-05, 'epoch': 0.28}
#   9% 500/5268 [00:21<03:06, 25.63it/s][INFO|trainer.py:2881] 2023-12-17 08:10:07,415 >> Saving model checkpoint to /tmp/test-ner/checkpoint-500
# [INFO|configuration_utils.py:461] 2023-12-17 08:10:07,416 >> Configuration saved in /tmp/test-ner/checkpoint-500/config.json
# [INFO|modeling_utils.py:2193] 2023-12-17 08:10:08,191 >> Model weights saved in /tmp/test-ner/checkpoint-500/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2428] 2023-12-17 08:10:08,192 >> tokenizer config file saved in /tmp/test-ner/checkpoint-500/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2437] 2023-12-17 08:10:08,193 >> Special tokens file saved in /tmp/test-ner/checkpoint-500/special_tokens_map.json
# {'loss': 0.0749, 'learning_rate': 4.050873196659074e-05, 'epoch': 0.57}
#  19% 1000/5268 [00:43<02:46, 25.62it/s][INFO|trainer.py:2881] 2023-12-17 08:10:29,790 >> Saving model checkpoint to /tmp/test-ner/checkpoint-1000
# [INFO|configuration_utils.py:461] 2023-12-17 08:10:29,791 >> Configuration saved in /tmp/test-ner/checkpoint-1000/config.json
# [INFO|modeling_utils.py:2193] 2023-12-17 08:10:30,562 >> Model weights saved in /tmp/test-ner/checkpoint-1000/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2428] 2023-12-17 08:10:30,563 >> tokenizer config file saved in /tmp/test-ner/checkpoint-1000/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2437] 2023-12-17 08:10:30,563 >> Special tokens file saved in /tmp/test-ner/checkpoint-1000/special_tokens_map.json
# {'loss': 0.0584, 'learning_rate': 3.5763097949886106e-05, 'epoch': 0.85}
#  28% 1500/5268 [01:05<02:29, 25.28it/s][INFO|trainer.py:2881] 2023-12-17 08:10:51,835 >> Saving model checkpoint to /tmp/test-ner/checkpoint-1500
# [INFO|configuration_utils.py:461] 2023-12-17 08:10:51,836 >> Configuration saved in /tmp/test-ner/checkpoint-1500/config.json
# [INFO|modeling_utils.py:2193] 2023-12-17 08:10:52,614 >> Model weights saved in /tmp/test-ner/checkpoint-1500/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2428] 2023-12-17 08:10:52,615 >> tokenizer config file saved in /tmp/test-ner/checkpoint-1500/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2437] 2023-12-17 08:10:52,616 >> Special tokens file saved in /tmp/test-ner/checkpoint-1500/special_tokens_map.json
# {'loss': 0.0481, 'learning_rate': 3.1017463933181475e-05, 'epoch': 1.14}
#  38% 2000/5268 [01:28<02:12, 24.63it/s][INFO|trainer.py:2881] 2023-12-17 08:11:14,322 >> Saving model checkpoint to /tmp/test-ner/checkpoint-2000
# [INFO|configuration_utils.py:461] 2023-12-17 08:11:14,323 >> Configuration saved in /tmp/test-ner/checkpoint-2000/config.json
# [INFO|modeling_utils.py:2193] 2023-12-17 08:11:15,101 >> Model weights saved in /tmp/test-ner/checkpoint-2000/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2428] 2023-12-17 08:11:15,102 >> tokenizer config file saved in /tmp/test-ner/checkpoint-2000/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2437] 2023-12-17 08:11:15,102 >> Special tokens file saved in /tmp/test-ner/checkpoint-2000/special_tokens_map.json
# {'loss': 0.032, 'learning_rate': 2.6271829916476843e-05, 'epoch': 1.42}
#  47% 2500/5268 [01:50<01:49, 25.36it/s][INFO|trainer.py:2881] 2023-12-17 08:11:36,606 >> Saving model checkpoint to /tmp/test-ner/checkpoint-2500
# [INFO|configuration_utils.py:461] 2023-12-17 08:11:36,607 >> Configuration saved in /tmp/test-ner/checkpoint-2500/config.json
# [INFO|modeling_utils.py:2193] 2023-12-17 08:11:37,384 >> Model weights saved in /tmp/test-ner/checkpoint-2500/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2428] 2023-12-17 08:11:37,385 >> tokenizer config file saved in /tmp/test-ner/checkpoint-2500/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2437] 2023-12-17 08:11:37,386 >> Special tokens file saved in /tmp/test-ner/checkpoint-2500/special_tokens_map.json
# {'loss': 0.0335, 'learning_rate': 2.152619589977221e-05, 'epoch': 1.71}
#  57% 3000/5268 [02:12<01:29, 25.45it/s][INFO|trainer.py:2881] 2023-12-17 08:11:58,570 >> Saving model checkpoint to /tmp/test-ner/checkpoint-3000
# [INFO|configuration_utils.py:461] 2023-12-17 08:11:58,571 >> Configuration saved in /tmp/test-ner/checkpoint-3000/config.json
# [INFO|modeling_utils.py:2193] 2023-12-17 08:11:59,352 >> Model weights saved in /tmp/test-ner/checkpoint-3000/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2428] 2023-12-17 08:11:59,354 >> tokenizer config file saved in /tmp/test-ner/checkpoint-3000/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2437] 2023-12-17 08:11:59,354 >> Special tokens file saved in /tmp/test-ner/checkpoint-3000/special_tokens_map.json
# {'loss': 0.0303, 'learning_rate': 1.678056188306758e-05, 'epoch': 1.99}
#  66% 3500/5268 [02:34<01:09, 25.41it/s][INFO|trainer.py:2881] 2023-12-17 08:12:20,880 >> Saving model checkpoint to /tmp/test-ner/checkpoint-3500
# [INFO|configuration_utils.py:461] 2023-12-17 08:12:20,881 >> Configuration saved in /tmp/test-ner/checkpoint-3500/config.json
# [INFO|modeling_utils.py:2193] 2023-12-17 08:12:21,649 >> Model weights saved in /tmp/test-ner/checkpoint-3500/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2428] 2023-12-17 08:12:21,650 >> tokenizer config file saved in /tmp/test-ner/checkpoint-3500/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2437] 2023-12-17 08:12:21,650 >> Special tokens file saved in /tmp/test-ner/checkpoint-3500/special_tokens_map.json
# {'loss': 0.0164, 'learning_rate': 1.2034927866362947e-05, 'epoch': 2.28}
#  76% 4000/5268 [02:56<00:50, 25.32it/s][INFO|trainer.py:2881] 2023-12-17 08:12:42,891 >> Saving model checkpoint to /tmp/test-ner/checkpoint-4000
# [INFO|configuration_utils.py:461] 2023-12-17 08:12:42,892 >> Configuration saved in /tmp/test-ner/checkpoint-4000/config.json
# [INFO|modeling_utils.py:2193] 2023-12-17 08:12:43,662 >> Model weights saved in /tmp/test-ner/checkpoint-4000/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2428] 2023-12-17 08:12:43,664 >> tokenizer config file saved in /tmp/test-ner/checkpoint-4000/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2437] 2023-12-17 08:12:43,664 >> Special tokens file saved in /tmp/test-ner/checkpoint-4000/special_tokens_map.json
# {'loss': 0.0156, 'learning_rate': 7.289293849658315e-06, 'epoch': 2.56}
#  85% 4500/5268 [03:19<00:29, 25.72it/s][INFO|trainer.py:2881] 2023-12-17 08:13:04,944 >> Saving model checkpoint to /tmp/test-ner/checkpoint-4500
# [INFO|configuration_utils.py:461] 2023-12-17 08:13:04,945 >> Configuration saved in /tmp/test-ner/checkpoint-4500/config.json
# [INFO|modeling_utils.py:2193] 2023-12-17 08:13:05,715 >> Model weights saved in /tmp/test-ner/checkpoint-4500/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2428] 2023-12-17 08:13:05,716 >> tokenizer config file saved in /tmp/test-ner/checkpoint-4500/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2437] 2023-12-17 08:13:05,717 >> Special tokens file saved in /tmp/test-ner/checkpoint-4500/special_tokens_map.json
# {'loss': 0.0154, 'learning_rate': 2.5436598329536827e-06, 'epoch': 2.85}
#  95% 5000/5268 [03:41<00:10, 24.92it/s][INFO|trainer.py:2881] 2023-12-17 08:13:27,113 >> Saving model checkpoint to /tmp/test-ner/checkpoint-5000
# [INFO|configuration_utils.py:461] 2023-12-17 08:13:27,114 >> Configuration saved in /tmp/test-ner/checkpoint-5000/config.json
# [INFO|modeling_utils.py:2193] 2023-12-17 08:13:27,902 >> Model weights saved in /tmp/test-ner/checkpoint-5000/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2428] 2023-12-17 08:13:27,904 >> tokenizer config file saved in /tmp/test-ner/checkpoint-5000/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2437] 2023-12-17 08:13:27,904 >> Special tokens file saved in /tmp/test-ner/checkpoint-5000/special_tokens_map.json
# 100% 5266/5268 [03:54<00:00, 24.66it/s][INFO|trainer.py:1955] 2023-12-17 08:13:40,140 >>
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# {'train_runtime': 234.2429, 'train_samples_per_second': 179.826, 'train_steps_per_second': 22.489, 'train_loss': 0.04786890410254557, 'epoch': 3.0}
# 100% 5268/5268 [03:54<00:00, 22.49it/s]
# [INFO|trainer.py:2881] 2023-12-17 08:13:40,145 >> Saving model checkpoint to /tmp/test-ner
# [INFO|configuration_utils.py:461] 2023-12-17 08:13:40,146 >> Configuration saved in /tmp/test-ner/config.json
# [INFO|modeling_utils.py:2193] 2023-12-17 08:13:40,916 >> Model weights saved in /tmp/test-ner/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2428] 2023-12-17 08:13:40,917 >> tokenizer config file saved in /tmp/test-ner/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2437] 2023-12-17 08:13:40,918 >> Special tokens file saved in /tmp/test-ner/special_tokens_map.json
# ***** train metrics *****
#   epoch                    =        3.0
#   train_loss               =     0.0479
#   train_runtime            = 0:03:54.24
#   train_samples            =      14041
#   train_samples_per_second =    179.826
#   train_steps_per_second   =     22.489
# 12/17/2023 08:13:41 - INFO - __main__ - *** Evaluate ***
# [INFO|trainer.py:738] 2023-12-17 08:13:41,063 >> The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: pos_tags, ner_tags, chunk_tags, id, tokens. If pos_tags, ner_tags, chunk_tags, id, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# [INFO|trainer.py:3158] 2023-12-17 08:13:41,066 >> ***** Running Evaluation *****
# [INFO|trainer.py:3160] 2023-12-17 08:13:41,066 >>   Num examples = 3250
# [INFO|trainer.py:3163] 2023-12-17 08:13:41,066 >>   Batch size = 8
# 100% 407/407 [00:05<00:00, 70.12it/s]
# ***** eval metrics *****
#   epoch                   =        3.0
#   eval_accuracy           =     0.9923
#   eval_f1                 =     0.9564
#   eval_loss               =     0.0398
#   eval_precision          =     0.9526
#   eval_recall             =     0.9603
#   eval_runtime            = 0:00:05.82
#   eval_samples            =       3250
#   eval_samples_per_second =    557.783
#   eval_steps_per_second   =     69.852

# %%
import transformers
print(transformers.__version__)
# Out:
# 4.35.2
